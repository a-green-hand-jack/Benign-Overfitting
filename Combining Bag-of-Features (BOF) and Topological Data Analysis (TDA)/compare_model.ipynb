# %%
# %load_ext autoreload
# %autoreload 2

from post_process.betti_feature_compare import GetFeatureCared, CompareFeatureCared
from post_process.val_acc_compare import CompareValAcc, CompareBOF
from itertools import product

layer_care_options = [True, False]
feature2get_options = ["max_death", "bar_number", "all_bars_survive_time_sum", "max_epsilon_bar_number", "death_len"]
l_distance_options = ['L1', 'L2']
betti_number_dim_options = ['0th', '1th']

# 使用product函数生成所有可能的组合
combinations = list(product(l_distance_options, feature2get_options,   betti_number_dim_options, layer_care_options))

# %%
from post_process.compare_model import CompareModel

for combination in combinations:
    # comp = CompareFeatureCared(folder, pkl_filename, *combination, aug_type="scale")
    print(combination)
    temp_Compare = CompareModel(*combination,file_path=r".\pre_process_outputs\angle_no_train", save_path=r".\pre_process_outputs\angle_no_train", folder_number=40)
# Out:
# ('L1', 'max_death', '0th', True)
# ('L1', 'max_death', '0th', False)
# ('L1', 'max_death', '1th', True)
# ('L1', 'max_death', '1th', False)
# ('L1', 'bar_number', '0th', True)
# ('L1', 'bar_number', '0th', False)
# ('L1', 'bar_number', '1th', True)
# ('L1', 'bar_number', '1th', False)
# ('L1', 'all_bars_survive_time_sum', '0th', True)
# ('L1', 'all_bars_survive_time_sum', '0th', False)
# ('L1', 'all_bars_survive_time_sum', '1th', True)
# ('L1', 'all_bars_survive_time_sum', '1th', False)
# ('L1', 'max_epsilon_bar_number', '0th', True)
# ('L1', 'max_epsilon_bar_number', '0th', False)
# ('L1', 'max_epsilon_bar_number', '1th', True)
# ('L1', 'max_epsilon_bar_number', '1th', False)
# ('L1', 'death_len', '0th', True)
# ('L1', 'death_len', '0th', False)
# ('L1', 'death_len', '1th', True)
# ('L1', 'death_len', '1th', False)
# ('L2', 'max_death', '0th', True)
# ('L2', 'max_death', '0th', False)
# ('L2', 'max_death', '1th', True)
# ('L2', 'max_death', '1th', False)
# ('L2', 'bar_number', '0th', True)
# ('L2', 'bar_number', '0th', False)
# ('L2', 'bar_number', '1th', True)
# ('L2', 'bar_number', '1th', False)
# ('L2', 'all_bars_survive_time_sum', '0th', True)
# ('L2', 'all_bars_survive_time_sum', '0th', False)
# ('L2', 'all_bars_survive_time_sum', '1th', True)
# ('L2', 'all_bars_survive_time_sum', '1th', False)
# ('L2', 'max_epsilon_bar_number', '0th', True)
# ('L2', 'max_epsilon_bar_number', '0th', False)
# ('L2', 'max_epsilon_bar_number', '1th', True)
# ('L2', 'max_epsilon_bar_number', '1th', False)
# ('L2', 'death_len', '0th', True)
# ('L2', 'death_len', '0th', False)
# ('L2', 'death_len', '1th', True)
# ('L2', 'death_len', '1th', False)
