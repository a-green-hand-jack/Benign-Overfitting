# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 考察input的bars

# %% [markdown]
# ### 首先加载数据

# %%
import pickle
# 定义一个加载pkl文件的函数
def print_pkl_file(file_path):
    try:
        with open(file_path, 'rb') as file:
            data = pickle.load(file)
            # print(data)
    except Exception as e:
        print(f"Error: {e}")
    
    return data

# %% [markdown]
# ### 然后绘制图像

# %%
import os
import matplotlib.pyplot as plt

def plot_stacked_horizontal_bars2(ax, bar_data, index_title, color, pre_index):
    """
    绘制表示持续区间的堆叠水平条形图。

    参数:
    - ax (matplotlib.axes._axes.Axes): 子图对象。
    - bar_data (列表): 表示持续区间的数据列表，每个元素是包含起始和结束位置的列表。
    - index_title (整数): 用于标题的索引。
    - color (str): 条形图的颜色。
    - plt_title (str): 图的标题。

    返回: 无返回值，但会在子图上显示绘制的水平条形图。
    """

    for index, bar in enumerate(bar_data):
        start = bar[0]  # 起始位置
        end = bar[1]    # 结束位置
        # 绘制水平条形图
        if index == 0:
            ax.barh(index + pre_index,  end - start, left=start, height=0.5, color=color, label=index_title)
        else:
            ax.barh(index + pre_index,  end - start, left=start, height=0.5, color=color)

def plot_betti_number_bars2(betti_number, plt_title=None, root=None):
    """
    绘制表示 Betti 数的堆叠水平条形图。

    参数:
    - betti_number (列表的列表): 包含多个 Betti 数的列表，每个 Betti 数以堆叠水平条形图表示。
    - bar_spacing (浮点数): 条形图之间的间距。
    - plt_title (str): 图的标题。
    - root (str): 图的保存路径。

    返回: 无返回值，但会在同一张图上显示绘制的堆叠水平条形图。
    """
    plt.rcParams['pdf.fonttype'] = 42
    plt.rcParams['ps.fonttype'] = 42

    if not os.path.exists(root):
        os.makedirs(root)

    fig, ax = plt.subplots()

    colors = ['red', 'black']  # 定义不同 Betti 数的颜色
    pre_index = 0
    for index, (value, color) in enumerate(zip(betti_number, colors)):
        if index == 0:
            pre_index += len(betti_number[1])
        else:
            pre_index = 0
        plot_stacked_horizontal_bars2(ax, value, index, color, pre_index)
        

    # 设置坐标轴标签
    ax.set_ylabel('Number')
    ax.set_xlabel('Birth-Death')
    ax.set_title(f"Persistence barcode {plt_title}")

    # 添加图例
    ax.legend()

    # 保存图片为PDF格式
    save_path = os.path.join(root, f"Betti_Bars_{plt_title}.pdf")
    # plt.savefig(save_path, format='pdf', bbox_inches='tight')
    plt.savefig(save_path, format='pdf', bbox_inches='tight', dpi=1000)


    # 显示图表
    plt.show()

# %%
# 例子
pkl_file_path = './Result/model_DTA_mini_imagenet/0/bars_betti_features_12th.pkl'
test_data = print_pkl_file(pkl_file_path)
L12save = test_data['L1_betti_number_list'][0]
L22save = test_data['L2_betti_number_list'][0]
data = L22save
plot_betti_number_bars2(betti_number=data, plt_title='L2', root="./test_draw_bars/")

# %% [markdown]
# ### 批量处理

# %% [markdown]
# #### model_DTA_mini_imagenet

# %%
import os

def print_subdirectories(folder_path, save_path = "./test_draw_bars/model_DTA_mini_imagenet"):
    """
    打印指定文件夹下的子文件夹路径。

    参数:
    - folder_path (str): 目标文件夹的路径。

    返回: 无返回值，但会打印子文件夹的路径。
    """
    # 获取文件夹下的所有子文件夹
    subdirectories = [os.path.join(folder_path, d) for d in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, d))]
    model_list = ['MLP', "LeNet", 'ResNet18', 'ResNet34', 'ResNet50', 'ResNet101', 'ResNet152']
    # 打印子文件夹的路径
    for subdirectory in subdirectories:
        print(os.path.join(subdirectory, 'bars_betti_features_12th.pkl'))
        pkl_file_path = os.path.join(subdirectory, 'bars_betti_features_12th.pkl')
        test_data = print_pkl_file(pkl_file_path)
        L12save = test_data['L1_betti_number_list'][0]
        L22save = test_data['L2_betti_number_list'][0]

        plot_betti_number_bars2(betti_number=L12save, plt_title='L1 model {}'.format(model_list[int(subdirectory.split('\\')[-1])]), root=save_path)
        plot_betti_number_bars2(betti_number=L22save, plt_title='L2 model {}'.format(model_list[int(subdirectory.split('\\')[-1])]), root=save_path)

# 示例用法
folder_path = "./Result/model_DTA_mini_imagenet"
save_path = "./test_draw_bars/model_DTA_mini_imagenet"
print_subdirectories(folder_path, save_path)
# Out:
# ./Result/model_DTA_mini_imagenet\0\bars_betti_features_12th.pkl
# ./Result/model_DTA_mini_imagenet\1\bars_betti_features_12th.pkl
# ./Result/model_DTA_mini_imagenet\2\bars_betti_features_12th.pkl
# ./Result/model_DTA_mini_imagenet\3\bars_betti_features_12th.pkl
# ./Result/model_DTA_mini_imagenet\4\bars_betti_features_12th.pkl
# ./Result/model_DTA_mini_imagenet\5\bars_betti_features_12th.pkl
# ./Result/model_DTA_mini_imagenet\6\bars_betti_features_12th.pkl

# %% [markdown]
# #### model_DTA_tiny_imagenet

# %%
folder_path = "./Result/model_DTA_tiny_imagenet"
save_path = "./test_draw_bars/model_DTA_tiny_imagenet"
print_subdirectories(folder_path, save_path)
# Out:
# ./Result/model_DTA_tiny_imagenet\0\bars_betti_features_12th.pkl
# ./Result/model_DTA_tiny_imagenet\1\bars_betti_features_12th.pkl
# ./Result/model_DTA_tiny_imagenet\2\bars_betti_features_12th.pkl
# ./Result/model_DTA_tiny_imagenet\3\bars_betti_features_12th.pkl
# ./Result/model_DTA_tiny_imagenet\4\bars_betti_features_12th.pkl
# ./Result/model_DTA_tiny_imagenet\5\bars_betti_features_12th.pkl
# ./Result/model_DTA_tiny_imagenet\6\bars_betti_features_12th.pkl

# %% [markdown]
# #### CIFAR10

# %%
folder_path = "./Result/model_DTA_cifar10"
save_path = "./test_draw_bars/model_DTA_cifar10"
print_subdirectories(folder_path, save_path)
# Out:
# ./Result/model_DTA_cifar10\0\bars_betti_features_12th.pkl
# ./Result/model_DTA_cifar10\1\bars_betti_features_12th.pkl
# ./Result/model_DTA_cifar10\2\bars_betti_features_12th.pkl
# ./Result/model_DTA_cifar10\3\bars_betti_features_12th.pkl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 folder_path = "./Result/model_DTA_cifar10"
#       2 save_path = "./test_draw_bars/model_DTA_cifar10"
# ----> 3 print_subdirectories(folder_path, save_path)
#
# Cell In[5], line 23, in print_subdirectories(folder_path, save_path)
#      20 L12save = test_data['L1_betti_number_list'][0]
#      21 L22save = test_data['L2_betti_number_list'][0]
# ---> 23 plot_betti_number_bars2(betti_number=L12save, plt_title='L1 model {}'.format(model_list[int(subdirectory.split('\\')[-1])]), root=save_path)
#      24 plot_betti_number_bars2(betti_number=L22save, plt_title='L2 model {}'.format(model_list[int(subdirectory.split('\\')[-1])]), root=save_path)
#
# Cell In[3], line 64, in plot_betti_number_bars2(betti_number, plt_title, root)
#      62 # 保存图片为PDF格式
#      63 save_path = os.path.join(root, f"Betti_Bars_{plt_title}.pdf")
# ---> 64 plt.savefig(save_path, format='pdf', bbox_inches='tight')
#      66 # 显示图表
#      67 plt.show()
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\figure.py:3378, in Figure.savefig(self, fname, transparent, **kwargs)
#    3374     for ax in self.axes:
#    3375         stack.enter_context(
#    3376             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3378 self.canvas.print_figure(fname, **kwargs)
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\backend_bases.py:2346, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
# -> 2346         bbox_inches = self.figure.get_tightbbox(
#    2347             renderer, bbox_extra_artists=bbox_extra_artists)
#    2348         if pad_inches is None:
#    2349             pad_inches = rcParams['savefig.pad_inches']
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\figure.py:1785, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1781 if ax.get_visible():
#    1782     # some axes don't take the bbox_extra_artists kwarg so we
#    1783     # need this conditional....
#    1784     try:
# -> 1785         bbox = ax.get_tightbbox(
#    1786             renderer, bbox_extra_artists=bbox_extra_artists)
#    1787     except TypeError:
#    1788         bbox = ax.get_tightbbox(renderer)
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\axes\_base.py:4408, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4405     bbox_artists = self.get_default_bbox_extra_artists()
#    4407 for a in bbox_artists:
# -> 4408     bbox = a.get_tightbbox(renderer)
#    4409     if (bbox is not None
#    4410             and 0 < bbox.width < np.inf
#    4411             and 0 < bbox.height < np.inf):
#    4412         bb.append(bbox)
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\artist.py:367, in Artist.get_tightbbox(self, renderer)
#     352 def get_tightbbox(self, renderer=None):
#     353     """
#     354     Like `.Artist.get_window_extent`, but includes any clipping.
#     355
#    (...)
#     365         The enclosing bounding box (in figure pixel coordinates).
#     366     """
# --> 367     bbox = self.get_window_extent(renderer)
#     368     if self.get_clip_on():
#     369         clip_box = self.get_clip_box()
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\patches.py:604, in Patch.get_window_extent(self, renderer)
#     603 def get_window_extent(self, renderer=None):
# --> 604     return self.get_path().get_extents(self.get_transform())
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\path.py:621, in Path.get_extents(self, transform, **kwargs)
#     619 from .transforms import Bbox
#     620 if transform is not None:
# --> 621     self = transform.transform_path(self)
#     622 if self.codes is None:
#     623     xys = self.vertices
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\transforms.py:1603, in Transform.transform_path(self, path)
#    1596 def transform_path(self, path):
#    1597     """
#    1598     Apply the transform to `.Path` *path*, returning a new `.Path`.
#    1599
#    1600     In some cases, this transform may insert curves into the path
#    1601     that began as line segments.
#    1602     """
# -> 1603     return self.transform_path_affine(self.transform_path_non_affine(path))
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\transforms.py:1613, in Transform.transform_path_affine(self, path)
#    1605 def transform_path_affine(self, path):
#    1606     """
#    1607     Apply the affine part of this transform to `.Path` *path*, returning a
#    1608     new `.Path`.
#    (...)
#    1611     ``transform_path_affine(transform_path_non_affine(values))``.
#    1612     """
# -> 1613     return self.get_affine().transform_path_affine(path)
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\transforms.py:2450, in CompositeGenericTransform.get_affine(self)
#    2447     return self._b.get_affine()
#    2448 else:
#    2449     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2450                            self._a.get_affine().get_matrix()))
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\transforms.py:2449, in CompositeGenericTransform.get_affine(self)
#    2447     return self._b.get_affine()
#    2448 else:
# -> 2449     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2450                            self._a.get_affine().get_matrix()))
#
# File d:\anaconda\envs\PyTorchGpu\Lib\site-packages\matplotlib\transforms.py:1903, in Affine2D.__init__(self, matrix, **kwargs)
#    1900 if matrix is None:
#    1901     # A bit faster than np.identity(3).
#    1902     matrix = IdentityTransform._mtx
# -> 1903 self._mtx = matrix.copy()
#    1904 self._invalid = 0
#
# KeyboardInterrupt:
