# %%
# %load_ext autoreload
# %autoreload 2
import os
import pandas as pd
import matplotlib.pyplot as plt
from support_code.draw_accuracy import *
import numpy as np
plt.rcParams['font.sans-serif'] = ['SimHei']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MLP

# %%
# 指定存储图像的目录
input_dir = 'MLP/csv'
output_dir = 'MLP/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

# %% [markdown]
# ## 观察整体的准确率变化

# %%
input_dir = 'MLP/csv'
output_dir = 'MLP/img/整体'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)
best_valid_acc(input_dir=input_dir, output_dir=output_dir)
# Out:
# 最大值字典:
# (0.1000, 0.1000, 0.1000, 0.1000): 0.5666799363057324
# (0.1000, 0.1000, 0.1000, 0.3250): 0.5593152866242038
# (0.1000, 0.1000, 0.1000, 0.5500): 0.5443869426751592
# (0.1000, 0.1000, 0.1000, 0.7750): 0.5345342356687898
# (0.1000, 0.1000, 0.1000, 1.0000): 0.5176154458598726
# (0.1000, 0.1000, 0.3250, 0.1000): 0.5621019108280255
# (0.1000, 0.1000, 0.3250, 0.3250): 0.5573248407643312
# (0.1000, 0.1000, 0.3250, 0.5500): 0.5475716560509554
# (0.1000, 0.1000, 0.3250, 0.7750): 0.526671974522293
# (0.1000, 0.1000, 0.3250, 1.0000): 0.5139331210191083
# (0.1000, 0.1000, 0.5500, 0.1000): 0.5729498407643312
# (0.1000, 0.1000, 0.5500, 0.3250): 0.558718152866242
# (0.1000, 0.1000, 0.5500, 0.5500): 0.5474721337579618
# (0.1000, 0.1000, 0.5500, 0.7750): 0.5244824840764332
# (0.1000, 0.1000, 0.5500, 1.0000): 0.515625
# (0.1000, 0.1000, 0.7750, 0.1000): 0.5677746815286624
# (0.1000, 0.1000, 0.7750, 0.3250): 0.5626990445859873
# (0.1000, 0.1000, 0.7750, 0.5500): 0.5485668789808917
# ...

# %% [markdown]
# ## 观察某一部分的准确率变化

# %% [markdown]
# ### 观察高维情况

# %%
# 示例用法
input_dir = 'MLP/csv'
output_dir = 'MLP/img/高维'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

# 创建包含多个元组的列表
param_list = []

for value in (0.1000,0.3250, 0.5500, 0.7750, 1.0000):
    min_values = (0.1000, value, value, value)
    max_values = (1.0000, value, value, value)
    param_list.append((min_values, max_values))

for value in param_list:
    # print(value[0], value[1])
    selected_files = extract_file_names(input_dir, min_values=value[0], max_values=value[1])
    chose_best_valid_acc(input_dir=input_dir, output_dir=output_dir, csv_list=selected_files,new_min_values=value[0], new_max_values=value[1])

# %% [markdown]
# ### 观察低维情况

# %%
group = 100
sept = 1
input_dir = 'MLP/csv'
output_dir = 'MLP/img/低维'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)
best_valid_acc_group_index(input_dir, output_dir, group, sept)

# %% [markdown]
# # LeNet

# %% [markdown]
# ## 观察整体的情况

# %%
# 指定存储图像的目录
input_dir = 'LeNet/csv'
output_dir = 'LeNet/img/整体'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)
best_valid_acc(input_dir=input_dir, output_dir=output_dir)
# Out:
# 最大值字典:
# (0.1000, 0.1000, 0.1000, 0.1000): 0.671875
# (0.1000, 0.1000, 0.1000, 0.3250): 0.6624203821656051
# (0.1000, 0.1000, 0.1000, 0.5500): 0.6591361464968153
# (0.1000, 0.1000, 0.1000, 0.7750): 0.6537619426751592
# (0.1000, 0.1000, 0.1000, 1.0000): 0.648984872611465
# (0.1000, 0.1000, 0.3250, 0.1000): 0.6636146496815286
# (0.1000, 0.1000, 0.3250, 0.3250): 0.6577428343949044
# (0.1000, 0.1000, 0.3250, 0.5500): 0.6542595541401274
# (0.1000, 0.1000, 0.3250, 0.7750): 0.6671974522292994
# (0.1000, 0.1000, 0.3250, 1.0000): 0.6542595541401274
# (0.1000, 0.1000, 0.5500, 0.1000): 0.6700835987261147
# (0.1000, 0.1000, 0.5500, 0.3250): 0.6731687898089171
# (0.1000, 0.1000, 0.5500, 0.5500): 0.6622213375796179
# (0.1000, 0.1000, 0.5500, 0.7750): 0.6534633757961783
# (0.1000, 0.1000, 0.5500, 1.0000): 0.6580414012738853
# (0.1000, 0.1000, 0.7750, 0.1000): 0.6715764331210191
# (0.1000, 0.1000, 0.7750, 0.3250): 0.6793391719745223
# (0.1000, 0.1000, 0.7750, 0.5500): 0.6702826433121019
# ...

# %% [markdown]
# ## 观察部分情况

# %% [markdown]
# ### 观察高维情况

# %%
# 指定存储图像的目录
input_dir = 'LeNet/csv'
output_dir = 'LeNet/img/高维'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

# 创建包含多个元组的列表
param_list = []

for value in (0.1000,0.3250, 0.5500, 0.7750, 1.0000):
    min_values = (0.1000, value, value, value)
    max_values = (1.0000, value, value, value)
    param_list.append((min_values, max_values))

for value in param_list:
    # print(value[0], value[1])
    selected_files = extract_file_names(input_dir, min_values=value[0], max_values=value[1])
    chose_best_valid_acc(input_dir=input_dir, output_dir=output_dir, csv_list=selected_files,new_min_values=value[0], new_max_values=value[1])

# %% [markdown]
# ### 观察低维情况

# %%
group = 25
sept = 1
input_dir = 'LeNet/csv'
output_dir = 'LeNet/img/低维'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)
best_valid_acc_group_index(input_dir, output_dir, group, sept)

# %% [markdown]
# # 新尝试

# %% [markdown]
# ## MLP

# %% [markdown]
# ### 转化为矩阵
#
# 我现在深感每次都是读取`csv`文件的不变,在速度和处理上都不方便,所以先转化为矩阵之后,在进行后处理

# %%
# 示例用法
input_dir = "MLP\csv"
max_values_array = extract_max_values(input_dir)
# print(max_values_array)

# %%
import numpy as np

# 假设 max_values_array 是一个长度为 625 的 NumPy 数组
# max_values_array = np.array(...)  # 假设这里是您的 max_values_array 数据

# 确保 max_values_array 的长度是 625
if len(max_values_array) != 625:
    raise ValueError("max_values_array 的长度不是 625，请调整输入数据以匹配所需长度。")

# 将 max_values_array 重新形状为 5x5x5x5 的 NumPy 矩阵
max_values_matrix = max_values_array.reshape((5, 5, 5, 5))

# 现在 max_values_matrix 是一个 5x5x5x5 的 NumPy 矩阵
print(max_values_matrix)

# %%
import numpy as np
import matplotlib.pyplot as plt



# 示例用法
# 指定关心的索引列表
i = 4
b = 124
indices_of_interest = range(0+0,125+125*i,25)

# 调用函数绘制散点图
plot_values_of_interest(max_values_matrix, indices_of_interest,"LeNet/img/new", plot=True)

# %% [markdown]
# ## LeNet

# %%
# 示例用法
input_dir = "LeNet\csv"
max_values_array = extract_max_values(input_dir)

import numpy as np

# 确保 max_values_array 的长度是 625
if len(max_values_array) != 625:
    raise ValueError("max_values_array 的长度不是 625，请调整输入数据以匹配所需长度。")

# 将 max_values_array 重新形状为 5x5x5x5 的 NumPy 矩阵
max_values_matrix = max_values_array.reshape((5, 5, 5, 5))

# %%
import numpy as np
import matplotlib.pyplot as plt
# 示例用法
# 指定关心的索引列表
i = 2
b = 125
c = 2
# indices_of_interest = range(c+ 0+125*i,c + b+125*i,25)
indices_of_interest = range(0,625,125)
# 调用函数绘制散点图
plot_values_of_interest(max_values_matrix, indices_of_interest,"LeNet/img/new", plot=True)
