# %%
# %load_ext autoreload
# %autoreload 2
import os
import pandas as pd
import matplotlib.pyplot as plt
from support_code.draw_accuracy import *
import numpy as np
plt.rcParams['font.sans-serif'] = ['SimHei']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MLP

# %%
# 指定存储图像的目录
input_dir = 'MLP-30-30/csv'
output_dir = 'MLP-30-30/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

# %% [markdown]
# ## 观察整体的准确率变化

# %%
best_valid_acc(input_dir=input_dir, output_dir=output_dir, plot=True)
# Out:
# 1-0.0000, 0.0000.csv
# 2--1.0000, 1.0000.csv
# 3--2.0000, 2.0000.csv
# 4--3.0000, 3.0000.csv
# 5--4.0000, 4.0000.csv
# 6--5.0000, 5.0000.csv
# 7--6.0000, 6.0000.csv
# 8--7.0000, 7.0000.csv
# 9--8.0000, 8.0000.csv
# 10--9.0000, 9.0000.csv
# 11--10.0000, 10.0000.csv
# 12--11.0000, 11.0000.csv
# 13--12.0000, 12.0000.csv
# 14--13.0000, 13.0000.csv
# 15--14.0000, 14.0000.csv
# 16--15.0000, 15.0000.csv
# 17--16.0000, 16.0000.csv
# 18--17.0000, 17.0000.csv
# 19--18.0000, 18.0000.csv
# 20--19.0000, 19.0000.csv
# 21--20.0000, 20.0000.csv
# 22--21.0000, 21.0000.csv
# 23--22.0000, 22.0000.csv
# 24--23.0000, 23.0000.csv
# 25--24.0000, 24.0000.csv
# 26--25.0000, 25.0000.csv
# 27--26.0000, 26.0000.csv
# 28--27.0000, 27.0000.csv
# 29--28.0000, 28.0000.csv
# 30--29.0000, 29.0000.csv
# 31--30.0000, 30.0000.csv
# 最大值字典:
# 1-0.0000, 0.0000: 0.5650875796178344
# 2--1.0000, 1.0000: 0.5630971337579618
# 3--2.0000, 2.0000: 0.4667595541401274
# 4--3.0000, 3.0000: 0.4378980891719745
# 5--4.0000, 4.0000: 0.4422770700636942
# 6--5.0000, 5.0000: 0.4234673566878981
# 7--6.0000, 6.0000: 0.4278463375796178
# 8--7.0000, 7.0000: 0.4177945859872611
# 9--8.0000, 8.0000: 0.4242635350318471
# 10--9.0000, 9.0000: 0.4084394904458598
# 11--10.0000, 10.0000: 0.4052547770700637
# 12--11.0000, 11.0000: 0.3984872611464968
# 13--12.0000, 12.0000: 0.4053542993630573
# 14--13.0000, 13.0000: 0.3999800955414013
# 15--14.0000, 14.0000: 0.3892316878980891
# 16--15.0000, 15.0000: 0.4014729299363057
# 17--16.0000, 16.0000: 0.3756966560509554
# 18--17.0000, 17.0000: 0.3907245222929936
# 19--18.0000, 18.0000: 0.3800756369426751
# 20--19.0000, 19.0000: 0.3695262738853503
# 21--20.0000, 20.0000: 0.3945063694267516
# 22--21.0000, 21.0000: 0.3675358280254777
# 23--22.0000, 22.0000: 0.3589769108280254
# 24--23.0000, 23.0000: 0.369327229299363
# 25--24.0000, 24.0000: 0.3823646496815286
# 26--25.0000, 25.0000: 0.3599721337579618
# 27--26.0000, 26.0000: 0.3682324840764331
# 28--27.0000, 27.0000: 0.3580812101910828
# 29--28.0000, 28.0000: 0.3439490445859872
# 30--29.0000, 29.0000: 0.3548964968152866
# 31--30.0000, 30.0000: 0.3512141719745223

# %% [markdown]
# # LeNet

# %% [markdown]
# ## 观察整体的情况

# %%
# 指定存储图像的目录
input_dir = 'LeNet-30-30/csv'
output_dir = 'LeNet-30-30/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)
best_valid_acc(input_dir=input_dir, output_dir=output_dir,plot=True)
# Out:
# 1-0.0000, 0.0000.csv
# 2--1.0000, 1.0000.csv
# 3--2.0000, 2.0000.csv
# 4--3.0000, 3.0000.csv
# 5--4.0000, 4.0000.csv
# 6--5.0000, 5.0000.csv
# 7--6.0000, 6.0000.csv
# 8--7.0000, 7.0000.csv
# 9--8.0000, 8.0000.csv
# 10--9.0000, 9.0000.csv
# 11--10.0000, 10.0000.csv
# 12--11.0000, 11.0000.csv
# 13--12.0000, 12.0000.csv
# 14--13.0000, 13.0000.csv
# 15--14.0000, 14.0000.csv
# 16--15.0000, 15.0000.csv
# 17--16.0000, 16.0000.csv
# 18--17.0000, 17.0000.csv
# 19--18.0000, 18.0000.csv
# 20--19.0000, 19.0000.csv
# 21--20.0000, 20.0000.csv
# 22--21.0000, 21.0000.csv
# 23--22.0000, 22.0000.csv
# 24--23.0000, 23.0000.csv
# 25--24.0000, 24.0000.csv
# 26--25.0000, 25.0000.csv
# 27--26.0000, 26.0000.csv
# 28--27.0000, 27.0000.csv
# 29--28.0000, 28.0000.csv
# 30--29.0000, 29.0000.csv
# 31--30.0000, 30.0000.csv
# 最大值字典:
# 1-0.0000, 0.0000: 0.6610270700636943
# 2--1.0000, 1.0000: 0.6607285031847133
# 3--2.0000, 2.0000: 0.6426154458598726
# 4--3.0000, 3.0000: 0.6496815286624203
# 5--4.0000, 4.0000: 0.6520700636942676
# 6--5.0000, 5.0000: 0.6695859872611465
# 7--6.0000, 6.0000: 0.663515127388535
# 8--7.0000, 7.0000: 0.6455015923566879
# 9--8.0000, 8.0000: 0.64171974522293
# 10--9.0000, 9.0000: 0.6547571656050956
# 11--10.0000, 10.0000: 0.6399283439490446
# 12--11.0000, 11.0000: 0.6119625796178344
# 13--12.0000, 12.0000: 0.6097730891719745
# 14--13.0000, 13.0000: 0.6137539808917197
# 15--14.0000, 14.0000: 0.6242038216560509
# 16--15.0000, 15.0000: 0.6107683121019108
# 17--16.0000, 16.0000: 0.59265525477707
# 18--17.0000, 17.0000: 0.5854896496815286
# 19--18.0000, 18.0000: 0.5810111464968153
# 20--19.0000, 19.0000: 0.5652866242038217
# 21--20.0000, 20.0000: 0.5494625796178344
# 22--21.0000, 21.0000: 0.5528463375796179
# 23--22.0000, 22.0000: 0.5431926751592356
# 24--23.0000, 23.0000: 0.5522492038216561
# 25--24.0000, 24.0000: 0.5638933121019108
# 26--25.0000, 25.0000: 0.5076632165605095
# 27--26.0000, 26.0000: 0.5150278662420382
# 28--27.0000, 27.0000: 0.5206011146496815
# 29--28.0000, 28.0000: 0.507265127388535
# 30--29.0000, 29.0000: 0.5036823248407644
# 31--30.0000, 30.0000: 0.5016918789808917
