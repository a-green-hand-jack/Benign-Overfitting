# %%
# %load_ext autoreload
# %autoreload 2
import os
import pandas as pd
import matplotlib.pyplot as plt
from support_code.draw_accuracy import *
import numpy as np
plt.rcParams['font.sans-serif'] = ['SimHei']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MLP

# %%
# 指定存储图像的目录
input_dir = 'MLP-alpha/csv'
output_dir = 'MLP-alpha/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

# %% [markdown]
# ## 观察整体的准确率变化

# %%
best_valid_acc(input_dir=input_dir, output_dir=output_dir, plot=True)
# Out:
# 1-0.0000.csv
# 2-0.1000.csv
# 3-0.2000.csv
# 4-0.3000.csv
# 5-0.4000.csv
# 6-0.5000.csv
# 7-0.6000.csv
# 8-0.7000.csv
# 9-0.8000.csv
# 10-0.9000.csv
# 11-1.0000.csv
# 最大值字典:
# 1-0.0000: 0.5354299363057324
# 2-0.1000: 0.5418988853503185
# 3-0.2000: 0.5473726114649682
# 4-0.3000: 0.5504578025477707
# 5-0.4000: 0.5512539808917197
# 6-0.5000: 0.5519506369426752
# 7-0.6000: 0.5561305732484076
# 8-0.7000: 0.551453025477707
# 9-0.8000: 0.5478702229299363
# 10-0.9000: 0.5563296178343949
# 11-1.0000: 0.5605095541401274

# %% [markdown]
# # LeNet

# %% [markdown]
# ## 观察整体的情况

# %%
# 指定存储图像的目录
input_dir = 'LeNet-alpha/csv'
output_dir = 'LeNet-alpha/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)
best_valid_acc(input_dir=input_dir, output_dir=output_dir,plot=True)
# Out:
# 1-0.0000.csv
# 2-0.0500.csv
# 3-0.1000.csv
# 4-0.1500.csv
# 5-0.2000.csv
# 6-0.2500.csv
# 7-0.3000.csv
# 8-0.3500.csv
# 9-0.4000.csv
# 10-0.4500.csv
# 11-0.5000.csv
# 12-0.5500.csv
# 13-0.6000.csv
# 14-0.6500.csv
# 15-0.7000.csv
# 16-0.7500.csv
# 17-0.8000.csv
# 18-0.8500.csv
# 19-0.9000.csv
# 20-0.9500.csv
# 21-1.0000.csv
# 22-1.0500.csv
# 最大值字典:
# 1-0.0000: 0.6346536624203821
# 2-0.0500: 0.63953025477707
# 3-0.1000: 0.6642117834394905
# 4-0.1500: 0.6504777070063694
# 5-0.2000: 0.6598328025477707
# 6-0.2500: 0.6670979299363057
# 7-0.3000: 0.6637141719745223
# 8-0.3500: 0.6663017515923567
# 9-0.4000: 0.6724721337579618
# 10-0.4500: 0.6675955414012739
# 11-0.5000: 0.6793391719745223
# 12-0.5500: 0.6731687898089171
# 13-0.6000: 0.6734673566878981
# 14-0.6500: 0.6880971337579618
# 15-0.7000: 0.6706807324840764
# 16-0.7500: 0.666202229299363
# 17-0.8000: 0.6962579617834395
# 18-0.8500: 0.6807324840764332
# 19-0.9000: 0.6777468152866242
# 20-0.9500: 0.6852109872611465
# 21-1.0000: 0.6894904458598726
# 22-1.0500: 0.6878980891719745
