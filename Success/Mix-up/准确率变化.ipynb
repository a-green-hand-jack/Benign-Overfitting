# %%
# %load_ext autoreload
# %autoreload 2
import os
import pandas as pd
import matplotlib.pyplot as plt
from support_code.draw_accuracy import *
import numpy as np
plt.rcParams['font.sans-serif'] = ['SimHei']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MLP

# %%
# 指定存储图像的目录
input_dir = 'MLP-alpha-uniform-Cos-big/csv'
output_dir = 'MLP-alpha-uniform-Cos-big/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

# %% [markdown]
# ## 观察整体的准确率变化

# %%
best_valid_acc(input_dir=input_dir, output_dir=output_dir, plot=True,use_text=False)
# Out:
# 0-0.0000.csv
# 1-0.0300.csv
# 2-0.0600.csv
# 3-0.0900.csv
# 4-0.1200.csv
# 5-0.1500.csv
# 6-0.1800.csv
# 7-0.2100.csv
# 8-0.2400.csv
# 9-0.2700.csv
# 10-0.3000.csv
# 11-0.3300.csv
# 12-0.3600.csv
# 13-0.3900.csv
# 14-0.4200.csv
# 15-0.4500.csv
# 16-0.4800.csv
# 17-0.5100.csv
# 18-0.5400.csv
# 19-0.5700.csv
# 20-0.6000.csv
# 21-0.6300.csv
# 22-0.6600.csv
# 23-0.6900.csv
# 24-0.7200.csv
# 25-0.7500.csv
# 26-0.7800.csv
# 27-0.8100.csv
# 28-0.8400.csv
# 29-0.8700.csv
# 30-0.9000.csv
# 31-0.9300.csv
# 32-0.9600.csv
# 最大值字典:
# 0-0.0000: 0.5624004777070064
# 1-0.0300: 0.5509554140127388
# 2-0.0600: 0.5504578025477707
# 3-0.0900: 0.546875
# 4-0.1200: 0.5609076433121019
# 5-0.1500: 0.5602109872611465
# 6-0.1800: 0.5625995222929936
# 7-0.2100: 0.5741441082802548
# 8-0.2400: 0.5733479299363057
# 9-0.2700: 0.5793192675159236
# 10-0.3000: 0.5815087579617835
# 11-0.3300: 0.5791202229299363
# 12-0.3600: 0.57921974522293
# 13-0.3900: 0.576234076433121
# 14-0.4200: 0.5761345541401274
# ...

# %% [markdown]
# # LeNet

# %% [markdown]
# ## 观察整体的情况

# %%
# 指定存储图像的目录
input_dir = 'LeNet-alpha-uniform-Cos-big/csv'
output_dir = 'LeNet-alpha-uniform-Cos-big/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)
best_valid_acc(input_dir=input_dir, output_dir=output_dir,plot=True,use_text=False)
# Out:
# 0-0.0000.csv
# 1-0.0300.csv
# 2-0.0600.csv
# 3-0.0900.csv
# 4-0.1200.csv
# 5-0.1500.csv
# 6-0.1800.csv
# 7-0.2100.csv
# 8-0.2400.csv
# 9-0.2700.csv
# 10-0.3000.csv
# 11-0.3300.csv
# 12-0.3600.csv
# 13-0.3900.csv
# 14-0.4200.csv
# 15-0.4500.csv
# 16-0.4800.csv
# 17-0.5100.csv
# 18-0.5400.csv
# 19-0.5700.csv
# 20-0.6000.csv
# 21-0.6300.csv
# 22-0.6600.csv
# 23-0.6900.csv
# 24-0.7200.csv
# 25-0.7500.csv
# 26-0.7800.csv
# 27-0.8100.csv
# 28-0.8400.csv
# 29-0.8700.csv
# 30-0.9000.csv
# 31-0.9300.csv
# 32-0.9600.csv
# 最大值字典:
# 0-0.0000: 0.6344546178343949
# 1-0.0300: 0.6464968152866242
# 2-0.0600: 0.6640127388535032
# 3-0.0900: 0.6597332802547771
# 4-0.1200: 0.6623208598726115
# 5-0.1500: 0.6713773885350318
# 6-0.1800: 0.6778463375796179
# 7-0.2100: 0.690187101910828
# 8-0.2400: 0.70421974522293
# 9-0.2700: 0.7025278662420382
# 10-0.3000: 0.7066082802547771
# 11-0.3300: 0.70203025477707
# 12-0.3600: 0.6877985668789809
# 13-0.3900: 0.6869028662420382
# 14-0.4200: 0.6875995222929936
# ...

# %%
compare_best_valid_acc(input_dir1='MLP-alpha-uniform-Cos-big/csv', input_dir2='LeNet-alpha-uniform-Cos-big/csv',output_dir='MLP-alpha-uniform-Cos/img',use_text=False)
# Out:
# 0-0.0000.csv
# 1-0.0300.csv
# 2-0.0600.csv
# 3-0.0900.csv
# 4-0.1200.csv
# 5-0.1500.csv
# 6-0.1800.csv
# 7-0.2100.csv
# 8-0.2400.csv
# 9-0.2700.csv
# 10-0.3000.csv
# 11-0.3300.csv
# 12-0.3600.csv
# 13-0.3900.csv
# 14-0.4200.csv
# 15-0.4500.csv
# 16-0.4800.csv
# 17-0.5100.csv
# 18-0.5400.csv
# 19-0.5700.csv
# 20-0.6000.csv
# 21-0.6300.csv
# 22-0.6600.csv
# 23-0.6900.csv
# 24-0.7200.csv
# 25-0.7500.csv
# 26-0.7800.csv
# 27-0.8100.csv
# 28-0.8400.csv
# 29-0.8700.csv
# 30-0.9000.csv
# 31-0.9300.csv
# 32-0.9600.csv
# 最大值字典:
# 0-0.0000: 0.5624004777070064
# 1-0.0300: 0.5509554140127388
# 2-0.0600: 0.5504578025477707
# 3-0.0900: 0.546875
# 4-0.1200: 0.5609076433121019
# 5-0.1500: 0.5602109872611465
# 6-0.1800: 0.5625995222929936
# 7-0.2100: 0.5741441082802548
# 8-0.2400: 0.5733479299363057
# 9-0.2700: 0.5793192675159236
# 10-0.3000: 0.5815087579617835
# 11-0.3300: 0.5791202229299363
# 12-0.3600: 0.57921974522293
# 13-0.3900: 0.576234076433121
# 14-0.4200: 0.5761345541401274
# ...
