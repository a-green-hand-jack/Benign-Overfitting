# %%
# %load_ext autoreload
# %autoreload 2
import os
import pandas as pd
import matplotlib.pyplot as plt
from support_code.draw_accuracy import *
import numpy as np
plt.rcParams['font.sans-serif'] = ['SimHei']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MLP

# %%
# 指定存储图像的目录
input_dir = 'MLP-alpha-uniform-Cos/csv'
output_dir = 'MLP-alpha-uniform-Cos/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

# %% [markdown]
# ## 观察整体的准确率变化

# %%
best_valid_acc(input_dir=input_dir, output_dir=output_dir, plot=True,use_text=False)
# Out:
# 1-0.0000.csv
# 2-0.1000.csv
# 3-0.2000.csv
# 4-0.3000.csv
# 5-0.4000.csv
# 6-0.5000.csv
# 7-0.6000.csv
# 8-0.7000.csv
# 9-0.8000.csv
# 10-0.9000.csv
# 11-1.0000.csv
# 最大值字典:
# 1-0.0000: 0.6438097133757962
# 2-0.1000: 0.7205414012738853
# 3-0.2000: 0.7161624203821656
# 4-0.3000: 0.6986464968152867
# 5-0.4000: 0.7173566878980892
# 6-0.5000: 0.7094944267515924
# 7-0.6000: 0.6803343949044586
# 8-0.7000: 0.6629179936305732
# 9-0.8000: 0.5668789808917197
# 10-0.9000: 0.3374800955414013
# 11-1.0000: 0.1000199044585987

# %% [markdown]
# # LeNet

# %% [markdown]
# ## 观察整体的情况

# %%
# 指定存储图像的目录
input_dir = 'LeNet-alpha-uniform-Cos/csv'
output_dir = 'LeNet-alpha-uniform-Cos/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)
best_valid_acc(input_dir=input_dir, output_dir=output_dir,plot=True,use_text=False)
# Out:
# 1-0.0000.csv
# 2-0.1000.csv
# 3-0.2000.csv
# 4-0.3000.csv
# 5-0.4000.csv
# 6-0.5000.csv
# 7-0.6000.csv
# 8-0.7000.csv
# 9-0.8000.csv
# 10-0.9000.csv
# 11-1.0000.csv
# 最大值字典:
# 1-0.0000: 0.6438097133757962
# 2-0.1000: 0.7205414012738853
# 3-0.2000: 0.7161624203821656
# 4-0.3000: 0.6986464968152867
# 5-0.4000: 0.7173566878980892
# 6-0.5000: 0.7094944267515924
# 7-0.6000: 0.6803343949044586
# 8-0.7000: 0.6629179936305732
# 9-0.8000: 0.5668789808917197
# 10-0.9000: 0.3374800955414013
# 11-1.0000: 0.1000199044585987

# %%
compare_best_valid_acc(input_dir1='MLP-alpha-uniform-Cos/csv', input_dir2='LeNet-alpha-uniform-Cos/csv',output_dir='MLP-alpha-uniform-Cos/img',use_text=False)
# Out:
# 1-0.0000.csv
# 2-0.1000.csv
# 3-0.2000.csv
# 4-0.3000.csv
# 5-0.4000.csv
# 6-0.5000.csv
# 7-0.6000.csv
# 8-0.7000.csv
# 9-0.8000.csv
# 10-0.9000.csv
# 11-1.0000.csv
# 12-1.1000.csv
# 最大值字典:
# 1-0.0000: 0.5677746815286624
# 2-0.1000: 0.5750398089171974
# 3-0.2000: 0.5818073248407644
# 4-0.3000: 0.580812101910828
# 5-0.4000: 0.5830015923566879
# 6-0.5000: 0.5751393312101911
# 7-0.6000: 0.5633957006369427
# 8-0.7000: 0.5665804140127388
# 9-0.8000: 0.5136345541401274
# 10-0.9000: 0.3775875796178344
# 11-1.0000: 0.2232285031847133
# 12-1.1000: 0.2009355095541401
# 1-0.0000.csv
# 2-0.1000.csv
# 3-0.2000.csv
# 4-0.3000.csv
# 5-0.4000.csv
# 6-0.5000.csv
# 7-0.6000.csv
# 8-0.7000.csv
# 9-0.8000.csv
# 10-0.9000.csv
# 11-1.0000.csv
# 最大值字典:
# 1-0.0000: 0.6438097133757962
# 2-0.1000: 0.7205414012738853
# 3-0.2000: 0.7161624203821656
# 4-0.3000: 0.6986464968152867
# 5-0.4000: 0.7173566878980892
# 6-0.5000: 0.7094944267515924
# 7-0.6000: 0.6803343949044586
# 8-0.7000: 0.6629179936305732
# ...
