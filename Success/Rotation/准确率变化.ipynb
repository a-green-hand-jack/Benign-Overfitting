# %%
# %load_ext autoreload
# %autoreload 2
import os
import pandas as pd
import matplotlib.pyplot as plt
from support_code.draw_accuracy import *
import numpy as np
plt.rcParams['font.sans-serif'] = ['SimHei']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MLP

# %%
# 指定存储图像的目录
input_dir = 'MLP-0-360/csv'
output_dir = 'MLP-0-360/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

# %% [markdown]
# ## 观察整体的准确率变化

# %%
best_valid_acc(input_dir=input_dir, output_dir=output_dir)
# Out:
# 1-0.0000, 10.0000.csv
# 2-0.0000, 20.0000.csv
# 3-0.0000, 30.0000.csv
# 4-0.0000, 40.0000.csv
# 5-0.0000, 50.0000.csv
# 6-0.0000, 60.0000.csv
# 7-0.0000, 70.0000.csv
# 8-0.0000, 80.0000.csv
# 9-0.0000, 90.0000.csv
# 10-0.0000, 100.0000.csv
# 11-0.0000, 110.0000.csv
# 12-0.0000, 120.0000.csv
# 13-0.0000, 130.0000.csv
# 14-0.0000, 140.0000.csv
# 15-0.0000, 150.0000.csv
# 16-0.0000, 160.0000.csv
# 17-0.0000, 170.0000.csv
# 18-0.0000, 180.0000.csv
# 19-0.0000, 190.0000.csv
# 20-0.0000, 200.0000.csv
# 21-0.0000, 210.0000.csv
# 22-0.0000, 220.0000.csv
# 23-0.0000, 230.0000.csv
# 24-0.0000, 240.0000.csv
# 25-0.0000, 250.0000.csv
# 26-0.0000, 260.0000.csv
# 27-0.0000, 270.0000.csv
# 28-0.0000, 280.0000.csv
# 29-0.0000, 290.0000.csv
# 30-0.0000, 300.0000.csv
# 31-0.0000, 310.0000.csv
# 32-0.0000, 320.0000.csv
# 33-0.0000, 330.0000.csv
# 34-0.0000, 340.0000.csv
# 35-0.0000, 350.0000.csv
# 36-0.0000, 360.0000.csv
# 最大值字典:
# 1-0.0000, 10.0000: 0.560609076433121
# 2-0.0000, 20.0000: 0.5493630573248408
# 3-0.0000, 30.0000: 0.523984872611465
# 4-0.0000, 40.0000: 0.5158240445859873
# 5-0.0000, 50.0000: 0.5081608280254777
# 6-0.0000, 60.0000: 0.4893511146496815
# 7-0.0000, 70.0000: 0.4892515923566879
# 8-0.0000, 80.0000: 0.4858678343949044
# 9-0.0000, 90.0000: 0.4819864649681528
# 10-0.0000, 100.0000: 0.4857683121019108
# 11-0.0000, 110.0000: 0.4738256369426751
# 12-0.0000, 120.0000: 0.4708399681528662
# 13-0.0000, 130.0000: 0.4712380573248407
# 14-0.0000, 140.0000: 0.4692476114649681
# 15-0.0000, 150.0000: 0.4726313694267516
# 16-0.0000, 160.0000: 0.4638734076433121
# 17-0.0000, 170.0000: 0.4569068471337579
# 18-0.0000, 180.0000: 0.4554140127388535
# 19-0.0000, 190.0000: 0.4593949044585987
# 20-0.0000, 200.0000: 0.4563097133757962
# 21-0.0000, 210.0000: 0.457703025477707
# 22-0.0000, 220.0000: 0.4497412420382166
# 23-0.0000, 230.0000: 0.4592953821656051
# 24-0.0000, 240.0000: 0.4484474522292994
# 25-0.0000, 250.0000: 0.4534235668789809
# 26-0.0000, 260.0000: 0.4535230891719745
# 27-0.0000, 270.0000: 0.4530254777070063
# 28-0.0000, 280.0000: 0.4533240445859872
# 29-0.0000, 290.0000: 0.4450636942675159
# 30-0.0000, 300.0000: 0.4598925159235669
# 31-0.0000, 310.0000: 0.4435708598726114
# 32-0.0000, 320.0000: 0.4472531847133758
# 33-0.0000, 330.0000: 0.4507364649681528
# 34-0.0000, 340.0000: 0.4462579617834395
# 35-0.0000, 350.0000: 0.4628781847133758
# 36-0.0000, 360.0000: 0.4782046178343949

# %% [markdown]
# # LeNet

# %% [markdown]
# ## 观察整体的情况

# %%
# 指定存储图像的目录
input_dir = 'LeNet-0-360/csv'
output_dir = 'LeNet-0-360/img/整体'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)
best_valid_acc(input_dir=input_dir, output_dir=output_dir)
# Out:
# 1-0.0000, 10.0000.csv
# 2-0.0000, 20.0000.csv
# 3-0.0000, 30.0000.csv
# 4-0.0000, 40.0000.csv
# 5-0.0000, 50.0000.csv
# 6-0.0000, 60.0000.csv
# 7-0.0000, 70.0000.csv
# 8-0.0000, 80.0000.csv
# 9-0.0000, 90.0000.csv
# 10-0.0000, 100.0000.csv
# 11-0.0000, 110.0000.csv
# 12-0.0000, 120.0000.csv
# 13-0.0000, 130.0000.csv
# 14-0.0000, 140.0000.csv
# 15-0.0000, 150.0000.csv
# 16-0.0000, 160.0000.csv
# 17-0.0000, 170.0000.csv
# 18-0.0000, 180.0000.csv
# 19-0.0000, 190.0000.csv
# 20-0.0000, 200.0000.csv
# 21-0.0000, 210.0000.csv
# 22-0.0000, 220.0000.csv
# 23-0.0000, 230.0000.csv
# 24-0.0000, 240.0000.csv
# 25-0.0000, 250.0000.csv
# 26-0.0000, 260.0000.csv
# 27-0.0000, 270.0000.csv
# 28-0.0000, 280.0000.csv
# 29-0.0000, 290.0000.csv
# 30-0.0000, 300.0000.csv
# 31-0.0000, 310.0000.csv
# 32-0.0000, 320.0000.csv
# 33-0.0000, 330.0000.csv
# 34-0.0000, 340.0000.csv
# 35-0.0000, 350.0000.csv
# 36-0.0000, 360.0000.csv
# 最大值字典:
# 1-0.0000, 10.0000: 0.6537619426751592
# 2-0.0000, 20.0000: 0.6466958598726115
# 3-0.0000, 30.0000: 0.6464968152866242
# 4-0.0000, 40.0000: 0.6363455414012739
# 5-0.0000, 50.0000: 0.6250995222929936
# 6-0.0000, 60.0000: 0.6165406050955414
# 7-0.0000, 70.0000: 0.5998208598726115
# 8-0.0000, 80.0000: 0.6034036624203821
# 9-0.0000, 90.0000: 0.5912619426751592
# 10-0.0000, 100.0000: 0.5718550955414012
# 11-0.0000, 110.0000: 0.5789211783439491
# 12-0.0000, 120.0000: 0.5760350318471338
# 13-0.0000, 130.0000: 0.5558320063694268
# 14-0.0000, 140.0000: 0.5619028662420382
# 15-0.0000, 150.0000: 0.5540406050955414
# 16-0.0000, 160.0000: 0.5471735668789809
# 17-0.0000, 170.0000: 0.5439888535031847
# 18-0.0000, 180.0000: 0.535828025477707
# 19-0.0000, 190.0000: 0.533937101910828
# 20-0.0000, 200.0000: 0.5319466560509554
# 21-0.0000, 210.0000: 0.541202229299363
# 22-0.0000, 220.0000: 0.5397093949044586
# 23-0.0000, 230.0000: 0.5242834394904459
# 24-0.0000, 240.0000: 0.53234474522293
# 25-0.0000, 250.0000: 0.5262738853503185
# 26-0.0000, 260.0000: 0.525577229299363
# 27-0.0000, 270.0000: 0.5337380573248408
# 28-0.0000, 280.0000: 0.5117436305732485
# 29-0.0000, 290.0000: 0.5284633757961783
# 30-0.0000, 300.0000: 0.53234474522293
# 31-0.0000, 310.0000: 0.5379179936305732
# 32-0.0000, 320.0000: 0.5398089171974523
# 33-0.0000, 330.0000: 0.5219944267515924
# 34-0.0000, 340.0000: 0.5435907643312102
# 35-0.0000, 350.0000: 0.5604100318471338
# 36-0.0000, 360.0000: 0.5809116242038217
