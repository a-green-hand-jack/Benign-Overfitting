# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%capture   # 阻止输出,便于操作
import os
import pandas as pd
import matplotlib.pyplot as plt
from support_code.draw_accuracy import *
plt.rcParams['font.sans-serif'] = ['SimHei']

# 指定存储图像的目录
input_dir = 'LeNet/csv'
output_dir = 'LeNet/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

best_valid_acc(input_dir=input_dir, output_dir=output_dir)
draw_accuracy(input_dir=input_dir, output_dir=output_dir)
draw_acc_change(input_dir=input_dir, output_dir=output_dir)
# Out:
# 最大值字典:
# 0.1: 0.2873208522796631
# 0.2: 0.3720143437385559
# 0.3: 0.4380971193313598
# 0.4: 0.5668789744377136
# 0.5: 0.6238057613372803
# 0.6: 0.6665008068084717
# 0.7: 0.7050158977508545
# 0.8: 0.7110868096351624
# 0.9: 0.6868033409118652
# 1.0: 0.643909215927124

# %%
# %%capture   # 阻止输出,便于操作
import os
import pandas as pd
import matplotlib.pyplot as plt
from support_code.draw_accuracy import *
plt.rcParams['font.sans-serif'] = ['SimHei']

# 指定存储图像的目录
input_dir = 'MLP/csv'
output_dir = 'MLP/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

best_valid_acc(input_dir=input_dir, output_dir=output_dir)
draw_accuracy(input_dir=input_dir, output_dir=output_dir)
draw_acc_change(input_dir=input_dir, output_dir=output_dir)
# Out:
# 最大值字典:
# 0.1: 0.3203622698783874
# 0.2: 0.4109275341033935
# 0.3: 0.4991042912006378
# 0.4: 0.5725517272949219
# 0.5: 0.6200239062309265
# 0.6: 0.6463972926139832
# 0.7: 0.6510748267173767
# 0.8: 0.6384354829788208
# 0.9: 0.6068869233131409
# 1.0: 0.5669785141944885
