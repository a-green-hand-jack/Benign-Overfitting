# %%
# %load_ext autoreload
# %autoreload 2
import os
import pandas as pd
import matplotlib.pyplot as plt
from support_code.draw_accuracy import *
import numpy as np
plt.rcParams['font.sans-serif'] = ['SimHei']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MLP

# %%
# 指定存储图像的目录
input_dir = 'MLP-30-30-big/csv'
output_dir = 'MLP-30-30-big/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

# %% [markdown]
# ## 观察整体的准确率变化

# %%
best_valid_acc(input_dir=input_dir, output_dir=output_dir, plot=True)
# Out:
# 2--60.0000, 60.0000.csv
# 3--59.0000, 59.0000.csv
# 4--58.0000, 58.0000.csv
# 5--57.0000, 57.0000.csv
# 6--56.0000, 56.0000.csv
# 7--55.0000, 55.0000.csv
# 8--54.0000, 54.0000.csv
# 9--53.0000, 53.0000.csv
# 10--52.0000, 52.0000.csv
# 11--51.0000, 51.0000.csv
# 12--50.0000, 50.0000.csv
# 13--49.0000, 49.0000.csv
# 14--48.0000, 48.0000.csv
# 15--47.0000, 47.0000.csv
# 16--46.0000, 46.0000.csv
# 17--45.0000, 45.0000.csv
# 18--44.0000, 44.0000.csv
# 19--43.0000, 43.0000.csv
# 20--42.0000, 42.0000.csv
# 21--41.0000, 41.0000.csv
# 22--40.0000, 40.0000.csv
# 23--39.0000, 39.0000.csv
# 24--38.0000, 38.0000.csv
# 25--37.0000, 37.0000.csv
# 26--36.0000, 36.0000.csv
# 27--35.0000, 35.0000.csv
# 28--34.0000, 34.0000.csv
# 29--33.0000, 33.0000.csv
# 30--32.0000, 32.0000.csv
# 31--31.0000, 31.0000.csv
# 32--30.0000, 30.0000.csv
# 33--29.0000, 29.0000.csv
# 34--28.0000, 28.0000.csv
# 35--27.0000, 27.0000.csv
# 36--26.0000, 26.0000.csv
# 37--25.0000, 25.0000.csv
# 38--24.0000, 24.0000.csv
# ...

# %% [markdown]
# # LeNet

# %% [markdown]
# ## 观察整体的情况

# %%
# 指定存储图像的目录
input_dir = 'LeNet-30-30-big/csv'
output_dir = 'LeNet-30-30-big/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)
best_valid_acc(input_dir=input_dir, output_dir=output_dir,plot=True)
# Out:
# 1--60.0000, 60.0000.csv
# 2--59.0000, 59.0000.csv
# 3--58.0000, 58.0000.csv
# 4--57.0000, 57.0000.csv
# 5--56.0000, 56.0000.csv
# 6--55.0000, 55.0000.csv
# 7--54.0000, 54.0000.csv
# 8--53.0000, 53.0000.csv
# 9--52.0000, 52.0000.csv
# 10--51.0000, 51.0000.csv
# 11--50.0000, 50.0000.csv
# 12--49.0000, 49.0000.csv
# 13--48.0000, 48.0000.csv
# 14--47.0000, 47.0000.csv
# 15--46.0000, 46.0000.csv
# 16--45.0000, 45.0000.csv
# 17--44.0000, 44.0000.csv
# 18--43.0000, 43.0000.csv
# 19--42.0000, 42.0000.csv
# 20--41.0000, 41.0000.csv
# 21--40.0000, 40.0000.csv
# 22--39.0000, 39.0000.csv
# 23--38.0000, 38.0000.csv
# 24--37.0000, 37.0000.csv
# 25--36.0000, 36.0000.csv
# 26--35.0000, 35.0000.csv
# 27--34.0000, 34.0000.csv
# 28--33.0000, 33.0000.csv
# 29--32.0000, 32.0000.csv
# 30--31.0000, 31.0000.csv
# 31--30.0000, 30.0000.csv
# 32--29.0000, 29.0000.csv
# 33--28.0000, 28.0000.csv
# 34--27.0000, 27.0000.csv
# 35--26.0000, 26.0000.csv
# 36--25.0000, 25.0000.csv
# 37--24.0000, 24.0000.csv
# ...
