# %%
# %load_ext autoreload
# %autoreload 2
import os
import pandas as pd
import matplotlib.pyplot as plt
from support_code.draw_accuracy import *
import numpy as np
plt.rcParams['font.sans-serif'] = ['SimHei']

# %% [markdown]
# # MLP

# %%
# 指定存储图像的目录
input_dir = 'MLP-30-30/csv'
output_dir = 'MLP-30-30/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

# %% [markdown]
# ## 观察整体的准确率变化

# %%
best_valid_acc(input_dir=input_dir, output_dir=output_dir, plot=True)
# Out:
# 2--30.0000, 30.0000.csv
# 3--29.0000, 29.0000.csv
# 4--28.0000, 28.0000.csv
# 5--27.0000, 27.0000.csv
# 6--26.0000, 26.0000.csv
# 7--25.0000, 25.0000.csv
# 8--24.0000, 24.0000.csv
# 9--23.0000, 23.0000.csv
# 10--22.0000, 22.0000.csv
# 11--21.0000, 21.0000.csv
# 12--20.0000, 20.0000.csv
# 13--19.0000, 19.0000.csv
# 14--18.0000, 18.0000.csv
# 15--17.0000, 17.0000.csv
# 16--16.0000, 16.0000.csv
# 17--15.0000, 15.0000.csv
# 18--14.0000, 14.0000.csv
# 19--13.0000, 13.0000.csv
# 20--12.0000, 12.0000.csv
# 21--11.0000, 11.0000.csv
# 22--10.0000, 10.0000.csv
# 23--9.0000, 9.0000.csv
# 24--8.0000, 8.0000.csv
# 25--7.0000, 7.0000.csv
# 26--6.0000, 6.0000.csv
# 27--5.0000, 5.0000.csv
# 28--4.0000, 4.0000.csv
# 29--3.0000, 3.0000.csv
# 30--2.0000, 2.0000.csv
# 31--1.0000, 1.0000.csv
# 32-0.0000, 0.0000.csv
# 最大值字典:
# 2--30.0000, 30.0000: 0.5629976114649682
# 3--29.0000, 29.0000: 0.5531449044585988
# 4--28.0000, 28.0000: 0.5510549363057324
# 5--27.0000, 27.0000: 0.5613057324840764
# 6--26.0000, 26.0000: 0.558718152866242
# 7--25.0000, 25.0000: 0.5512539808917197
# 8--24.0000, 24.0000: 0.5573248407643312
# 9--23.0000, 23.0000: 0.5573248407643312
# 10--22.0000, 22.0000: 0.5580214968152867
# 11--21.0000, 21.0000: 0.559812898089172
# 12--20.0000, 20.0000: 0.5573248407643312
# 13--19.0000, 19.0000: 0.5629976114649682
# 14--18.0000, 18.0000: 0.5629976114649682
# 15--17.0000, 17.0000: 0.5604100318471338
# 16--16.0000, 16.0000: 0.5640923566878981
# 17--15.0000, 15.0000: 0.5707603503184714
# 18--14.0000, 14.0000: 0.5674761146496815
# 19--13.0000, 13.0000: 0.5719546178343949
# 20--12.0000, 12.0000: 0.569765127388535
# 21--11.0000, 11.0000: 0.5684713375796179
# 22--10.0000, 10.0000: 0.5731488853503185
# 23--9.0000, 9.0000: 0.578125
# 24--8.0000, 8.0000: 0.5709593949044586
# 25--7.0000, 7.0000: 0.569765127388535
# 26--6.0000, 6.0000: 0.5759355095541401
# 27--5.0000, 5.0000: 0.5668789808917197
# 28--4.0000, 4.0000: 0.5706608280254777
# 29--3.0000, 3.0000: 0.5734474522292994
# 30--2.0000, 2.0000: 0.5596138535031847
# 31--1.0000, 1.0000: 0.5671775477707006
# 32-0.0000, 0.0000: 0.5636942675159236

# %% [markdown]
# # LeNet

# %% [markdown]
# ## 观察整体的情况

# %%
# 指定存储图像的目录
input_dir = 'LeNet-30-30/csv'
output_dir = 'LeNet-30-30/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)
best_valid_acc(input_dir=input_dir, output_dir=output_dir,plot=True)
# Out:
# 1--30.0000, 30.0000.csv
# 2--29.0000, 29.0000.csv
# 3--28.0000, 28.0000.csv
# 4--27.0000, 27.0000.csv
# 5--26.0000, 26.0000.csv
# 6--25.0000, 25.0000.csv
# 7--24.0000, 24.0000.csv
# 8--23.0000, 23.0000.csv
# 9--22.0000, 22.0000.csv
# 10--21.0000, 21.0000.csv
# 11--20.0000, 20.0000.csv
# 12--19.0000, 19.0000.csv
# 13--18.0000, 18.0000.csv
# 14--17.0000, 17.0000.csv
# 15--16.0000, 16.0000.csv
# 16--15.0000, 15.0000.csv
# 17--14.0000, 14.0000.csv
# 18--13.0000, 13.0000.csv
# 19--12.0000, 12.0000.csv
# 20--11.0000, 11.0000.csv
# 21--10.0000, 10.0000.csv
# 22--9.0000, 9.0000.csv
# 23--8.0000, 8.0000.csv
# 24--7.0000, 7.0000.csv
# 25--6.0000, 6.0000.csv
# 26--5.0000, 5.0000.csv
# 27--4.0000, 4.0000.csv
# 28--3.0000, 3.0000.csv
# 29--2.0000, 2.0000.csv
# 30--1.0000, 1.0000.csv
# 31-0.0000, 0.0000.csv
# 最大值字典:
# 1--30.0000, 30.0000: 0.6797372611464968
# 2--29.0000, 29.0000: 0.6742635350318471
# 3--28.0000, 28.0000: 0.6898885350318471
# 4--27.0000, 27.0000: 0.6755573248407644
# 5--26.0000, 26.0000: 0.6952627388535032
# 6--25.0000, 25.0000: 0.6792396496815286
# 7--24.0000, 24.0000: 0.6816281847133758
# 8--23.0000, 23.0000: 0.6681926751592356
# 9--22.0000, 22.0000: 0.6896894904458599
# 10--21.0000, 21.0000: 0.679140127388535
# 11--20.0000, 20.0000: 0.6928742038216561
# 12--19.0000, 19.0000: 0.6688893312101911
# 13--18.0000, 18.0000: 0.6770501592356688
# 14--17.0000, 17.0000: 0.6800358280254777
# 15--16.0000, 16.0000: 0.6835191082802548
# 16--15.0000, 15.0000: 0.6809315286624203
# 17--14.0000, 14.0000: 0.6913813694267515
# 18--13.0000, 13.0000: 0.6799363057324841
# 19--12.0000, 12.0000: 0.681827229299363
# 20--11.0000, 11.0000: 0.673765923566879
# 21--10.0000, 10.0000: 0.6780453821656051
# 22--9.0000, 9.0000: 0.6713773885350318
# 23--8.0000, 8.0000: 0.6825238853503185
# 24--7.0000, 7.0000: 0.6652070063694268
# 25--6.0000, 6.0000: 0.6674960191082803
# 26--5.0000, 5.0000: 0.650577229299363
# 27--4.0000, 4.0000: 0.6506767515923567
# 28--3.0000, 3.0000: 0.6480891719745223
# 29--2.0000, 2.0000: 0.6496815286624203
# 30--1.0000, 1.0000: 0.6438097133757962
# 31-0.0000, 0.0000: 0.6553542993630573
