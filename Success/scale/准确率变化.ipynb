# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%capture   # 阻止输出,便于操作
import os
import pandas as pd
import matplotlib.pyplot as plt
from support_code.draw_accuracy import *
plt.rcParams['font.sans-serif'] = ['SimHei']

# 指定存储图像的目录
input_dir = 'LeNet-0921-1917/csv'
output_dir = 'LeNet-0921-1917/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

best_valid_acc(input_dir=input_dir, output_dir=output_dir)
draw_accuracy(input_dir=input_dir, output_dir=output_dir)
draw_acc_change(input_dir=input_dir, output_dir=output_dir)
# Out:
# UsageError: unrecognized arguments: 阻止输出,便于操作

# %%
# %%capture   # 阻止输出,便于操作
import os
import pandas as pd
import matplotlib.pyplot as plt
from support_code.draw_accuracy import *
plt.rcParams['font.sans-serif'] = ['SimHei']

# 指定存储图像的目录
input_dir = 'MLP-0921-1905/csv'
output_dir = 'MLP-0921-1905/img'
# 如果目录不存在，创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(input_dir):
    os.makedirs(input_dir)

best_valid_acc(input_dir=input_dir, output_dir=output_dir)
draw_accuracy(input_dir=input_dir, output_dir=output_dir)
draw_acc_change(input_dir=input_dir, output_dir=output_dir)
# Out:
# 最大值字典:
# 0.1: 0.3169785141944885
# 0.2: 0.3715167343616485
# 0.3: 0.4297372698783874
# 0.4: 0.4876592457294464
# 0.5: 0.5389131903648376
# 0.6: 0.5735469460487366
# 0.7: 0.5931528806686401
# 0.8: 0.5927547812461853
# 0.9: 0.5649880766868591
# 1.0: 0.534335196018219
