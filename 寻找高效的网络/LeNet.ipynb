# %%
# 加载各种库
import torch
import os
import pickle
import torch.nn as nn
from torchvision.transforms import ToTensor
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
import torchvision
from torchvision.datasets import CIFAR10
import numpy as np
import random
from torch.optim.lr_scheduler import CosineAnnealingLR  # 实现cos函数式的变化
# 加载支持函数和类
from support_code.load_dataset import get_data_loader
from support_code.LeNet import LeNet
# 设置设备和种子
device_cuda = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# 设置随机种子
seed = 10  # 你可以选择任何整数作为种子值

# 设置PyTorch随机种子
torch.manual_seed(seed)

# 设置CUDA随机种子（如果使用GPU）
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# 设置Numpy随机种子
np.random.seed(seed)

# 设置Python随机种子
random.seed(seed)

# %%
def get_scale(scale, writer,  
            device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu"), train_loader=None, valid_loader=None, test_loader=None, 
            channel=3,
            num_classes=10,
            im_size=(32, 32),
            # 可能需要的超参数
            momentum = 0.9,
            weight_decay = 0.0005,
            initial_lr = 0.1,
            num_epochs = 100,
            save_dir = "logs-LeNet-0913"):

  # -------------------------------------------------创建模型实例并将其移至 GPU -----------------------------------------------------
  model = LeNet(channel=channel, num_classes=num_classes)
  model.to(device)
  # 确保文件夹存在，如果不存在则创建它
  os.makedirs(save_dir, exist_ok=True)
  # 定义损失函数/优化器/学习率
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(model.parameters(), lr=initial_lr, weight_decay=weight_decay, momentum=momentum)
  scheduler = CosineAnnealingLR(optimizer, T_max=10)

  # 记录训练过程中的准确率和损失
  tag_loss = "train_loss_{}".format(scale)
  tag_acc = "train_accuracy_{}".format(scale)

  # 训练循环...
  final_train_loss = 0
  final_train_acc = 0
  best_train_acc = 0.0  # 用于跟踪一个scale也就是一个完整的train的过程中的最佳准确率

  # 验证步骤...
  # 记录验证的次数
  valid_correct = 0
  valid_total = 0
  best_valid_acc = 0.0
  val_loss = "val_loss_{}".format(scale)
  val_acc = "val_accuracy_{}".format(scale)
  acc = 0.0
  loss = 1.0

  for epoch in range(num_epochs):

    # ----------------------------首先是训练过程----------------------------
    train_correct = 0
    train_total = 0
    for batch_idx, (imgs, targets) in enumerate(train_loader):
      imgs, targets = imgs.to(device), targets.to(device)
      outputs = model(imgs)
      loss = criterion(outputs, targets)
      _, predicted = torch.max(outputs, 1)
      train_total += targets.size(0)
      train_correct += (predicted == targets).sum().item()
      optimizer.zero_grad() # W_new = W_old + \gamma \times \deta W_old,这里相当于先要求\gamma 为零矩阵
      loss.backward()   # 使用backward得到了\deta W_old
      optimizer.step()  # 选择合适的\gamma 得到了W_new
      scheduler.step()  # \gamma 事实上是一个依赖于learning_rate的一个矩阵函数,这里更新了learning_rate,而且learning_rate的更新是依赖于epoch的

    acc = train_correct / train_total
    writer.add_scalar(tag_loss, loss.item(), epoch)
    writer.add_scalar(tag_acc, acc, epoch)
    # 更新模型权重并记录到Tensorboard
    for name, param in model.named_parameters():
      writer.add_histogram(name, param.clone().cpu().data.numpy(), epoch)
    final_train_acc = train_correct / train_total
    # 更新最佳准确率,以及对应的loss
    if final_train_acc >= best_train_acc:
      best_train_acc = final_train_acc
      best_train_loss = loss.item()
    final_train_loss = loss.item()
    print("Epoch [{}/{}], Final Train Loss: {:.4f}, Final Train Accuracy: {:.2f}%, Best Train Accuracy: {:.2f}, Loss to best acc:{:.2f}%".format(epoch+1, num_epochs, final_train_loss, final_train_acc * 100, best_train_acc * 100, best_train_loss),"\n")
    # 记录学习率(learning_rate)的更新情况
    writer.add_scalar("learning_rate",optimizer.param_groups[0]['lr'])

    # -------------------------然后进入了验证步骤---------------------------------
    for batch_idx, (imgs, targets) in enumerate(valid_loader):
      imgs, targets = imgs.to(device), targets.to(device)
      outputs = model(imgs)
      loss = criterion(outputs, targets)
      _, predicted = torch.max(outputs, 1)
      valid_total += targets.size(0)
      valid_correct += (predicted == targets).sum().item()
      acc = valid_correct / valid_total

    writer.add_scalar(val_loss, loss.item(), epoch)
    writer.add_scalar(val_acc, acc, epoch)
    # 记录valid中的最终情况
    final_valid_acc = acc
    final_valid_loss = loss
    # 更新最佳准确率,以及对应的loss
    if final_valid_acc >= best_valid_acc:
      best_valid_acc = final_valid_acc
      best_valid_loss = loss.item()
    final_valid_loss = loss.item()
    print("Epoch [{}/{}], Final Valid Loss: {:.4f}, Final Valid Accuracy: {:.2f}%, Best Valid Accuracy: {:.2f}%, Loss to best Valid accuracy:{:.2f}".format(epoch+1, num_epochs, final_valid_loss, final_valid_acc * 100, best_valid_acc * 100, best_valid_loss),"\n")


  # 记录train过程中的最终情况
  writer.add_scalar("final_train_loss", final_train_loss, scale)
  writer.add_scalar("final_train_acc", final_train_acc, scale)
  writer.add_scalar("best_train_acc", best_train_acc, scale)
  writer.add_scalar("best_train_loss", best_train_loss, scale)
  # 记录valid的最终情况
  writer.add_scalar("final_valid_loss", final_valid_loss, scale)
  writer.add_scalar("final_valid_acc", final_valid_acc, scale)
  writer.add_scalar("best_valid_acc", best_valid_acc, scale)
  writer.add_scalar("best_valid_loss", best_valid_loss, scale)

  # 保存模型参数
  # 构建完整的文件路径
  filename = os.path.join(save_dir, "scale={}.pth".format(scale))
  # 保存模型
  torch.save(model.state_dict(), filename)
  print("模型参数已保存为{}".format(filename), '\n')

  # 完成各种工作，记录结果...
  normal_dict = {
      "训练的模型的保留路径": filename,
      "在测试集中的最终损失": final_valid_loss,
      "在测试集中的最终损失":best_valid_loss,
      "在测试集中的最终准确率": final_valid_acc,
      "在测试集中的最佳准确率": best_valid_acc,
      "在训练集中的最终准确率": final_train_acc,
      "在训练集中的最佳准确率": best_train_acc,
      "在训练集中的最终损失": final_train_loss,
      "在训练集中的最佳损失":best_train_loss
  }
  return normal_dict

# %%
# 定义初始的scale范围
scale_min = 0.1
scale_max = 0.9
scale_list = [round(x * 0.1, 1) for x in range(int(scale_min * 10), int(scale_max * 10) + 1)]
# print(scale_list)
my_list = []
# 添加tensorboard
writer_new = SummaryWriter("logs-LeNet-0913")

for scale in scale_list:
  train_loader, valid_loader, test_loader = get_data_loader(scale, valid_scale=0.1)
  dic = {}
  print("--------------------开始scale={}的情况---------------------".format(scale), "\n")
  dic['scale={}'.format(scale)] = get_scale(scale=scale, writer=writer_new, train_loader=train_loader, valid_loader=valid_loader,save_dir = "logs-LeNet-0913", num_epochs=200)
  print(dic['scale={}'.format(scale)])
  my_list.append(dic)

writer_new.close()

# -------------------------------------保存列表,因为我发现notebook不是很可靠-----------------------------
# 指定保存文件的文件夹和文件名
folder_path = "logs-LeNet-0913"
file_name = "dic_scale_512.pkl"

# 确保文件夹存在，如果不存在则创建它
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# 组合文件夹路径和文件名
dic_file_path = os.path.join(folder_path, file_name)

with open(dic_file_path, "wb") as file:
  pickle.dump(dic, file=file)

print("字典保存在文件中")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# --------------------开始scale=0.1的情况---------------------
#
# Epoch [1/200], Final Train Loss: 2.1605, Final Train Accuracy: 16.21%, Best Train Accuracy: 16.21, Loss to best acc:2.16%
#
# Epoch [1/200], Final Valid Loss: 2.2354, Final Valid Accuracy: 16.00%, Best Valid Accuracy: 16.00%, Loss to best Valid accuracy:2.24
#
# Epoch [2/200], Final Train Loss: 2.0804, Final Train Accuracy: 20.26%, Best Train Accuracy: 20.26, Loss to best acc:2.08%
#
# Epoch [2/200], Final Valid Loss: 2.2882, Final Valid Accuracy: 14.95%, Best Valid Accuracy: 16.00%, Loss to best Valid accuracy:2.24
#
# Epoch [3/200], Final Train Loss: 2.0522, Final Train Accuracy: 22.37%, Best Train Accuracy: 22.37, Loss to best acc:2.05%
#
# Epoch [3/200], Final Valid Loss: 2.2383, Final Valid Accuracy: 14.97%, Best Valid Accuracy: 16.00%, Loss to best Valid accuracy:2.24
#
# Epoch [4/200], Final Train Loss: 1.9623, Final Train Accuracy: 24.29%, Best Train Accuracy: 24.29, Loss to best acc:1.96%
#
# Epoch [4/200], Final Valid Loss: 2.2540, Final Valid Accuracy: 15.30%, Best Valid Accuracy: 16.00%, Loss to best Valid accuracy:2.24
#
# Epoch [5/200], Final Train Loss: 2.0375, Final Train Accuracy: 25.13%, Best Train Accuracy: 25.13, Loss to best acc:2.04%
#
# Epoch [5/200], Final Valid Loss: 2.2529, Final Valid Accuracy: 15.24%, Best Valid Accuracy: 16.00%, Loss to best Valid accuracy:2.24
#
# Epoch [6/200], Final Train Loss: 1.9956, Final Train Accuracy: 25.27%, Best Train Accuracy: 25.27, Loss to best acc:2.00%
#
# Epoch [6/200], Final Valid Loss: 2.2690, Final Valid Accuracy: 14.95%, Best Valid Accuracy: 16.00%, Loss to best Valid accuracy:2.24
#
# Epoch [7/200], Final Train Loss: 2.0339, Final Train Accuracy: 26.16%, Best Train Accuracy: 26.16, Loss to best acc:2.03%
#
# Epoch [7/200], Final Valid Loss: 2.1603, Final Valid Accuracy: 15.44%, Best Valid Accuracy: 16.00%, Loss to best Valid accuracy:2.24
#
# Epoch [8/200], Final Train Loss: 2.0548, Final Train Accuracy: 26.33%, Best Train Accuracy: 26.33, Loss to best acc:2.05%
#
# Epoch [8/200], Final Valid Loss: 2.1869, Final Valid Accuracy: 16.01%, Best Valid Accuracy: 16.01%, Loss to best Valid accuracy:2.19
#
# Epoch [9/200], Final Train Loss: 2.0374, Final Train Accuracy: 27.11%, Best Train Accuracy: 27.11, Loss to best acc:2.04%
#
# Epoch [9/200], Final Valid Loss: 2.1929, Final Valid Accuracy: 16.13%, Best Valid Accuracy: 16.13%, Loss to best Valid accuracy:2.19
#
# Epoch [10/200], Final Train Loss: 1.8958, Final Train Accuracy: 27.55%, Best Train Accuracy: 27.55, Loss to best acc:1.90%
#
# Epoch [10/200], Final Valid Loss: 2.1851, Final Valid Accuracy: 16.18%, Best Valid Accuracy: 16.18%, Loss to best Valid accuracy:2.19
#
# Epoch [11/200], Final Train Loss: 1.9142, Final Train Accuracy: 27.13%, Best Train Accuracy: 27.55, Loss to best acc:1.90%
#
# Epoch [11/200], Final Valid Loss: 2.2504, Final Valid Accuracy: 16.35%, Best Valid Accuracy: 16.35%, Loss to best Valid accuracy:2.25
#
# Epoch [12/200], Final Train Loss: 1.9130, Final Train Accuracy: 28.94%, Best Train Accuracy: 28.94, Loss to best acc:1.91%
#
# Epoch [12/200], Final Valid Loss: 2.2543, Final Valid Accuracy: 16.30%, Best Valid Accuracy: 16.35%, Loss to best Valid accuracy:2.25
#
# Epoch [13/200], Final Train Loss: 1.9745, Final Train Accuracy: 28.25%, Best Train Accuracy: 28.94, Loss to best acc:1.91%
#
# Epoch [13/200], Final Valid Loss: 2.1762, Final Valid Accuracy: 16.49%, Best Valid Accuracy: 16.49%, Loss to best Valid accuracy:2.18
#
# Epoch [14/200], Final Train Loss: 1.9064, Final Train Accuracy: 27.35%, Best Train Accuracy: 28.94, Loss to best acc:1.91%
#
# Epoch [14/200], Final Valid Loss: 2.1721, Final Valid Accuracy: 16.56%, Best Valid Accuracy: 16.56%, Loss to best Valid accuracy:2.17
#
# Epoch [15/200], Final Train Loss: 1.9955, Final Train Accuracy: 29.14%, Best Train Accuracy: 29.14, Loss to best acc:2.00%
#
# Epoch [15/200], Final Valid Loss: 2.1496, Final Valid Accuracy: 16.64%, Best Valid Accuracy: 16.64%, Loss to best Valid accuracy:2.15
#
# Epoch [16/200], Final Train Loss: 1.8807, Final Train Accuracy: 28.89%, Best Train Accuracy: 29.14, Loss to best acc:2.00%
#
# Epoch [16/200], Final Valid Loss: 2.1428, Final Valid Accuracy: 16.91%, Best Valid Accuracy: 16.91%, Loss to best Valid accuracy:2.14
#
# Epoch [17/200], Final Train Loss: 1.8843, Final Train Accuracy: 29.37%, Best Train Accuracy: 29.37, Loss to best acc:1.88%
#
# Epoch [17/200], Final Valid Loss: 2.1458, Final Valid Accuracy: 17.15%, Best Valid Accuracy: 17.15%, Loss to best Valid accuracy:2.15
#
# Epoch [18/200], Final Train Loss: 1.9345, Final Train Accuracy: 30.00%, Best Train Accuracy: 30.00, Loss to best acc:1.93%
#
# Epoch [18/200], Final Valid Loss: 2.3080, Final Valid Accuracy: 17.19%, Best Valid Accuracy: 17.19%, Loss to best Valid accuracy:2.31
#
# Epoch [19/200], Final Train Loss: 1.8736, Final Train Accuracy: 30.00%, Best Train Accuracy: 30.00, Loss to best acc:1.87%
#
# Epoch [19/200], Final Valid Loss: 2.3118, Final Valid Accuracy: 17.13%, Best Valid Accuracy: 17.19%, Loss to best Valid accuracy:2.31
#
# Epoch [20/200], Final Train Loss: 1.8693, Final Train Accuracy: 30.27%, Best Train Accuracy: 30.27, Loss to best acc:1.87%
#
, Best Train Accuracy: 73.58, Loss to best acc:0.79%
#
# Epoch [189/200], Final Valid Loss: 2.2805, Final Valid Accuracy: 23.21%, Best Valid Accuracy: 23.21%, Loss to best Valid accuracy:2.28
#
# Epoch [190/200], Final Train Loss: 0.7908, Final Train Accuracy: 72.24%, Best Train Accuracy: 73.58, Loss to best acc:0.79%
#
# Epoch [190/200], Final Valid Loss: 2.3202, Final Valid Accuracy: 23.22%, Best Valid Accuracy: 23.22%, Loss to best Valid accuracy:2.32
#
# Epoch [191/200], Final Train Loss: 0.8630, Final Train Accuracy: 73.68%, Best Train Accuracy: 73.68, Loss to best acc:0.86%
#
# Epoch [191/200], Final Valid Loss: 2.2398, Final Valid Accuracy: 23.25%, Best Valid Accuracy: 23.25%, Loss to best Valid accuracy:2.24
#
# Epoch [192/200], Final Train Loss: 0.7869, Final Train Accuracy: 73.61%, Best Train Accuracy: 73.68, Loss to best acc:0.86%
#
# Epoch [192/200], Final Valid Loss: 2.2531, Final Valid Accuracy: 23.26%, Best Valid Accuracy: 23.26%, Loss to best Valid accuracy:2.25
#
# Epoch [193/200], Final Train Loss: 0.8268, Final Train Accuracy: 73.04%, Best Train Accuracy: 73.68, Loss to best acc:0.86%
#
# Epoch [193/200], Final Valid Loss: 2.2853, Final Valid Accuracy: 23.28%, Best Valid Accuracy: 23.28%, Loss to best Valid accuracy:2.29
#
# Epoch [194/200], Final Train Loss: 0.8485, Final Train Accuracy: 73.35%, Best Train Accuracy: 73.68, Loss to best acc:0.86%
#
# Epoch [194/200], Final Valid Loss: 2.4483, Final Valid Accuracy: 23.28%, Best Valid Accuracy: 23.28%, Loss to best Valid accuracy:2.29
#
# Epoch [195/200], Final Train Loss: 0.8916, Final Train Accuracy: 73.31%, Best Train Accuracy: 73.68, Loss to best acc:0.86%
#
# Epoch [195/200], Final Valid Loss: 2.4286, Final Valid Accuracy: 23.29%, Best Valid Accuracy: 23.29%, Loss to best Valid accuracy:2.43
#
# Epoch [196/200], Final Train Loss: 0.8292, Final Train Accuracy: 72.55%, Best Train Accuracy: 73.68, Loss to best acc:0.86%
#
# Epoch [196/200], Final Valid Loss: 2.2669, Final Valid Accuracy: 23.30%, Best Valid Accuracy: 23.30%, Loss to best Valid accuracy:2.27
#
# Epoch [197/200], Final Train Loss: 0.8384, Final Train Accuracy: 73.20%, Best Train Accuracy: 73.68, Loss to best acc:0.86%
#
# Epoch [197/200], Final Valid Loss: 2.7739, Final Valid Accuracy: 23.27%, Best Valid Accuracy: 23.30%, Loss to best Valid accuracy:2.27
#
# Epoch [198/200], Final Train Loss: 0.8609, Final Train Accuracy: 73.27%, Best Train Accuracy: 73.68, Loss to best acc:0.86%
#
# Epoch [198/200], Final Valid Loss: 2.5429, Final Valid Accuracy: 23.27%, Best Valid Accuracy: 23.30%, Loss to best Valid accuracy:2.27
#
# Epoch [199/200], Final Train Loss: 0.8189, Final Train Accuracy: 71.78%, Best Train Accuracy: 73.68, Loss to best acc:0.86%
#
# Epoch [199/200], Final Valid Loss: 2.4057, Final Valid Accuracy: 23.27%, Best Valid Accuracy: 23.30%, Loss to best Valid accuracy:2.27
#
# Epoch [200/200], Final Train Loss: 0.8514, Final Train Accuracy: 73.35%, Best Train Accuracy: 73.68, Loss to best acc:0.86%
#
# Epoch [200/200], Final Valid Loss: 2.3330, Final Valid Accuracy: 23.29%, Best Valid Accuracy: 23.30%, Loss to best Valid accuracy:2.27
#
# 模型参数已保存为logs-LeNet-0913\scale=0.9.pth
#
# {'训练的模型的保留路径': 'logs-LeNet-0913\\scale=0.9.pth', '在测试集中的最终损失': 2.266911506652832, '在测试集中的最终准确率': 0.232885, '在测试集中的最佳准确率': 0.2329795918367347, '在训练集中的最终准确率': 0.73346, '在训练集中的最佳准确率': 0.73682, '在训练集中的最终损失': 0.8513621091842651, '在训练集中的最佳损失': 0.8630187511444092}
# 字典保存在文件中
