# %% [markdown]
# # 提高模型准确率
#
# 之前的模型不知道为啥,准确率都低的吓人,这次采用如下的配置,希望可以有一点提高:
#
# 1. MLP,调用support_code里面的MLP
# 2. 依然采用SDG
# 3. 采用CosineAnnealingLR动态调整学习率

# %%
# 加载各种库
import torch
import os
import torch.nn as nn
from torchvision.transforms import ToTensor
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
import torchvision
from torchvision.datasets import CIFAR10
import numpy as np
import random
from torch.optim.lr_scheduler import CosineAnnealingLR  # 实现cos函数式的变化
# 加载支持函数和类
from support_code.load_dataset import get_data_loader
from support_code.MLP import MLP
# 设置设备和种子
device_cuda = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# 设置随机种子
seed = 10  # 你可以选择任何整数作为种子值

# 设置PyTorch随机种子
torch.manual_seed(seed)

# 设置CUDA随机种子（如果使用GPU）
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# 设置Numpy随机种子
np.random.seed(seed)

# 设置Python随机种子
random.seed(seed)

# %%
def get_scale(scale, writer,  
            device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu"), train_loader=None, valid_loader=None, test_loader=None, 
            channel=3,
            num_classes=10,
            im_size=(32, 32),
            # 可能需要的超参数
            momentum = 0.9,
            weight_decay = 0.0005,
            initial_lr = 0.1,
            num_epochs = 100):

  # -------------------------------------------------创建模型实例并将其移至 GPU -----------------------------------------------------
  model = MLP(channel=channel, num_classes=num_classes, im_size=im_size)
  model.to(device)
  # 定义文件夹路径
  save_dir = "保存模型-MLP-09013"

  # 确保文件夹存在，如果不存在则创建它
  os.makedirs(save_dir, exist_ok=True)
  # 定义损失函数/优化器/学习率
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(model.parameters(), lr=initial_lr, weight_decay=weight_decay, momentum=momentum)
  scheduler = CosineAnnealingLR(optimizer, T_max=10)

  # 记录训练过程中的准确率和损失
  tag_loss = "train_loss_{}".format(scale)
  tag_acc = "train_accuracy_{}".format(scale)

  # 训练循环...
  final_train_loss = 0
  final_train_acc = 0
  best_train_acc = 0.0  # 用于跟踪一个scale也就是一个完整的train的过程中的最佳准确率

  # 验证步骤...
  # 记录验证的次数
  valid_correct = 0
  valid_total = 0
  best_valid_acc = 0.0
  val_loss = "val_loss_{}".format(scale)
  val_acc = "val_accuracy_{}".format(scale)
  acc = 0.0
  loss = 1.0

  for epoch in range(num_epochs):

    # ----------------------------首先是训练过程----------------------------
    train_correct = 0
    train_total = 0
    for batch_idx, (imgs, targets) in enumerate(train_loader):
      imgs, targets = imgs.to(device), targets.to(device)
      outputs = model(imgs)
      loss = criterion(outputs, targets)
      _, predicted = torch.max(outputs, 1)
      train_total += targets.size(0)
      train_correct += (predicted == targets).sum().item()
      optimizer.zero_grad() # W_new = W_old + \gamma \times \deta W_old,这里相当于先要求\gamma 为零矩阵
      loss.backward()   # 使用backward得到了\deta W_old
      optimizer.step()  # 选择合适的\gamma 得到了W_new
      scheduler.step()  # \gamma 事实上是一个依赖于learning_rate的一个矩阵函数,这里更新了learning_rate,而且learning_rate的更新是依赖于epoch的

    acc = train_correct / train_total
    writer.add_scalar(tag_loss, loss.item(), epoch)
    writer.add_scalar(tag_acc, acc, epoch)
    # 更新模型权重并记录到Tensorboard
    for name, param in model.named_parameters():
      writer.add_histogram(name, param.clone().cpu().data.numpy(), epoch)
    final_train_acc = train_correct / train_total
    # 更新最佳准确率,以及对应的loss
    if final_train_acc >= best_train_acc:
      best_train_acc = final_train_acc
      best_train_loss = loss.item()
    final_train_loss = loss.item()
    print("Epoch [{}/{}], Final Train Loss: {:.4f}, Final Train Accuracy: {:.2f}%, Best Train Accuracy: {:.2f}, Loss to best acc:{:.2f}%".format(epoch+1, num_epochs, final_train_loss, final_train_acc * 100, best_train_acc * 100, best_train_loss),"\n")
    # 记录学习率(learning_rate)的更新情况
    writer.add_scalar("learning_rate",optimizer.param_groups[0]['lr'])

    # -------------------------然后进入了验证步骤---------------------------------
    for batch_idx, (imgs, targets) in enumerate(valid_loader):
      imgs, targets = imgs.to(device), targets.to(device)
      outputs = model(imgs)
      loss = criterion(outputs, targets)
      _, predicted = torch.max(outputs, 1)
      valid_total += targets.size(0)
      valid_correct += (predicted == targets).sum().item()
      acc = valid_correct / valid_total

    writer.add_scalar(val_loss, loss.item(), epoch)
    writer.add_scalar(val_acc, acc, epoch)
    # 记录valid中的最终情况
    final_valid_acc = acc
    final_valid_loss = loss
    # 更新最佳准确率,以及对应的loss
    if final_valid_acc >= best_valid_acc:
      best_valid_acc = final_valid_acc
      best_valid_loss = loss.item()
    final_valid_loss = loss.item()
    print("Epoch [{}/{}], Final Valid Loss: {:.4f}, Final Valid Accuracy: {:.2f}%, Best Valid Accuracy: {:.2f}%, Loss to best Valid accuracy:{:.2f}".format(epoch+1, num_epochs, final_valid_loss, final_valid_acc * 100, best_valid_acc * 100, best_valid_loss),"\n")


  # 记录train过程中的最终情况
  writer.add_scalar("final_train_loss", final_train_loss, scale)
  writer.add_scalar("final_train_acc", final_train_acc, scale)
  writer.add_scalar("best_train_acc", best_train_acc, scale)
  writer.add_scalar("best_train_loss", best_train_loss, scale)
  # 记录valid的最终情况
  writer.add_scalar("final_valid_loss", final_valid_loss, scale)
  writer.add_scalar("final_valid_acc", final_valid_acc, scale)
  writer.add_scalar("best_valid_acc", best_valid_acc, scale)
  writer.add_scalar("best_valid_loss", best_valid_loss, scale)

  # 保存模型参数
  # 构建完整的文件路径
  filename = os.path.join(save_dir, "scale={}.pth".format(scale))
  # 保存模型
  torch.save(model.state_dict(), filename)
  print("模型参数已保存为{}".format(filename), '\n')

  # 完成各种工作，记录结果...
  normal_dict = {
      "训练的模型的保留路径": filename,
      "在测试集中的最终损失": final_valid_loss,
      "在测试集中的最终损失":best_valid_loss,
      "在测试集中的最终准确率": final_valid_acc,
      "在测试集中的最佳准确率": best_valid_acc,
      "在训练集中的最终准确率": final_train_acc,
      "在训练集中的最佳准确率": best_train_acc,
      "在训练集中的最终损失": final_train_loss,
      "在训练集中的最佳损失":best_train_loss
  }
  return normal_dict

# %%
# 定义初始的scale范围
scale_min = 0.1
scale_max = 0.9
scale_list = [round(x * 0.1, 1) for x in range(int(scale_min * 10), int(scale_max * 10) + 1)]
# print(scale_list)
my_list = []
# 添加tensorboard
writer_new = SummaryWriter("logs-MLP-0913")

for scale in scale_list:
  train_loader, valid_loader, test_loader = get_data_loader(scale, valid_scale=0.1)
  dic = {}
  print("--------------------开始scale={}的情况---------------------".format(scale), "\n")
  dic['sacle={}'.format(scale)] = get_scale(scale=scale, writer=writer_new, train_loader=train_loader, valid_loader=valid_loader)
  print(dic['sacle={}'.format(scale)])
  my_list.append(dic)

writer_new.close()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# --------------------开始scale=0.1的情况---------------------
#
# Epoch [1/100], Final Train Loss: 2.0789, Final Train Accuracy: 20.62%, Best Train Accuracy: 20.62, Loss to best acc:2.08%
#
# Epoch [1/100], Final Valid Loss: 2.2169, Final Valid Accuracy: 21.40%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [2/100], Final Train Loss: 2.0474, Final Train Accuracy: 22.95%, Best Train Accuracy: 22.95, Loss to best acc:2.05%
#
# Epoch [2/100], Final Valid Loss: 2.2683, Final Valid Accuracy: 18.00%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [3/100], Final Train Loss: 2.0030, Final Train Accuracy: 23.80%, Best Train Accuracy: 23.80, Loss to best acc:2.00%
#
# Epoch [3/100], Final Valid Loss: 2.2284, Final Valid Accuracy: 18.07%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [4/100], Final Train Loss: 2.0456, Final Train Accuracy: 24.18%, Best Train Accuracy: 24.18, Loss to best acc:2.05%
#
# Epoch [4/100], Final Valid Loss: 2.2451, Final Valid Accuracy: 17.90%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [5/100], Final Train Loss: 2.0480, Final Train Accuracy: 24.59%, Best Train Accuracy: 24.59, Loss to best acc:2.05%
#
# Epoch [5/100], Final Valid Loss: 2.2251, Final Valid Accuracy: 17.78%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [6/100], Final Train Loss: 2.0013, Final Train Accuracy: 25.26%, Best Train Accuracy: 25.26, Loss to best acc:2.00%
#
# Epoch [6/100], Final Valid Loss: 2.2355, Final Valid Accuracy: 17.90%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [7/100], Final Train Loss: 1.9941, Final Train Accuracy: 25.32%, Best Train Accuracy: 25.32, Loss to best acc:1.99%
#
# Epoch [7/100], Final Valid Loss: 2.2721, Final Valid Accuracy: 17.49%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [8/100], Final Train Loss: 2.0986, Final Train Accuracy: 25.32%, Best Train Accuracy: 25.32, Loss to best acc:2.10%
#
# Epoch [8/100], Final Valid Loss: 2.2438, Final Valid Accuracy: 17.51%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [9/100], Final Train Loss: 2.0618, Final Train Accuracy: 25.56%, Best Train Accuracy: 25.56, Loss to best acc:2.06%
#
# Epoch [9/100], Final Valid Loss: 2.3155, Final Valid Accuracy: 17.04%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [10/100], Final Train Loss: 2.0136, Final Train Accuracy: 25.73%, Best Train Accuracy: 25.73, Loss to best acc:2.01%
#
# Epoch [10/100], Final Valid Loss: 2.2024, Final Valid Accuracy: 17.30%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [11/100], Final Train Loss: 1.9926, Final Train Accuracy: 26.06%, Best Train Accuracy: 26.06, Loss to best acc:1.99%
#
# Epoch [11/100], Final Valid Loss: 2.2722, Final Valid Accuracy: 16.97%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [12/100], Final Train Loss: 1.9858, Final Train Accuracy: 26.03%, Best Train Accuracy: 26.06, Loss to best acc:1.99%
#
# Epoch [12/100], Final Valid Loss: 2.2197, Final Valid Accuracy: 17.32%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [13/100], Final Train Loss: 1.8951, Final Train Accuracy: 26.48%, Best Train Accuracy: 26.48, Loss to best acc:1.90%
#
# Epoch [13/100], Final Valid Loss: 2.2251, Final Valid Accuracy: 17.63%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [14/100], Final Train Loss: 1.9182, Final Train Accuracy: 26.55%, Best Train Accuracy: 26.55, Loss to best acc:1.92%
#
# Epoch [14/100], Final Valid Loss: 2.2092, Final Valid Accuracy: 17.71%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [15/100], Final Train Loss: 1.9188, Final Train Accuracy: 26.83%, Best Train Accuracy: 26.83, Loss to best acc:1.92%
#
# Epoch [15/100], Final Valid Loss: 2.2128, Final Valid Accuracy: 17.71%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [16/100], Final Train Loss: 1.9992, Final Train Accuracy: 26.87%, Best Train Accuracy: 26.87, Loss to best acc:2.00%
#
# Epoch [16/100], Final Valid Loss: 2.2067, Final Valid Accuracy: 17.81%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [17/100], Final Train Loss: 2.0304, Final Train Accuracy: 27.16%, Best Train Accuracy: 27.16, Loss to best acc:2.03%
#
# Epoch [17/100], Final Valid Loss: 2.2222, Final Valid Accuracy: 17.97%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [18/100], Final Train Loss: 2.0066, Final Train Accuracy: 27.34%, Best Train Accuracy: 27.34, Loss to best acc:2.01%
#
# Epoch [18/100], Final Valid Loss: 2.2843, Final Valid Accuracy: 17.84%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [19/100], Final Train Loss: 1.9143, Final Train Accuracy: 27.20%, Best Train Accuracy: 27.34, Loss to best acc:2.01%
#
# Epoch [19/100], Final Valid Loss: 2.2255, Final Valid Accuracy: 17.75%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [20/100], Final Train Loss: 2.0251, Final Train Accuracy: 27.06%, Best Train Accuracy: 27.34, Loss to best acc:2.01%
#
# Epoch [20/100], Final Valid Loss: 2.2720, Final Valid Accuracy: 17.62%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [21/100], Final Train Loss: 1.9747, Final Train Accuracy: 27.00%, Best Train Accuracy: 27.34, Loss to best acc:2.01%
#
# Epoch [21/100], Final Valid Loss: 2.2075, Final Valid Accuracy: 17.63%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [22/100], Final Train Loss: 1.8603, Final Train Accuracy: 27.28%, Best Train Accuracy: 27.34, Loss to best acc:2.01%
#
# Epoch [22/100], Final Valid Loss: 2.1977, Final Valid Accuracy: 17.76%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [23/100], Final Train Loss: 1.8928, Final Train Accuracy: 27.32%, Best Train Accuracy: 27.34, Loss to best acc:2.01%
#
# Epoch [23/100], Final Valid Loss: 2.2378, Final Valid Accuracy: 17.82%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [24/100], Final Train Loss: 2.0042, Final Train Accuracy: 27.67%, Best Train Accuracy: 27.67, Loss to best acc:2.00%
#
# Epoch [24/100], Final Valid Loss: 2.1896, Final Valid Accuracy: 17.90%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [25/100], Final Train Loss: 1.9647, Final Train Accuracy: 27.47%, Best Train Accuracy: 27.67, Loss to best acc:2.00%
#
# Epoch [25/100], Final Valid Loss: 2.2576, Final Valid Accuracy: 17.84%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [26/100], Final Train Loss: 2.0454, Final Train Accuracy: 27.66%, Best Train Accuracy: 27.67, Loss to best acc:2.00%
#
# Epoch [26/100], Final Valid Loss: 2.2403, Final Valid Accuracy: 17.89%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [27/100], Final Train Loss: 1.9149, Final Train Accuracy: 28.10%, Best Train Accuracy: 28.10, Loss to best acc:1.91%
#
# Epoch [27/100], Final Valid Loss: 2.1779, Final Valid Accuracy: 17.96%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [28/100], Final Train Loss: 1.9625, Final Train Accuracy: 28.53%, Best Train Accuracy: 28.53, Loss to best acc:1.96%
#
# Epoch [28/100], Final Valid Loss: 2.2284, Final Valid Accuracy: 18.02%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [29/100], Final Train Loss: 1.9675, Final Train Accuracy: 28.16%, Best Train Accuracy: 28.53, Loss to best acc:1.96%
#
# Epoch [29/100], Final Valid Loss: 2.2318, Final Valid Accuracy: 18.05%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [30/100], Final Train Loss: 1.8652, Final Train Accuracy: 28.48%, Best Train Accuracy: 28.53, Loss to best acc:1.96%
#
# Epoch [30/100], Final Valid Loss: 2.1901, Final Valid Accuracy: 18.16%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [31/100], Final Train Loss: 1.8251, Final Train Accuracy: 28.36%, Best Train Accuracy: 28.53, Loss to best acc:1.96%
#
# Epoch [31/100], Final Valid Loss: 2.2007, Final Valid Accuracy: 18.19%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [32/100], Final Train Loss: 1.9495, Final Train Accuracy: 28.33%, Best Train Accuracy: 28.53, Loss to best acc:1.96%
#
# Epoch [32/100], Final Valid Loss: 2.1969, Final Valid Accuracy: 18.18%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [33/100], Final Train Loss: 1.9694, Final Train Accuracy: 28.62%, Best Train Accuracy: 28.62, Loss to best acc:1.97%
#
# Epoch [33/100], Final Valid Loss: 2.2280, Final Valid Accuracy: 18.18%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [34/100], Final Train Loss: 1.9687, Final Train Accuracy: 28.35%, Best Train Accuracy: 28.62, Loss to best acc:1.97%
#
# Epoch [34/100], Final Valid Loss: 2.2058, Final Valid Accuracy: 18.24%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [35/100], Final Train Loss: 1.9798, Final Train Accuracy: 28.37%, Best Train Accuracy: 28.62, Loss to best acc:1.97%
#
# Epoch [35/100], Final Valid Loss: 2.1820, Final Valid Accuracy: 18.29%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [36/100], Final Train Loss: 1.9940, Final Train Accuracy: 28.33%, Best Train Accuracy: 28.62, Loss to best acc:1.97%
#
# Epoch [36/100], Final Valid Loss: 2.2254, Final Valid Accuracy: 18.32%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [37/100], Final Train Loss: 1.9288, Final Train Accuracy: 28.67%, Best Train Accuracy: 28.67, Loss to best acc:1.93%
#
# Epoch [37/100], Final Valid Loss: 2.2417, Final Valid Accuracy: 18.31%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [38/100], Final Train Loss: 1.8852, Final Train Accuracy: 28.63%, Best Train Accuracy: 28.67, Loss to best acc:1.93%
#
# Epoch [38/100], Final Valid Loss: 2.2369, Final Valid Accuracy: 18.33%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [39/100], Final Train Loss: 1.9598, Final Train Accuracy: 28.80%, Best Train Accuracy: 28.80, Loss to best acc:1.96%
#
# Epoch [39/100], Final Valid Loss: 2.2794, Final Valid Accuracy: 18.23%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [40/100], Final Train Loss: 1.9241, Final Train Accuracy: 28.02%, Best Train Accuracy: 28.80, Loss to best acc:1.96%
#
# Epoch [40/100], Final Valid Loss: 2.1454, Final Valid Accuracy: 18.27%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [41/100], Final Train Loss: 1.8921, Final Train Accuracy: 28.78%, Best Train Accuracy: 28.80, Loss to best acc:1.96%
#
# Epoch [41/100], Final Valid Loss: 2.1853, Final Valid Accuracy: 18.37%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [42/100], Final Train Loss: 1.9396, Final Train Accuracy: 28.18%, Best Train Accuracy: 28.80, Loss to best acc:1.96%
#
# Epoch [42/100], Final Valid Loss: 2.2021, Final Valid Accuracy: 18.43%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [43/100], Final Train Loss: 1.9119, Final Train Accuracy: 28.89%, Best Train Accuracy: 28.89, Loss to best acc:1.91%
#
# Epoch [43/100], Final Valid Loss: 2.2317, Final Valid Accuracy: 18.43%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [44/100], Final Train Loss: 1.8735, Final Train Accuracy: 28.94%, Best Train Accuracy: 28.94, Loss to best acc:1.87%
#
# Epoch [44/100], Final Valid Loss: 2.1928, Final Valid Accuracy: 18.45%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [45/100], Final Train Loss: 1.9727, Final Train Accuracy: 28.74%, Best Train Accuracy: 28.94, Loss to best acc:1.87%
#
# Epoch [45/100], Final Valid Loss: 2.2139, Final Valid Accuracy: 18.54%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [46/100], Final Train Loss: 1.9752, Final Train Accuracy: 29.07%, Best Train Accuracy: 29.07, Loss to best acc:1.98%
#
# Epoch [46/100], Final Valid Loss: 2.2172, Final Valid Accuracy: 18.57%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [47/100], Final Train Loss: 1.9234, Final Train Accuracy: 28.69%, Best Train Accuracy: 29.07, Loss to best acc:1.98%
#
# Epoch [47/100], Final Valid Loss: 2.1744, Final Valid Accuracy: 18.60%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [48/100], Final Train Loss: 1.9661, Final Train Accuracy: 28.76%, Best Train Accuracy: 29.07, Loss to best acc:1.98%
#
# Epoch [48/100], Final Valid Loss: 2.2237, Final Valid Accuracy: 18.60%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [49/100], Final Train Loss: 1.9856, Final Train Accuracy: 28.68%, Best Train Accuracy: 29.07, Loss to best acc:1.98%
#
# Epoch [49/100], Final Valid Loss: 2.2332, Final Valid Accuracy: 18.62%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [50/100], Final Train Loss: 1.9174, Final Train Accuracy: 29.12%, Best Train Accuracy: 29.12, Loss to best acc:1.92%
#
# Epoch [50/100], Final Valid Loss: 2.2857, Final Valid Accuracy: 18.54%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [51/100], Final Train Loss: 1.9857, Final Train Accuracy: 29.53%, Best Train Accuracy: 29.53, Loss to best acc:1.99%
#
# Epoch [51/100], Final Valid Loss: 2.1784, Final Valid Accuracy: 18.55%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [52/100], Final Train Loss: 1.8813, Final Train Accuracy: 29.46%, Best Train Accuracy: 29.53, Loss to best acc:1.99%
#
# Epoch [52/100], Final Valid Loss: 2.1725, Final Valid Accuracy: 18.57%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [53/100], Final Train Loss: 1.9217, Final Train Accuracy: 29.16%, Best Train Accuracy: 29.53, Loss to best acc:1.99%
#
# Epoch [53/100], Final Valid Loss: 2.1851, Final Valid Accuracy: 18.59%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [54/100], Final Train Loss: 1.9225, Final Train Accuracy: 29.38%, Best Train Accuracy: 29.53, Loss to best acc:1.99%
#
# Epoch [54/100], Final Valid Loss: 2.1863, Final Valid Accuracy: 18.68%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [55/100], Final Train Loss: 1.9147, Final Train Accuracy: 29.40%, Best Train Accuracy: 29.53, Loss to best acc:1.99%
#
# Epoch [55/100], Final Valid Loss: 2.2725, Final Valid Accuracy: 18.65%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [56/100], Final Train Loss: 1.8909, Final Train Accuracy: 29.57%, Best Train Accuracy: 29.57, Loss to best acc:1.89%
#
# Epoch [56/100], Final Valid Loss: 2.1958, Final Valid Accuracy: 18.69%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [57/100], Final Train Loss: 1.8651, Final Train Accuracy: 29.49%, Best Train Accuracy: 29.57, Loss to best acc:1.89%
#
# Epoch [57/100], Final Valid Loss: 2.2064, Final Valid Accuracy: 18.69%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [58/100], Final Train Loss: 1.9777, Final Train Accuracy: 29.31%, Best Train Accuracy: 29.57, Loss to best acc:1.89%
#
# Epoch [58/100], Final Valid Loss: 2.2115, Final Valid Accuracy: 18.73%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [59/100], Final Train Loss: 1.8383, Final Train Accuracy: 29.88%, Best Train Accuracy: 29.88, Loss to best acc:1.84%
#
# Epoch [59/100], Final Valid Loss: 2.1499, Final Valid Accuracy: 18.75%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [60/100], Final Train Loss: 1.9081, Final Train Accuracy: 29.79%, Best Train Accuracy: 29.88, Loss to best acc:1.84%
#
# Epoch [60/100], Final Valid Loss: 2.2144, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [61/100], Final Train Loss: 1.9577, Final Train Accuracy: 29.70%, Best Train Accuracy: 29.88, Loss to best acc:1.84%
#
# Epoch [61/100], Final Valid Loss: 2.2572, Final Valid Accuracy: 18.69%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [62/100], Final Train Loss: 1.9049, Final Train Accuracy: 29.37%, Best Train Accuracy: 29.88, Loss to best acc:1.84%
#
# Epoch [62/100], Final Valid Loss: 2.2128, Final Valid Accuracy: 18.72%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [63/100], Final Train Loss: 1.9641, Final Train Accuracy: 29.85%, Best Train Accuracy: 29.88, Loss to best acc:1.84%
#
# Epoch [63/100], Final Valid Loss: 2.2240, Final Valid Accuracy: 18.73%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [64/100], Final Train Loss: 1.8862, Final Train Accuracy: 29.54%, Best Train Accuracy: 29.88, Loss to best acc:1.84%
#
# Epoch [64/100], Final Valid Loss: 2.2142, Final Valid Accuracy: 18.72%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [65/100], Final Train Loss: 1.9249, Final Train Accuracy: 29.95%, Best Train Accuracy: 29.95, Loss to best acc:1.92%
#
# Epoch [65/100], Final Valid Loss: 2.2335, Final Valid Accuracy: 18.66%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [66/100], Final Train Loss: 1.8980, Final Train Accuracy: 29.51%, Best Train Accuracy: 29.95, Loss to best acc:1.92%
#
# Epoch [66/100], Final Valid Loss: 2.2078, Final Valid Accuracy: 18.66%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [67/100], Final Train Loss: 1.9046, Final Train Accuracy: 29.96%, Best Train Accuracy: 29.96, Loss to best acc:1.90%
#
# Epoch [67/100], Final Valid Loss: 2.1768, Final Valid Accuracy: 18.70%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [68/100], Final Train Loss: 1.9613, Final Train Accuracy: 29.83%, Best Train Accuracy: 29.96, Loss to best acc:1.90%
#
# Epoch [68/100], Final Valid Loss: 2.2083, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [69/100], Final Train Loss: 1.9528, Final Train Accuracy: 29.83%, Best Train Accuracy: 29.96, Loss to best acc:1.90%
#
# Epoch [69/100], Final Valid Loss: 2.1581, Final Valid Accuracy: 18.76%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [70/100], Final Train Loss: 1.9036, Final Train Accuracy: 29.72%, Best Train Accuracy: 29.96, Loss to best acc:1.90%
#
# Epoch [70/100], Final Valid Loss: 2.2401, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [71/100], Final Train Loss: 1.8714, Final Train Accuracy: 29.89%, Best Train Accuracy: 29.96, Loss to best acc:1.90%
#
# Epoch [71/100], Final Valid Loss: 2.1762, Final Valid Accuracy: 18.76%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [72/100], Final Train Loss: 1.8169, Final Train Accuracy: 30.22%, Best Train Accuracy: 30.22, Loss to best acc:1.82%
#
# Epoch [72/100], Final Valid Loss: 2.1798, Final Valid Accuracy: 18.76%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [73/100], Final Train Loss: 1.9671, Final Train Accuracy: 30.03%, Best Train Accuracy: 30.22, Loss to best acc:1.82%
#
# Epoch [73/100], Final Valid Loss: 2.2078, Final Valid Accuracy: 18.75%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [74/100], Final Train Loss: 1.9179, Final Train Accuracy: 30.17%, Best Train Accuracy: 30.22, Loss to best acc:1.82%
#
# Epoch [74/100], Final Valid Loss: 2.2254, Final Valid Accuracy: 18.77%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [75/100], Final Train Loss: 1.9099, Final Train Accuracy: 29.74%, Best Train Accuracy: 30.22, Loss to best acc:1.82%
#
# Epoch [75/100], Final Valid Loss: 2.2011, Final Valid Accuracy: 18.82%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [76/100], Final Train Loss: 1.9034, Final Train Accuracy: 29.97%, Best Train Accuracy: 30.22, Loss to best acc:1.82%
#
# Epoch [76/100], Final Valid Loss: 2.2288, Final Valid Accuracy: 18.79%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [77/100], Final Train Loss: 1.9274, Final Train Accuracy: 30.25%, Best Train Accuracy: 30.25, Loss to best acc:1.93%
#
# Epoch [77/100], Final Valid Loss: 2.1952, Final Valid Accuracy: 18.79%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [78/100], Final Train Loss: 1.9138, Final Train Accuracy: 30.17%, Best Train Accuracy: 30.25, Loss to best acc:1.93%
#
# Epoch [78/100], Final Valid Loss: 2.1628, Final Valid Accuracy: 18.80%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [79/100], Final Train Loss: 1.8537, Final Train Accuracy: 29.82%, Best Train Accuracy: 30.25, Loss to best acc:1.93%
#
# Epoch [79/100], Final Valid Loss: 2.1967, Final Valid Accuracy: 18.84%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [80/100], Final Train Loss: 1.9111, Final Train Accuracy: 30.31%, Best Train Accuracy: 30.31, Loss to best acc:1.91%
#
# Epoch [80/100], Final Valid Loss: 2.3440, Final Valid Accuracy: 18.80%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [81/100], Final Train Loss: 1.9030, Final Train Accuracy: 30.35%, Best Train Accuracy: 30.35, Loss to best acc:1.90%
#
# Epoch [81/100], Final Valid Loss: 2.2422, Final Valid Accuracy: 18.78%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [82/100], Final Train Loss: 1.8731, Final Train Accuracy: 30.30%, Best Train Accuracy: 30.35, Loss to best acc:1.90%
#
# Epoch [82/100], Final Valid Loss: 2.2230, Final Valid Accuracy: 18.77%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [83/100], Final Train Loss: 1.9315, Final Train Accuracy: 30.18%, Best Train Accuracy: 30.35, Loss to best acc:1.90%
#
# Epoch [83/100], Final Valid Loss: 2.2282, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [84/100], Final Train Loss: 1.8406, Final Train Accuracy: 30.47%, Best Train Accuracy: 30.47, Loss to best acc:1.84%
#
# Epoch [84/100], Final Valid Loss: 2.2091, Final Valid Accuracy: 18.75%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [85/100], Final Train Loss: 1.9127, Final Train Accuracy: 29.89%, Best Train Accuracy: 30.47, Loss to best acc:1.84%
#
# Epoch [85/100], Final Valid Loss: 2.2089, Final Valid Accuracy: 18.77%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [86/100], Final Train Loss: 1.8894, Final Train Accuracy: 30.70%, Best Train Accuracy: 30.70, Loss to best acc:1.89%
#
# Epoch [86/100], Final Valid Loss: 2.1643, Final Valid Accuracy: 18.79%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [87/100], Final Train Loss: 2.0100, Final Train Accuracy: 30.53%, Best Train Accuracy: 30.70, Loss to best acc:1.89%
#
# Epoch [87/100], Final Valid Loss: 2.2793, Final Valid Accuracy: 18.75%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [88/100], Final Train Loss: 1.9944, Final Train Accuracy: 30.39%, Best Train Accuracy: 30.70, Loss to best acc:1.89%
#
# Epoch [88/100], Final Valid Loss: 2.1824, Final Valid Accuracy: 18.78%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [89/100], Final Train Loss: 1.9599, Final Train Accuracy: 30.46%, Best Train Accuracy: 30.70, Loss to best acc:1.89%
#
# Epoch [89/100], Final Valid Loss: 2.2478, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [90/100], Final Train Loss: 1.9567, Final Train Accuracy: 30.39%, Best Train Accuracy: 30.70, Loss to best acc:1.89%
#
# Epoch [90/100], Final Valid Loss: 2.1852, Final Valid Accuracy: 18.76%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [91/100], Final Train Loss: 1.9007, Final Train Accuracy: 30.38%, Best Train Accuracy: 30.70, Loss to best acc:1.89%
#
# Epoch [91/100], Final Valid Loss: 2.3364, Final Valid Accuracy: 18.72%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [92/100], Final Train Loss: 1.8519, Final Train Accuracy: 30.38%, Best Train Accuracy: 30.70, Loss to best acc:1.89%
#
# Epoch [92/100], Final Valid Loss: 2.2559, Final Valid Accuracy: 18.72%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [93/100], Final Train Loss: 1.9277, Final Train Accuracy: 30.42%, Best Train Accuracy: 30.70, Loss to best acc:1.89%
#
# Epoch [93/100], Final Valid Loss: 2.1581, Final Valid Accuracy: 18.75%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [94/100], Final Train Loss: 1.9024, Final Train Accuracy: 30.75%, Best Train Accuracy: 30.75, Loss to best acc:1.90%
#
# Epoch [94/100], Final Valid Loss: 2.2232, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [95/100], Final Train Loss: 1.9050, Final Train Accuracy: 30.48%, Best Train Accuracy: 30.75, Loss to best acc:1.90%
#
# Epoch [95/100], Final Valid Loss: 2.2240, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [96/100], Final Train Loss: 1.8434, Final Train Accuracy: 31.00%, Best Train Accuracy: 31.00, Loss to best acc:1.84%
#
# Epoch [96/100], Final Valid Loss: 2.1911, Final Valid Accuracy: 18.76%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [97/100], Final Train Loss: 1.9833, Final Train Accuracy: 30.55%, Best Train Accuracy: 31.00, Loss to best acc:1.84%
#
# Epoch [97/100], Final Valid Loss: 2.2376, Final Valid Accuracy: 18.75%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [98/100], Final Train Loss: 1.8814, Final Train Accuracy: 30.20%, Best Train Accuracy: 31.00, Loss to best acc:1.84%
#
# Epoch [98/100], Final Valid Loss: 2.2550, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [99/100], Final Train Loss: 1.8561, Final Train Accuracy: 30.62%, Best Train Accuracy: 31.00, Loss to best acc:1.84%
#
# Epoch [99/100], Final Valid Loss: 2.1631, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# Epoch [100/100], Final Train Loss: 1.8848, Final Train Accuracy: 30.99%, Best Train Accuracy: 31.00, Loss to best acc:1.84%
#
# Epoch [100/100], Final Valid Loss: 2.2190, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.22
#
# 模型参数已保存为LP-RL-model_scale=0.1.pth
#
# {'训练的模型的保留路径': 'LP-RL-model_scale=0.1.pth', '在测试集中的最终损失': 2.2168614864349365, '在测试集中的最终准确率': 0.18739, '在测试集中的最佳准确率': 0.214, '在训练集中的最终准确率': 0.30986, '在训练集中的最佳准确率': 0.30998, '在训练集中的最终损失': 1.8848055601119995, '在训练集中的最佳损失': 1.8433647155761719}
# Files already downloaded and verified
# Files already downloaded and verified
# --------------------开始scale=0.2的情况---------------------
#
# Epoch [1/100], Final Train Loss: 2.1173, Final Train Accuracy: 22.60%, Best Train Accuracy: 22.60, Loss to best acc:2.12%
#
# Epoch [1/100], Final Valid Loss: 2.1808, Final Valid Accuracy: 18.40%, Best Valid Accuracy: 18.40%, Loss to best Valid accuracy:2.18
#
# Epoch [2/100], Final Train Loss: 1.9634, Final Train Accuracy: 25.53%, Best Train Accuracy: 25.53, Loss to best acc:1.96%
#
# Epoch [2/100], Final Valid Loss: 2.2280, Final Valid Accuracy: 18.05%, Best Valid Accuracy: 18.40%, Loss to best Valid accuracy:2.18
#
# Epoch [3/100], Final Train Loss: 1.9148, Final Train Accuracy: 27.19%, Best Train Accuracy: 27.19, Loss to best acc:1.91%
#
# Epoch [3/100], Final Valid Loss: 2.2036, Final Valid Accuracy: 18.30%, Best Valid Accuracy: 18.40%, Loss to best Valid accuracy:2.18
#
# Epoch [4/100], Final Train Loss: 1.8988, Final Train Accuracy: 27.98%, Best Train Accuracy: 27.98, Loss to best acc:1.90%
#
# Epoch [4/100], Final Valid Loss: 2.2037, Final Valid Accuracy: 18.18%, Best Valid Accuracy: 18.40%, Loss to best Valid accuracy:2.18
#
# Epoch [5/100], Final Train Loss: 1.9245, Final Train Accuracy: 29.16%, Best Train Accuracy: 29.16, Loss to best acc:1.92%
#
# Epoch [5/100], Final Valid Loss: 2.2148, Final Valid Accuracy: 18.48%, Best Valid Accuracy: 18.48%, Loss to best Valid accuracy:2.21
#
# Epoch [6/100], Final Train Loss: 1.8638, Final Train Accuracy: 29.21%, Best Train Accuracy: 29.21, Loss to best acc:1.86%
#
# Epoch [6/100], Final Valid Loss: 2.2168, Final Valid Accuracy: 18.12%, Best Valid Accuracy: 18.48%, Loss to best Valid accuracy:2.21
#
# Epoch [7/100], Final Train Loss: 1.8883, Final Train Accuracy: 29.07%, Best Train Accuracy: 29.21, Loss to best acc:1.86%
#
# Epoch [7/100], Final Valid Loss: 2.2381, Final Valid Accuracy: 17.53%, Best Valid Accuracy: 18.48%, Loss to best Valid accuracy:2.21
#
# Epoch [8/100], Final Train Loss: 1.7912, Final Train Accuracy: 29.82%, Best Train Accuracy: 29.82, Loss to best acc:1.79%
#
# Epoch [8/100], Final Valid Loss: 2.1832, Final Valid Accuracy: 18.00%, Best Valid Accuracy: 18.48%, Loss to best Valid accuracy:2.21
#
# Epoch [9/100], Final Train Loss: 1.8895, Final Train Accuracy: 30.29%, Best Train Accuracy: 30.29, Loss to best acc:1.89%
#
# Epoch [9/100], Final Valid Loss: 2.1803, Final Valid Accuracy: 18.13%, Best Valid Accuracy: 18.48%, Loss to best Valid accuracy:2.21
#
# Epoch [10/100], Final Train Loss: 1.9932, Final Train Accuracy: 30.61%, Best Train Accuracy: 30.61, Loss to best acc:1.99%
#
# Epoch [10/100], Final Valid Loss: 2.1540, Final Valid Accuracy: 18.45%, Best Valid Accuracy: 18.48%, Loss to best Valid accuracy:2.21
#
# Epoch [11/100], Final Train Loss: 1.8757, Final Train Accuracy: 30.70%, Best Train Accuracy: 30.70, Loss to best acc:1.88%
#
# Epoch [11/100], Final Valid Loss: 2.1310, Final Valid Accuracy: 18.95%, Best Valid Accuracy: 18.95%, Loss to best Valid accuracy:2.13
#
# Epoch [12/100], Final Train Loss: 1.8409, Final Train Accuracy: 31.04%, Best Train Accuracy: 31.04, Loss to best acc:1.84%
#
# Epoch [12/100], Final Valid Loss: 2.1990, Final Valid Accuracy: 19.25%, Best Valid Accuracy: 19.25%, Loss to best Valid accuracy:2.20
#
# Epoch [13/100], Final Train Loss: 1.8584, Final Train Accuracy: 31.13%, Best Train Accuracy: 31.13, Loss to best acc:1.86%
#
# Epoch [13/100], Final Valid Loss: 2.2549, Final Valid Accuracy: 19.11%, Best Valid Accuracy: 19.25%, Loss to best Valid accuracy:2.20
#
# Epoch [14/100], Final Train Loss: 1.8739, Final Train Accuracy: 31.44%, Best Train Accuracy: 31.44, Loss to best acc:1.87%
#
# Epoch [14/100], Final Valid Loss: 2.1519, Final Valid Accuracy: 19.02%, Best Valid Accuracy: 19.25%, Loss to best Valid accuracy:2.20
#
# Epoch [15/100], Final Train Loss: 1.8847, Final Train Accuracy: 31.20%, Best Train Accuracy: 31.44, Loss to best acc:1.87%
#
# Epoch [15/100], Final Valid Loss: 2.1724, Final Valid Accuracy: 19.02%, Best Valid Accuracy: 19.25%, Loss to best Valid accuracy:2.20
#
# Epoch [16/100], Final Train Loss: 1.7910, Final Train Accuracy: 32.17%, Best Train Accuracy: 32.17, Loss to best acc:1.79%
#
# Epoch [16/100], Final Valid Loss: 2.2152, Final Valid Accuracy: 18.98%, Best Valid Accuracy: 19.25%, Loss to best Valid accuracy:2.20
#
# Epoch [17/100], Final Train Loss: 1.9186, Final Train Accuracy: 32.17%, Best Train Accuracy: 32.17, Loss to best acc:1.92%
#
# Epoch [17/100], Final Valid Loss: 2.2022, Final Valid Accuracy: 18.89%, Best Valid Accuracy: 19.25%, Loss to best Valid accuracy:2.20
#
# Epoch [18/100], Final Train Loss: 1.8741, Final Train Accuracy: 32.51%, Best Train Accuracy: 32.51, Loss to best acc:1.87%
#
# Epoch [18/100], Final Valid Loss: 2.2206, Final Valid Accuracy: 18.86%, Best Valid Accuracy: 19.25%, Loss to best Valid accuracy:2.20
#
# Epoch [19/100], Final Train Loss: 1.9019, Final Train Accuracy: 32.40%, Best Train Accuracy: 32.51, Loss to best acc:1.87%
#
# Epoch [19/100], Final Valid Loss: 2.1547, Final Valid Accuracy: 18.96%, Best Valid Accuracy: 19.25%, Loss to best Valid accuracy:2.20
#
# Epoch [20/100], Final Train Loss: 1.8396, Final Train Accuracy: 32.75%, Best Train Accuracy: 32.75, Loss to best acc:1.84%
#
# Epoch [20/100], Final Valid Loss: 2.1292, Final Valid Accuracy: 18.93%, Best Valid Accuracy: 19.25%, Loss to best Valid accuracy:2.20
#
# Epoch [21/100], Final Train Loss: 1.7289, Final Train Accuracy: 32.68%, Best Train Accuracy: 32.75, Loss to best acc:1.84%
#
# Epoch [21/100], Final Valid Loss: 2.1798, Final Valid Accuracy: 19.02%, Best Valid Accuracy: 19.25%, Loss to best Valid accuracy:2.20
#
# Epoch [22/100], Final Train Loss: 1.8544, Final Train Accuracy: 32.93%, Best Train Accuracy: 32.93, Loss to best acc:1.85%
#
# Epoch [22/100], Final Valid Loss: 2.1744, Final Valid Accuracy: 19.15%, Best Valid Accuracy: 19.25%, Loss to best Valid accuracy:2.20
#
# Epoch [23/100], Final Train Loss: 1.8325, Final Train Accuracy: 33.25%, Best Train Accuracy: 33.25, Loss to best acc:1.83%
#
# Epoch [23/100], Final Valid Loss: 2.1971, Final Valid Accuracy: 19.12%, Best Valid Accuracy: 19.25%, Loss to best Valid accuracy:2.20
#
# Epoch [24/100], Final Train Loss: 1.8530, Final Train Accuracy: 32.60%, Best Train Accuracy: 33.25, Loss to best acc:1.83%
#
# Epoch [24/100], Final Valid Loss: 2.1910, Final Valid Accuracy: 19.30%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [25/100], Final Train Loss: 1.7650, Final Train Accuracy: 33.21%, Best Train Accuracy: 33.25, Loss to best acc:1.83%
#
# Epoch [25/100], Final Valid Loss: 2.1932, Final Valid Accuracy: 19.26%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [26/100], Final Train Loss: 1.7868, Final Train Accuracy: 33.67%, Best Train Accuracy: 33.67, Loss to best acc:1.79%
#
# Epoch [26/100], Final Valid Loss: 2.2796, Final Valid Accuracy: 19.05%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [27/100], Final Train Loss: 1.8042, Final Train Accuracy: 33.56%, Best Train Accuracy: 33.67, Loss to best acc:1.79%
#
# Epoch [27/100], Final Valid Loss: 2.2183, Final Valid Accuracy: 19.04%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [28/100], Final Train Loss: 1.8417, Final Train Accuracy: 33.47%, Best Train Accuracy: 33.67, Loss to best acc:1.79%
#
# Epoch [28/100], Final Valid Loss: 2.2182, Final Valid Accuracy: 18.93%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [29/100], Final Train Loss: 1.8147, Final Train Accuracy: 33.43%, Best Train Accuracy: 33.67, Loss to best acc:1.79%
#
# Epoch [29/100], Final Valid Loss: 2.1368, Final Valid Accuracy: 18.99%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [30/100], Final Train Loss: 1.8445, Final Train Accuracy: 34.31%, Best Train Accuracy: 34.31, Loss to best acc:1.84%
#
# Epoch [30/100], Final Valid Loss: 2.1988, Final Valid Accuracy: 19.01%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [31/100], Final Train Loss: 1.7390, Final Train Accuracy: 34.02%, Best Train Accuracy: 34.31, Loss to best acc:1.84%
#
# Epoch [31/100], Final Valid Loss: 2.1578, Final Valid Accuracy: 19.13%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [32/100], Final Train Loss: 1.8966, Final Train Accuracy: 33.98%, Best Train Accuracy: 34.31, Loss to best acc:1.84%
#
# Epoch [32/100], Final Valid Loss: 2.1675, Final Valid Accuracy: 19.16%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [33/100], Final Train Loss: 1.7745, Final Train Accuracy: 33.99%, Best Train Accuracy: 34.31, Loss to best acc:1.84%
#
# Epoch [33/100], Final Valid Loss: 2.2167, Final Valid Accuracy: 19.11%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [34/100], Final Train Loss: 1.7474, Final Train Accuracy: 34.41%, Best Train Accuracy: 34.41, Loss to best acc:1.75%
#
# Epoch [34/100], Final Valid Loss: 2.2143, Final Valid Accuracy: 19.15%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [35/100], Final Train Loss: 1.8195, Final Train Accuracy: 34.56%, Best Train Accuracy: 34.56, Loss to best acc:1.82%
#
# Epoch [35/100], Final Valid Loss: 2.2192, Final Valid Accuracy: 19.08%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [36/100], Final Train Loss: 1.8364, Final Train Accuracy: 34.71%, Best Train Accuracy: 34.71, Loss to best acc:1.84%
#
# Epoch [36/100], Final Valid Loss: 2.2035, Final Valid Accuracy: 19.14%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [37/100], Final Train Loss: 1.8402, Final Train Accuracy: 34.72%, Best Train Accuracy: 34.72, Loss to best acc:1.84%
#
# Epoch [37/100], Final Valid Loss: 2.3057, Final Valid Accuracy: 18.91%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [38/100], Final Train Loss: 1.8038, Final Train Accuracy: 34.73%, Best Train Accuracy: 34.73, Loss to best acc:1.80%
#
# Epoch [38/100], Final Valid Loss: 2.1792, Final Valid Accuracy: 18.97%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [39/100], Final Train Loss: 1.8511, Final Train Accuracy: 34.45%, Best Train Accuracy: 34.73, Loss to best acc:1.80%
#
# Epoch [39/100], Final Valid Loss: 2.2650, Final Valid Accuracy: 18.84%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [40/100], Final Train Loss: 1.7982, Final Train Accuracy: 34.83%, Best Train Accuracy: 34.83, Loss to best acc:1.80%
#
# Epoch [40/100], Final Valid Loss: 2.1431, Final Valid Accuracy: 18.82%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [41/100], Final Train Loss: 1.7272, Final Train Accuracy: 34.86%, Best Train Accuracy: 34.86, Loss to best acc:1.73%
#
# Epoch [41/100], Final Valid Loss: 2.2039, Final Valid Accuracy: 18.84%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [42/100], Final Train Loss: 1.6935, Final Train Accuracy: 35.36%, Best Train Accuracy: 35.36, Loss to best acc:1.69%
#
# Epoch [42/100], Final Valid Loss: 2.1844, Final Valid Accuracy: 18.79%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [43/100], Final Train Loss: 1.8133, Final Train Accuracy: 34.96%, Best Train Accuracy: 35.36, Loss to best acc:1.69%
#
# Epoch [43/100], Final Valid Loss: 2.1783, Final Valid Accuracy: 18.80%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [44/100], Final Train Loss: 1.8176, Final Train Accuracy: 34.86%, Best Train Accuracy: 35.36, Loss to best acc:1.69%
#
# Epoch [44/100], Final Valid Loss: 2.2110, Final Valid Accuracy: 18.78%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [45/100], Final Train Loss: 1.7857, Final Train Accuracy: 34.90%, Best Train Accuracy: 35.36, Loss to best acc:1.69%
#
# Epoch [45/100], Final Valid Loss: 2.2359, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [46/100], Final Train Loss: 1.8645, Final Train Accuracy: 34.96%, Best Train Accuracy: 35.36, Loss to best acc:1.69%
#
# Epoch [46/100], Final Valid Loss: 2.2420, Final Valid Accuracy: 18.62%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [47/100], Final Train Loss: 1.7240, Final Train Accuracy: 35.49%, Best Train Accuracy: 35.49, Loss to best acc:1.72%
#
# Epoch [47/100], Final Valid Loss: 2.1507, Final Valid Accuracy: 18.61%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [48/100], Final Train Loss: 1.8378, Final Train Accuracy: 35.91%, Best Train Accuracy: 35.91, Loss to best acc:1.84%
#
# Epoch [48/100], Final Valid Loss: 2.0749, Final Valid Accuracy: 18.72%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [49/100], Final Train Loss: 1.7429, Final Train Accuracy: 35.82%, Best Train Accuracy: 35.91, Loss to best acc:1.84%
#
# Epoch [49/100], Final Valid Loss: 2.2218, Final Valid Accuracy: 18.65%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [50/100], Final Train Loss: 1.6882, Final Train Accuracy: 35.81%, Best Train Accuracy: 35.91, Loss to best acc:1.84%
#
# Epoch [50/100], Final Valid Loss: 2.2744, Final Valid Accuracy: 18.56%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [51/100], Final Train Loss: 1.8061, Final Train Accuracy: 35.76%, Best Train Accuracy: 35.91, Loss to best acc:1.84%
#
# Epoch [51/100], Final Valid Loss: 2.1779, Final Valid Accuracy: 18.67%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [52/100], Final Train Loss: 1.8015, Final Train Accuracy: 35.72%, Best Train Accuracy: 35.91, Loss to best acc:1.84%
#
# Epoch [52/100], Final Valid Loss: 2.1510, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [53/100], Final Train Loss: 1.7902, Final Train Accuracy: 35.63%, Best Train Accuracy: 35.91, Loss to best acc:1.84%
#
# Epoch [53/100], Final Valid Loss: 2.2303, Final Valid Accuracy: 18.76%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [54/100], Final Train Loss: 1.6584, Final Train Accuracy: 35.41%, Best Train Accuracy: 35.91, Loss to best acc:1.84%
#
# Epoch [54/100], Final Valid Loss: 2.1535, Final Valid Accuracy: 18.79%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [55/100], Final Train Loss: 1.8051, Final Train Accuracy: 35.87%, Best Train Accuracy: 35.91, Loss to best acc:1.84%
#
# Epoch [55/100], Final Valid Loss: 2.1697, Final Valid Accuracy: 18.83%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [56/100], Final Train Loss: 1.7977, Final Train Accuracy: 35.79%, Best Train Accuracy: 35.91, Loss to best acc:1.84%
#
# Epoch [56/100], Final Valid Loss: 2.1259, Final Valid Accuracy: 18.88%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [57/100], Final Train Loss: 1.7138, Final Train Accuracy: 36.28%, Best Train Accuracy: 36.28, Loss to best acc:1.71%
#
# Epoch [57/100], Final Valid Loss: 2.2628, Final Valid Accuracy: 18.79%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [58/100], Final Train Loss: 1.7809, Final Train Accuracy: 36.43%, Best Train Accuracy: 36.43, Loss to best acc:1.78%
#
# Epoch [58/100], Final Valid Loss: 2.2053, Final Valid Accuracy: 18.73%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [59/100], Final Train Loss: 1.7003, Final Train Accuracy: 36.47%, Best Train Accuracy: 36.47, Loss to best acc:1.70%
#
# Epoch [59/100], Final Valid Loss: 2.1507, Final Valid Accuracy: 18.79%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [60/100], Final Train Loss: 1.8293, Final Train Accuracy: 35.92%, Best Train Accuracy: 36.47, Loss to best acc:1.70%
#
# Epoch [60/100], Final Valid Loss: 2.2073, Final Valid Accuracy: 18.80%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [61/100], Final Train Loss: 1.6116, Final Train Accuracy: 36.10%, Best Train Accuracy: 36.47, Loss to best acc:1.70%
#
# Epoch [61/100], Final Valid Loss: 2.1189, Final Valid Accuracy: 18.84%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [62/100], Final Train Loss: 1.6527, Final Train Accuracy: 35.99%, Best Train Accuracy: 36.47, Loss to best acc:1.70%
#
# Epoch [62/100], Final Valid Loss: 2.1520, Final Valid Accuracy: 18.85%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [63/100], Final Train Loss: 1.6862, Final Train Accuracy: 36.65%, Best Train Accuracy: 36.65, Loss to best acc:1.69%
#
# Epoch [63/100], Final Valid Loss: 2.1980, Final Valid Accuracy: 18.82%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [64/100], Final Train Loss: 1.6976, Final Train Accuracy: 36.21%, Best Train Accuracy: 36.65, Loss to best acc:1.69%
#
# Epoch [64/100], Final Valid Loss: 2.1685, Final Valid Accuracy: 18.86%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [65/100], Final Train Loss: 1.7955, Final Train Accuracy: 36.30%, Best Train Accuracy: 36.65, Loss to best acc:1.69%
#
# Epoch [65/100], Final Valid Loss: 2.2673, Final Valid Accuracy: 18.76%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [66/100], Final Train Loss: 1.7711, Final Train Accuracy: 35.96%, Best Train Accuracy: 36.65, Loss to best acc:1.69%
#
# Epoch [66/100], Final Valid Loss: 2.2675, Final Valid Accuracy: 18.79%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [67/100], Final Train Loss: 1.6734, Final Train Accuracy: 36.47%, Best Train Accuracy: 36.65, Loss to best acc:1.69%
#
# Epoch [67/100], Final Valid Loss: 2.1765, Final Valid Accuracy: 18.79%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [68/100], Final Train Loss: 1.7507, Final Train Accuracy: 36.49%, Best Train Accuracy: 36.65, Loss to best acc:1.69%
#
# Epoch [68/100], Final Valid Loss: 2.2395, Final Valid Accuracy: 18.73%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [69/100], Final Train Loss: 1.6923, Final Train Accuracy: 36.88%, Best Train Accuracy: 36.88, Loss to best acc:1.69%
#
# Epoch [69/100], Final Valid Loss: 2.2295, Final Valid Accuracy: 18.73%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [70/100], Final Train Loss: 1.8653, Final Train Accuracy: 36.37%, Best Train Accuracy: 36.88, Loss to best acc:1.69%
#
# Epoch [70/100], Final Valid Loss: 2.2266, Final Valid Accuracy: 18.77%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [71/100], Final Train Loss: 1.8061, Final Train Accuracy: 36.29%, Best Train Accuracy: 36.88, Loss to best acc:1.69%
#
# Epoch [71/100], Final Valid Loss: 2.1782, Final Valid Accuracy: 18.77%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [72/100], Final Train Loss: 1.8220, Final Train Accuracy: 37.12%, Best Train Accuracy: 37.12, Loss to best acc:1.82%
#
# Epoch [72/100], Final Valid Loss: 2.1669, Final Valid Accuracy: 18.81%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [73/100], Final Train Loss: 1.8241, Final Train Accuracy: 36.78%, Best Train Accuracy: 37.12, Loss to best acc:1.82%
#
# Epoch [73/100], Final Valid Loss: 2.1880, Final Valid Accuracy: 18.81%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [74/100], Final Train Loss: 1.7092, Final Train Accuracy: 36.53%, Best Train Accuracy: 37.12, Loss to best acc:1.82%
#
# Epoch [74/100], Final Valid Loss: 2.1923, Final Valid Accuracy: 18.81%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [75/100], Final Train Loss: 1.7019, Final Train Accuracy: 37.02%, Best Train Accuracy: 37.12, Loss to best acc:1.82%
#
# Epoch [75/100], Final Valid Loss: 2.2344, Final Valid Accuracy: 18.80%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [76/100], Final Train Loss: 1.7315, Final Train Accuracy: 36.43%, Best Train Accuracy: 37.12, Loss to best acc:1.82%
#
# Epoch [76/100], Final Valid Loss: 2.2004, Final Valid Accuracy: 18.78%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [77/100], Final Train Loss: 1.7411, Final Train Accuracy: 37.28%, Best Train Accuracy: 37.28, Loss to best acc:1.74%
#
# Epoch [77/100], Final Valid Loss: 2.1712, Final Valid Accuracy: 18.76%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [78/100], Final Train Loss: 1.8476, Final Train Accuracy: 36.98%, Best Train Accuracy: 37.28, Loss to best acc:1.74%
#
# Epoch [78/100], Final Valid Loss: 2.2730, Final Valid Accuracy: 18.74%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [79/100], Final Train Loss: 1.7922, Final Train Accuracy: 36.96%, Best Train Accuracy: 37.28, Loss to best acc:1.74%
#
# Epoch [79/100], Final Valid Loss: 2.2237, Final Valid Accuracy: 18.71%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [80/100], Final Train Loss: 1.7536, Final Train Accuracy: 37.49%, Best Train Accuracy: 37.49, Loss to best acc:1.75%
#
# Epoch [80/100], Final Valid Loss: 2.1378, Final Valid Accuracy: 18.75%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [81/100], Final Train Loss: 1.6562, Final Train Accuracy: 36.82%, Best Train Accuracy: 37.49, Loss to best acc:1.75%
#
# Epoch [81/100], Final Valid Loss: 2.2100, Final Valid Accuracy: 18.77%, Best Valid Accuracy: 19.30%, Loss to best Valid accuracy:2.19
#
# Epoch [82/100], Final Train Loss: 1.7868, Final Train Accuracy: 37.42%, Best Train Accuracy: 37.49, Loss to best acc:1.75%
#
# ...
#
# Epoch [41/100], Final Train Loss: 0.7918, Final Train Accuracy: 72.11%, Best Train Accuracy: 72.49, Loss to best acc:0.65%
#
# Epoch [41/100], Final Valid Loss: 2.5079, Final Valid Accuracy: 22.99%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [42/100], Final Train Loss: 0.8076, Final Train Accuracy: 72.30%, Best Train Accuracy: 72.49, Loss to best acc:0.65%
#
# Epoch [42/100], Final Valid Loss: 2.1312, Final Valid Accuracy: 23.08%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [43/100], Final Train Loss: 0.7610, Final Train Accuracy: 73.19%, Best Train Accuracy: 73.19, Loss to best acc:0.76%
#
# Epoch [43/100], Final Valid Loss: 2.2342, Final Valid Accuracy: 23.00%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [44/100], Final Train Loss: 0.8178, Final Train Accuracy: 73.34%, Best Train Accuracy: 73.34, Loss to best acc:0.82%
#
# Epoch [44/100], Final Valid Loss: 2.3342, Final Valid Accuracy: 22.86%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [45/100], Final Train Loss: 0.8075, Final Train Accuracy: 74.12%, Best Train Accuracy: 74.12, Loss to best acc:0.81%
#
# Epoch [45/100], Final Valid Loss: 2.3312, Final Valid Accuracy: 22.83%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [46/100], Final Train Loss: 0.7529, Final Train Accuracy: 74.06%, Best Train Accuracy: 74.12, Loss to best acc:0.81%
#
# Epoch [46/100], Final Valid Loss: 2.2241, Final Valid Accuracy: 22.87%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [47/100], Final Train Loss: 0.9095, Final Train Accuracy: 73.87%, Best Train Accuracy: 74.12, Loss to best acc:0.81%
#
# Epoch [47/100], Final Valid Loss: 2.1643, Final Valid Accuracy: 22.93%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [48/100], Final Train Loss: 0.7168, Final Train Accuracy: 74.34%, Best Train Accuracy: 74.34, Loss to best acc:0.72%
#
# Epoch [48/100], Final Valid Loss: 2.2746, Final Valid Accuracy: 22.98%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [49/100], Final Train Loss: 0.6798, Final Train Accuracy: 74.32%, Best Train Accuracy: 74.34, Loss to best acc:0.72%
#
# Epoch [49/100], Final Valid Loss: 2.3613, Final Valid Accuracy: 22.96%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [50/100], Final Train Loss: 0.7719, Final Train Accuracy: 74.85%, Best Train Accuracy: 74.85, Loss to best acc:0.77%
#
# Epoch [50/100], Final Valid Loss: 2.2437, Final Valid Accuracy: 22.96%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [51/100], Final Train Loss: 0.6877, Final Train Accuracy: 75.28%, Best Train Accuracy: 75.28, Loss to best acc:0.69%
#
# Epoch [51/100], Final Valid Loss: 2.1991, Final Valid Accuracy: 22.97%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [52/100], Final Train Loss: 0.6807, Final Train Accuracy: 74.56%, Best Train Accuracy: 75.28, Loss to best acc:0.69%
#
# Epoch [52/100], Final Valid Loss: 2.3341, Final Valid Accuracy: 22.89%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [53/100], Final Train Loss: 0.8396, Final Train Accuracy: 74.61%, Best Train Accuracy: 75.28, Loss to best acc:0.69%
#
# Epoch [53/100], Final Valid Loss: 2.2806, Final Valid Accuracy: 22.85%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [54/100], Final Train Loss: 0.9767, Final Train Accuracy: 73.92%, Best Train Accuracy: 75.28, Loss to best acc:0.69%
#
# Epoch [54/100], Final Valid Loss: 2.2118, Final Valid Accuracy: 22.91%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [55/100], Final Train Loss: 0.7845, Final Train Accuracy: 74.71%, Best Train Accuracy: 75.28, Loss to best acc:0.69%
#
# Epoch [55/100], Final Valid Loss: 2.2358, Final Valid Accuracy: 22.87%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [56/100], Final Train Loss: 0.8635, Final Train Accuracy: 75.42%, Best Train Accuracy: 75.42, Loss to best acc:0.86%
#
# Epoch [56/100], Final Valid Loss: 2.3939, Final Valid Accuracy: 22.80%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [57/100], Final Train Loss: 0.7765, Final Train Accuracy: 75.42%, Best Train Accuracy: 75.42, Loss to best acc:0.86%
#
# Epoch [57/100], Final Valid Loss: 2.1509, Final Valid Accuracy: 22.85%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [58/100], Final Train Loss: 0.8062, Final Train Accuracy: 76.25%, Best Train Accuracy: 76.25, Loss to best acc:0.81%
#
# Epoch [58/100], Final Valid Loss: 2.1253, Final Valid Accuracy: 22.93%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [59/100], Final Train Loss: 0.7257, Final Train Accuracy: 76.20%, Best Train Accuracy: 76.25, Loss to best acc:0.81%
#
# Epoch [59/100], Final Valid Loss: 2.3513, Final Valid Accuracy: 22.88%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [60/100], Final Train Loss: 0.6684, Final Train Accuracy: 76.43%, Best Train Accuracy: 76.43, Loss to best acc:0.67%
#
# Epoch [60/100], Final Valid Loss: 2.2958, Final Valid Accuracy: 22.91%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [61/100], Final Train Loss: 0.6560, Final Train Accuracy: 76.76%, Best Train Accuracy: 76.76, Loss to best acc:0.66%
#
# Epoch [61/100], Final Valid Loss: 2.1775, Final Valid Accuracy: 22.97%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [62/100], Final Train Loss: 0.5890, Final Train Accuracy: 76.63%, Best Train Accuracy: 76.76, Loss to best acc:0.66%
#
# Epoch [62/100], Final Valid Loss: 2.1906, Final Valid Accuracy: 23.02%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [63/100], Final Train Loss: 0.7715, Final Train Accuracy: 75.72%, Best Train Accuracy: 76.76, Loss to best acc:0.66%
#
# Epoch [63/100], Final Valid Loss: 2.2474, Final Valid Accuracy: 23.00%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [64/100], Final Train Loss: 0.7300, Final Train Accuracy: 76.52%, Best Train Accuracy: 76.76, Loss to best acc:0.66%
#
# Epoch [64/100], Final Valid Loss: 2.1877, Final Valid Accuracy: 22.99%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [65/100], Final Train Loss: 0.7215, Final Train Accuracy: 77.36%, Best Train Accuracy: 77.36, Loss to best acc:0.72%
#
# Epoch [65/100], Final Valid Loss: 2.3479, Final Valid Accuracy: 22.96%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [66/100], Final Train Loss: 0.7396, Final Train Accuracy: 75.43%, Best Train Accuracy: 77.36, Loss to best acc:0.72%
#
# Epoch [66/100], Final Valid Loss: 2.3074, Final Valid Accuracy: 22.88%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [67/100], Final Train Loss: 0.8115, Final Train Accuracy: 77.24%, Best Train Accuracy: 77.36, Loss to best acc:0.72%
#
# Epoch [67/100], Final Valid Loss: 2.2219, Final Valid Accuracy: 22.90%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [68/100], Final Train Loss: 0.7429, Final Train Accuracy: 76.94%, Best Train Accuracy: 77.36, Loss to best acc:0.72%
#
# Epoch [68/100], Final Valid Loss: 2.2593, Final Valid Accuracy: 22.87%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [69/100], Final Train Loss: 0.7464, Final Train Accuracy: 76.33%, Best Train Accuracy: 77.36, Loss to best acc:0.72%
#
# Epoch [69/100], Final Valid Loss: 2.2473, Final Valid Accuracy: 22.87%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [70/100], Final Train Loss: 0.6261, Final Train Accuracy: 77.04%, Best Train Accuracy: 77.36, Loss to best acc:0.72%
#
# Epoch [70/100], Final Valid Loss: 2.3225, Final Valid Accuracy: 22.89%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [71/100], Final Train Loss: 0.6184, Final Train Accuracy: 77.33%, Best Train Accuracy: 77.36, Loss to best acc:0.72%
#
# Epoch [71/100], Final Valid Loss: 2.2234, Final Valid Accuracy: 22.92%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [72/100], Final Train Loss: 0.5895, Final Train Accuracy: 77.94%, Best Train Accuracy: 77.94, Loss to best acc:0.59%
#
# Epoch [72/100], Final Valid Loss: 2.3318, Final Valid Accuracy: 22.88%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [73/100], Final Train Loss: 0.7060, Final Train Accuracy: 77.92%, Best Train Accuracy: 77.94, Loss to best acc:0.59%
#
# Epoch [73/100], Final Valid Loss: 2.2561, Final Valid Accuracy: 22.90%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [74/100], Final Train Loss: 0.7427, Final Train Accuracy: 77.51%, Best Train Accuracy: 77.94, Loss to best acc:0.59%
#
# Epoch [74/100], Final Valid Loss: 2.2724, Final Valid Accuracy: 22.90%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [75/100], Final Train Loss: 0.7190, Final Train Accuracy: 78.34%, Best Train Accuracy: 78.34, Loss to best acc:0.72%
#
# Epoch [75/100], Final Valid Loss: 2.2863, Final Valid Accuracy: 22.89%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [76/100], Final Train Loss: 0.6668, Final Train Accuracy: 78.06%, Best Train Accuracy: 78.34, Loss to best acc:0.72%
#
# Epoch [76/100], Final Valid Loss: 2.2202, Final Valid Accuracy: 22.89%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [77/100], Final Train Loss: 0.6987, Final Train Accuracy: 78.22%, Best Train Accuracy: 78.34, Loss to best acc:0.72%
#
# Epoch [77/100], Final Valid Loss: 2.3133, Final Valid Accuracy: 22.86%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [78/100], Final Train Loss: 0.7350, Final Train Accuracy: 78.16%, Best Train Accuracy: 78.34, Loss to best acc:0.72%
#
# Epoch [78/100], Final Valid Loss: 2.3003, Final Valid Accuracy: 22.85%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [79/100], Final Train Loss: 0.7669, Final Train Accuracy: 78.46%, Best Train Accuracy: 78.46, Loss to best acc:0.77%
#
# Epoch [79/100], Final Valid Loss: 2.1167, Final Valid Accuracy: 22.94%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [80/100], Final Train Loss: 0.6611, Final Train Accuracy: 78.22%, Best Train Accuracy: 78.46, Loss to best acc:0.77%
#
# Epoch [80/100], Final Valid Loss: 2.4377, Final Valid Accuracy: 22.93%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [81/100], Final Train Loss: 0.5767, Final Train Accuracy: 78.14%, Best Train Accuracy: 78.46, Loss to best acc:0.77%
#
# Epoch [81/100], Final Valid Loss: 2.2804, Final Valid Accuracy: 22.94%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [82/100], Final Train Loss: 0.6412, Final Train Accuracy: 78.12%, Best Train Accuracy: 78.46, Loss to best acc:0.77%
#
# Epoch [82/100], Final Valid Loss: 2.2460, Final Valid Accuracy: 22.95%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [83/100], Final Train Loss: 0.5703, Final Train Accuracy: 79.15%, Best Train Accuracy: 79.15, Loss to best acc:0.57%
#
# Epoch [83/100], Final Valid Loss: 2.3157, Final Valid Accuracy: 22.97%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [84/100], Final Train Loss: 0.6470, Final Train Accuracy: 78.58%, Best Train Accuracy: 79.15, Loss to best acc:0.57%
#
# Epoch [84/100], Final Valid Loss: 2.2929, Final Valid Accuracy: 22.94%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [85/100], Final Train Loss: 0.6150, Final Train Accuracy: 78.71%, Best Train Accuracy: 79.15, Loss to best acc:0.57%
#
# Epoch [85/100], Final Valid Loss: 2.2567, Final Valid Accuracy: 22.98%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [86/100], Final Train Loss: 0.6216, Final Train Accuracy: 78.59%, Best Train Accuracy: 79.15, Loss to best acc:0.57%
#
# Epoch [86/100], Final Valid Loss: 2.1865, Final Valid Accuracy: 23.02%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [87/100], Final Train Loss: 0.6677, Final Train Accuracy: 78.64%, Best Train Accuracy: 79.15, Loss to best acc:0.57%
#
# Epoch [87/100], Final Valid Loss: 2.2258, Final Valid Accuracy: 23.01%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [88/100], Final Train Loss: 0.7911, Final Train Accuracy: 78.58%, Best Train Accuracy: 79.15, Loss to best acc:0.57%
#
# Epoch [88/100], Final Valid Loss: 2.3151, Final Valid Accuracy: 23.01%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [89/100], Final Train Loss: 0.7185, Final Train Accuracy: 78.59%, Best Train Accuracy: 79.15, Loss to best acc:0.57%
#
# Epoch [89/100], Final Valid Loss: 2.2033, Final Valid Accuracy: 23.04%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [90/100], Final Train Loss: 0.6395, Final Train Accuracy: 78.86%, Best Train Accuracy: 79.15, Loss to best acc:0.57%
#
# Epoch [90/100], Final Valid Loss: 2.2642, Final Valid Accuracy: 23.03%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [91/100], Final Train Loss: 0.6505, Final Train Accuracy: 78.91%, Best Train Accuracy: 79.15, Loss to best acc:0.57%
#
# Epoch [91/100], Final Valid Loss: 2.1756, Final Valid Accuracy: 23.06%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [92/100], Final Train Loss: 0.5504, Final Train Accuracy: 79.01%, Best Train Accuracy: 79.15, Loss to best acc:0.57%
#
# Epoch [92/100], Final Valid Loss: 2.2378, Final Valid Accuracy: 23.04%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [93/100], Final Train Loss: 0.6257, Final Train Accuracy: 79.12%, Best Train Accuracy: 79.15, Loss to best acc:0.57%
#
# Epoch [93/100], Final Valid Loss: 2.2687, Final Valid Accuracy: 23.03%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [94/100], Final Train Loss: 0.7338, Final Train Accuracy: 79.63%, Best Train Accuracy: 79.63, Loss to best acc:0.73%
#
# Epoch [94/100], Final Valid Loss: 2.2046, Final Valid Accuracy: 23.05%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [95/100], Final Train Loss: 0.5767, Final Train Accuracy: 80.05%, Best Train Accuracy: 80.05, Loss to best acc:0.58%
#
# Epoch [95/100], Final Valid Loss: 2.3631, Final Valid Accuracy: 23.06%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [96/100], Final Train Loss: 0.6767, Final Train Accuracy: 79.35%, Best Train Accuracy: 80.05, Loss to best acc:0.58%
#
# Epoch [96/100], Final Valid Loss: 2.3874, Final Valid Accuracy: 23.03%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [97/100], Final Train Loss: 0.7256, Final Train Accuracy: 79.05%, Best Train Accuracy: 80.05, Loss to best acc:0.58%
#
# Epoch [97/100], Final Valid Loss: 2.3821, Final Valid Accuracy: 23.04%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [98/100], Final Train Loss: 0.7571, Final Train Accuracy: 79.66%, Best Train Accuracy: 80.05, Loss to best acc:0.58%
#
# Epoch [98/100], Final Valid Loss: 2.2958, Final Valid Accuracy: 23.08%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [99/100], Final Train Loss: 0.6713, Final Train Accuracy: 79.85%, Best Train Accuracy: 80.05, Loss to best acc:0.58%
#
# Epoch [99/100], Final Valid Loss: 2.3552, Final Valid Accuracy: 23.10%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# Epoch [100/100], Final Train Loss: 0.6218, Final Train Accuracy: 79.60%, Best Train Accuracy: 80.05, Loss to best acc:0.58%
#
# Epoch [100/100], Final Valid Loss: 2.2232, Final Valid Accuracy: 23.12%, Best Valid Accuracy: 27.40%, Loss to best Valid accuracy:2.13
#
# 模型参数已保存为LP-RL-model_scale=0.9.pth
#
# {'训练的模型的保留路径': 'LP-RL-model_scale=0.9.pth', '在测试集中的最终损失': 2.1318132877349854, '在测试集中的最终准确率': 0.23123, '在测试集中的最佳准确率': 0.274, '在训练集中的最终准确率': 0.79604, '在训练集中的最佳准确率': 0.80048, '在训练集中的最终损失': 0.6218470335006714, '在训练集中的最佳损失': 0.5766631960868835}
