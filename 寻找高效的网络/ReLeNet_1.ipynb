# %% [markdown]
# # 提高模型准确率
#
# 之前的模型不知道为啥,准确率都低的吓人,这次采用如下的配置,希望可以有一点提高:
#
# 1. MLP,调用support_code里面的MLP
# 2. 依然采用SDG
# 3. 采用CosineAnnealingLR动态调整学习率

# %%
# 加载各种库
import torch
import os
import pickle   # 保存列表
import torch.nn as nn
from torchvision.transforms import ToTensor
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
import torchvision
from torchvision.datasets import CIFAR10
import numpy as np
import random
from torch.optim.lr_scheduler import CosineAnnealingLR  # 实现cos函数式的变化
# 加载支持函数和类
from support_code.load_dataset import get_data_loader
from support_code.MLP import MLP
# 设置设备和种子
device_cuda = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# 设置随机种子
seed = 10  # 你可以选择任何整数作为种子值

# 设置PyTorch随机种子
torch.manual_seed(seed)

# 设置CUDA随机种子（如果使用GPU）
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# 设置Numpy随机种子
np.random.seed(seed)

# 设置Python随机种子
random.seed(seed)

# %%
def get_scale(scale, writer,  
            device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu"), train_loader=None, valid_loader=None, test_loader=None, 
            channel=3,
            num_classes=10,
            im_size=(32, 32),
            # 可能需要的超参数
            momentum = 0.9,
            weight_decay = 0.0005,
            initial_lr = 0.1,
            num_epochs = 100):

  # -------------------------------------------------创建模型实例并将其移至 GPU -----------------------------------------------------
  model = MLP(channel=channel, num_classes=num_classes, im_size=im_size)
  model.to(device)
  # 定义损失函数/优化器/学习率
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(model.parameters(), lr=initial_lr, weight_decay=weight_decay, momentum=momentum)
  scheduler = CosineAnnealingLR(optimizer, T_max=10)

  # 记录训练过程中的准确率和损失
  tag_loss = "train_loss_{}".format(scale)
  tag_acc = "train_accuracy_{}".format(scale)

  # 训练循环...
  final_train_loss = 0
  final_train_acc = 0
  best_train_acc = 0.0  # 用于跟踪一个scale也就是一个完整的train的过程中的最佳准确率

  # 验证步骤...
  # 记录验证的次数
  valid_correct = 0
  valid_total = 0
  best_valid_acc = 0.0
  val_loss = "val_loss_{}".format(scale)
  val_acc = "val_accuracy_{}".format(scale)
  acc = 0.0
  loss = 1.0

  for epoch in range(num_epochs):

    # ----------------------------首先是训练过程----------------------------
    train_correct = 0
    train_total = 0
    for batch_idx, (imgs, targets) in enumerate(train_loader):
      imgs, targets = imgs.to(device), targets.to(device)
      outputs = model(imgs)
      loss = criterion(outputs, targets)
      _, predicted = torch.max(outputs, 1)
      train_total += targets.size(0)
      train_correct += (predicted == targets).sum().item()
      optimizer.zero_grad() # W_new = W_old + \gamma \times \deta W_old,这里相当于先要求\gamma 为零矩阵
      loss.backward()   # 使用backward得到了\deta W_old
      optimizer.step()  # 选择合适的\gamma 得到了W_new
      scheduler.step()  # \gamma 事实上是一个依赖于learning_rate的一个矩阵函数,这里更新了learning_rate,而且learning_rate的更新是依赖于epoch的

    acc = train_correct / train_total
    writer.add_scalar(tag_loss, loss.item(), epoch)
    writer.add_scalar(tag_acc, acc, epoch)
    # 更新模型权重并记录到Tensorboard
    for name, param in model.named_parameters():
      writer.add_histogram(name, param.clone().cpu().data.numpy(), epoch)
    final_train_acc = train_correct / train_total
    # 更新最佳准确率,以及对应的loss
    if final_train_acc >= best_train_acc:
      best_train_acc = final_train_acc
      best_train_loss = loss.item()
    final_train_loss = loss.item()
    print("Epoch [{}/{}], Final Train Loss: {:.4f}, Final Train Accuracy: {:.2f}%, Best Train Accuracy: {:.2f}, Loss to best acc:{:.2f}%".format(epoch+1, num_epochs, final_train_loss, final_train_acc * 100, best_train_acc * 100, best_train_loss),"\n")
    # 记录学习率(learning_rate)的更新情况
    writer.add_scalar("learning_rate",optimizer.param_groups[0]['lr'])

    # -------------------------然后进入了验证步骤---------------------------------
    for batch_idx, (imgs, targets) in enumerate(valid_loader):
      imgs, targets = imgs.to(device), targets.to(device)
      outputs = model(imgs)
      loss = criterion(outputs, targets)
      _, predicted = torch.max(outputs, 1)
      valid_total += targets.size(0)
      valid_correct += (predicted == targets).sum().item()
      acc = valid_correct / valid_total

    writer.add_scalar(val_loss, loss.item(), epoch)
    writer.add_scalar(val_acc, acc, epoch)
    # 记录valid中的最终情况
    final_valid_acc = acc
    final_valid_loss = loss
    # 更新最佳准确率,以及对应的loss
    if final_valid_acc >= best_valid_acc:
      best_valid_acc = final_valid_acc
      best_valid_loss = loss.item()
    final_valid_loss = loss.item()
    print("Epoch [{}/{}], Final Valid Loss: {:.4f}, Final Valid Accuracy: {:.2f}%, Best Valid Accuracy: {:.2f}%, Loss to best Valid accuracy:{:.2f}".format(epoch+1, num_epochs, final_valid_loss, final_valid_acc * 100, best_valid_acc * 100, best_valid_loss),"\n")


  # 记录train过程中的最终情况
  writer.add_scalar("final_train_loss", final_train_loss, scale)
  writer.add_scalar("final_train_acc", final_train_acc, scale)
  writer.add_scalar("best_train_acc", best_train_acc, scale)
  writer.add_scalar("best_train_loss", best_train_loss, scale)
  # 记录valid的最终情况
  writer.add_scalar("final_valid_loss", final_valid_loss, scale)
  writer.add_scalar("final_valid_acc", final_valid_acc, scale)
  writer.add_scalar("best_valid_acc", best_valid_acc, scale)
  writer.add_scalar("best_valid_loss", best_valid_loss, scale)

  # -------------------------------保存模型,并且指定保存目录-----------------------------
  # filename = "scale{}.pth".format(scale)
  filename = "scale=1.0-512.pth"
  # 保存模型
  torch.save(model.state_dict(), filename)
  print("模型参数已保存为{}".format(filename), '\n')

  # 完成各种工作，记录结果...
  normal_dict = {
      "训练的模型的保留路径": filename,
      "在测试集中的最终损失": final_valid_loss,
      "在测试集中的最终损失":best_valid_loss,
      "在测试集中的最终准确率": final_valid_acc,
      "在测试集中的最佳准确率": best_valid_acc,
      "在训练集中的最终准确率": final_train_acc,
      "在训练集中的最佳准确率": best_train_acc,
      "在训练集中的最终损失": final_train_loss,
      "在训练集中的最佳损失":best_train_loss
  }
  return normal_dict

# %%
# 添加tensorboard
writer_new = SummaryWriter("scale_1_512")

scale=1.0
train_loader, valid_loader, test_loader = get_data_loader(scale, valid_scale=0.1)
dic = {}
print("--------------------开始scale={}的情况---------------------".format(scale), "\n")
dic['sacle={}'.format(scale)] = get_scale(scale=scale, writer=writer_new, train_loader=train_loader, valid_loader=valid_loader, num_epochs=300)
print(dic['sacle={}'.format(scale)])


writer_new.close()
# -------------------------------------保存列表,因为我发现notebook不是很可靠-----------------------------
# 指定保存文件的文件夹和文件名
folder_path = "scale_1_512"
file_name = "dic_scale_512.pkl"

# 确保文件夹存在，如果不存在则创建它
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# 组合文件夹路径和文件名
dic_file_path = os.path.join(folder_path, file_name)

with open(dic_file_path, "wb") as file:
  pickle.dump(dic, file=file)

print("字典保存在文件中")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# --------------------开始scale=1.0的情况---------------------
#
# Epoch [1/300], Final Train Loss: 1.5967, Final Train Accuracy: 37.27%, Best Train Accuracy: 37.27, Loss to best acc:1.60%
#
# Epoch [1/300], Final Valid Loss: 2.1968, Final Valid Accuracy: 19.00%, Best Valid Accuracy: 19.00%, Loss to best Valid accuracy:2.20
#
# Epoch [2/300], Final Train Loss: 1.3556, Final Train Accuracy: 46.53%, Best Train Accuracy: 46.53, Loss to best acc:1.36%
#
# Epoch [2/300], Final Valid Loss: 2.1599, Final Valid Accuracy: 20.00%, Best Valid Accuracy: 20.00%, Loss to best Valid accuracy:2.16
#
# Epoch [3/300], Final Train Loss: 1.4365, Final Train Accuracy: 50.23%, Best Train Accuracy: 50.23, Loss to best acc:1.44%
#
# Epoch [3/300], Final Valid Loss: 2.1136, Final Valid Accuracy: 21.40%, Best Valid Accuracy: 21.40%, Loss to best Valid accuracy:2.11
#
# Epoch [4/300], Final Train Loss: 1.3588, Final Train Accuracy: 52.27%, Best Train Accuracy: 52.27, Loss to best acc:1.36%
#
# Epoch [4/300], Final Valid Loss: 2.2136, Final Valid Accuracy: 21.93%, Best Valid Accuracy: 21.93%, Loss to best Valid accuracy:2.21
#
# Epoch [5/300], Final Train Loss: 1.3024, Final Train Accuracy: 54.72%, Best Train Accuracy: 54.72, Loss to best acc:1.30%
#
# Epoch [5/300], Final Valid Loss: 2.1471, Final Valid Accuracy: 22.66%, Best Valid Accuracy: 22.66%, Loss to best Valid accuracy:2.15
#
# Epoch [6/300], Final Train Loss: 1.1449, Final Train Accuracy: 56.64%, Best Train Accuracy: 56.64, Loss to best acc:1.14%
#
# Epoch [6/300], Final Valid Loss: 2.1598, Final Valid Accuracy: 22.98%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [7/300], Final Train Loss: 1.1734, Final Train Accuracy: 58.90%, Best Train Accuracy: 58.90, Loss to best acc:1.17%
#
# Epoch [7/300], Final Valid Loss: 2.2000, Final Valid Accuracy: 22.56%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [8/300], Final Train Loss: 1.2397, Final Train Accuracy: 59.75%, Best Train Accuracy: 59.75, Loss to best acc:1.24%
#
# Epoch [8/300], Final Valid Loss: 2.2588, Final Valid Accuracy: 22.05%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [9/300], Final Train Loss: 1.1781, Final Train Accuracy: 61.06%, Best Train Accuracy: 61.06, Loss to best acc:1.18%
#
# Epoch [9/300], Final Valid Loss: 2.1424, Final Valid Accuracy: 22.21%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [10/300], Final Train Loss: 1.0129, Final Train Accuracy: 62.74%, Best Train Accuracy: 62.74, Loss to best acc:1.01%
#
# Epoch [10/300], Final Valid Loss: 2.0988, Final Valid Accuracy: 22.68%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [11/300], Final Train Loss: 0.9232, Final Train Accuracy: 64.49%, Best Train Accuracy: 64.49, Loss to best acc:0.92%
#
# Epoch [11/300], Final Valid Loss: 2.3026, Final Valid Accuracy: 22.22%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [12/300], Final Train Loss: 1.0422, Final Train Accuracy: 65.44%, Best Train Accuracy: 65.44, Loss to best acc:1.04%
#
# Epoch [12/300], Final Valid Loss: 2.1762, Final Valid Accuracy: 22.43%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [13/300], Final Train Loss: 1.0480, Final Train Accuracy: 65.71%, Best Train Accuracy: 65.71, Loss to best acc:1.05%
#
# Epoch [13/300], Final Valid Loss: 2.2047, Final Valid Accuracy: 22.73%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch
, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [28/300], Final Train Loss: 0.6316, Final Train Accuracy: 79.72%, Best Train Accuracy: 79.72, Loss to best acc:0.63%
#
# Epoch [28/300], Final Valid Loss: 2.2575, Final Valid Accuracy: 22.02%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [29/300], Final Train Loss: 0.7399, Final Train Accuracy: 79.73%, Best Train Accuracy: 79.73, Loss to best acc:0.74%
#
# Epoch [29/300], Final Valid Loss: 2.3764, Final Valid Accuracy: 22.11%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [30/300], Final Train Loss: 0.5485, Final Train Accuracy: 80.24%, Best Train Accuracy: 80.24, Loss to best acc:0.55%
#
# Epoch [30/300], Final Valid Loss: 2.3380, Final Valid Accuracy: 22.14%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [31/300], Final Train Loss: 0.6365, Final Train Accuracy: 80.71%, Best Train Accuracy: 80.71, Loss to best acc:0.64%
#
# Epoch [31/300], Final Valid Loss: 2.4487, Final Valid Accuracy: 22.08%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [32/300], Final Train Loss: 0.6039, Final Train Accuracy: 79.74%, Best Train Accuracy: 80.71, Loss to best acc:0.64%
#
# Epoch [32/300], Final Valid Loss: 2.3315, Final Valid Accuracy: 22.13%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [33/300], Final Train Loss: 0.5564, Final Train Accuracy: 81.70%, Best Train Accuracy: 81.70, Loss to best acc:0.56%
#
# Epoch [33/300], Final Valid Loss: 2.2217, Final Valid Accuracy: 22.25%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [34/300], Final Train Loss: 0.5826, Final Train Accuracy: 83.53%, Best Train Accuracy: 83.53, Loss to best acc:0.58%
#
# Epoch [34/300], Final Valid Loss: 2.3238, Final Valid Accuracy: 22.31%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [35/300], Final Train Loss: 0.6249, Final Train Accuracy: 82.24%, Best Train Accuracy: 83.53, Loss to best acc:0.58%
#
# Epoch [35/300], Final Valid Loss: 2.4212, Final Valid Accuracy: 22.32%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [36/300], Final Train Loss: 0.5570, Final Train Accuracy: 82.58%, Best Train Accuracy: 83.53, Loss to best acc:0.58%
#
# Epoch [36/300], Final Valid Loss: 2.3251, Final Valid Accuracy: 22.44%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [37/300], Final Train Loss: 0.5126, Final Train Accuracy: 83.06%, Best Train Accuracy: 83.53, Loss to best acc:0.58%
#
# Epoch [37/300], Final Valid Loss: 2.1799, Final Valid Accuracy: 22.59%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [38/300], Final Train Loss: 0.4306, Final Train Accuracy: 84.99%, Best Train Accuracy: 84.99, Loss to best acc:0.43%
#
# Epoch [38/300], Final Valid Loss: 2.3690, Final Valid Accuracy: 22.61%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [39/300], Final Train Loss: 0.6485, Final Train Accuracy: 85.15%, Best Train Accuracy: 85.15, Loss to best acc:0.65%
#
# Epoch [39/300], Final Valid Loss: 2.4384, Final Valid Accuracy: 22.59%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [40/300], Final Train Loss: 0.4802, Final Train Accuracy: 83.59%, Best Train Accuracy: 85.15, Loss to best acc:0.65%
#
# Epoch [40/300], Final Valid Loss: 2.5010, Final Valid Accuracy: 22.60%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [41/300], Final Train Loss: 0.4651, Final Train Accuracy: 84.55%, Best Train Accuracy: 85.15, Loss to best acc:0.65%
#
# Epoch [41/300], Final Valid Loss: 2.4355, Final Valid Accuracy: 22.58%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [42/300], Final Train Loss: 0.3850, Final Train Accuracy: 84.93%, Best Train Accuracy: 85.15, Loss to best acc:0.65%
#
# Epoch [42/300], Final Valid Loss: 2.4611, Final Valid Accuracy: 22.54%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [43/300], Final Train Loss: 0.5658, Final Train Accuracy: 83.91%, Best Train Accuracy: 85.15, Loss to best acc:0.65%
#
# Epoch [43/300], Final Valid Loss: 2.1944, Final Valid Accuracy: 22.65%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [44/300], Final Train Loss: 0.4878, Final Train Accuracy: 83.99%, Best Train Accuracy: 85.15, Loss to best acc:0.65%
#
# Epoch [44/300], Final Valid Loss: 2.2797, Final Valid Accuracy: 22.78%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [45/300], Final Train Loss: 0.4591, Final Train Accuracy: 85.76%, Best Train Accuracy: 85.76, Loss to best acc:0.46%
#
# Epoch [45/300], Final Valid Loss: 2.3757, Final Valid Accuracy: 22.71%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [46/300], Final Train Loss: 0.3412, Final Train Accuracy: 87.18%, Best Train Accuracy: 87.18, Loss to best acc:0.34%
#
# Epoch [46/300], Final Valid Loss: 2.1122, Final Valid Accuracy: 22.88%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [47/300], Final Train Loss: 0.6156, Final Train Accuracy: 86.88%, Best Train Accuracy: 87.18, Loss to best acc:0.34%
#
# Epoch [47/300], Final Valid Loss: 2.6211, Final Valid Accuracy: 22.94%, Best Valid Accuracy: 22.98%, Loss to best Valid accuracy:2.16
#
# Epoch [48/300], Final Train Loss: 0.6274, Final Train Accuracy: 86.21%, Best Train Accuracy: 87.18, Loss to best acc:0.34%
#
# Epoch [48/300], Final Valid Loss: 2.2229, Final Valid Accuracy: 23.03%, Best Valid Accuracy: 23.03%, Loss to best Valid accuracy:2.22
#
# Epoch [49/300], Final Train Loss: 0.3869, Final Train Accuracy: 85.83%, Best Train Accuracy: 87.18, Loss to best acc:0.34%
#
# Epoch [49/300], Final Valid Loss: 2.4050, Final Valid Accuracy: 23.03%, Best Valid Accuracy: 23.03%, Loss to best Valid accuracy:2.41
#
# Epoch [50/300], Final Train Loss: 0.3562, Final Train Accuracy: 88.02%, Best Train Accuracy: 88.02, Loss to best acc:0.36%
#
# Epoch [50/300], Final Valid Loss: 2.3434, Final Valid Accuracy: 23.11%, Best Valid Accuracy: 23.11%, Loss to best Valid accuracy:2.34
#
# Epoch [51/300], Final Train Loss: 0.4137, Final Train Accuracy: 87.90%, Best Train Accuracy: 88.02, Loss to best acc:0.36%
#
# Epoch [51/300], Final Valid Loss: 2.4275, Final Valid Accuracy: 23.14%, Best Valid Accuracy: 23.14%, Loss to best Valid accuracy:2.43
#
# Epoch [52/300], Final Train Loss: 0.3675, Final Train Accuracy: 87.59%, Best Train Accuracy: 88.02, Loss to best acc:0.36%
#
# Epoch [52/300], Final Valid Loss: 2.1936, Final Valid Accuracy: 23.27%, Best Valid Accuracy: 23.27%, Loss to best Valid accuracy:2.19
#
# Epoch [53/300], Final Train Loss: 0.3674, Final Train Accuracy: 88.25%, Best Train Accuracy: 88.25, Loss to best acc:0.37%
#
# Epoch [53/300], Final Valid Loss: 2.4421, Final Valid Accuracy: 23.29%, Best Valid Accuracy: 23.29%, Loss to best Valid accuracy:2.44
#
# Epoch [54/300], Final Train Loss: 0.4355, Final Train Accuracy: 87.76%, Best Train Accuracy: 88.25, Loss to best acc:0.37%
#
# Epoch [54/300], Final Valid Loss: 2.3718, Final Valid Accuracy: 23.30%, Best Valid Accuracy: 23.30%, Loss to best Valid accuracy:2.37
#
# Epoch [55/300], Final Train Loss: 0.3745, Final Train Accuracy: 88.76%, Best Train Accuracy: 88.76, Loss to best acc:0.37%
#
# Epoch [55/300], Final Valid Loss: 2.3778, Final Valid Accuracy: 23.28%, Best Valid Accuracy: 23.30%, Loss to best Valid accuracy:2.37
#
# Epoch [56/300], Final Train Loss: 0.4514, Final Train Accuracy: 88.16%, Best Train Accuracy: 88.76, Loss to best acc:0.37%
#
# Epoch [56/300], Final Valid Loss: 2.3923, Final Valid Accuracy: 23.28%, Best Valid Accuracy: 23.30%, Loss to best Valid accuracy:2.37
#
# Epoch [57/300], Final Train Loss: 0.6090, Final Train Accuracy: 88.23%, Best Train Accuracy: 88.76, Loss to best acc:0.37%
#
# Epoch [57/300], Final Valid Loss: 2.5801, Final Valid Accuracy: 23.22%, Best Valid Accuracy: 23.30%, Loss to best Valid accuracy:2.37
#
# Epoch [58/300], Final Train Loss: 0.4886, Final Train Accuracy: 88.88%, Best Train Accuracy: 88.88, Loss to best acc:0.49%
#
# Epoch [58/300], Final Valid Loss: 2.1803, Final Valid Accuracy: 23.36%, Best Valid Accuracy: 23.36%, Loss to best Valid accuracy:2.18
#
# Epoch [59/300], Final Train Loss: 0.3618, Final Train Accuracy: 88.53%, Best Train Accuracy: 88.88, Loss to best acc:0.49%
#
# Epoch [59/300], Final Valid Loss: 2.3145, Final Valid Accuracy: 23.44%, Best Valid Accuracy: 23.44%, Loss to best Valid accuracy:2.31
#
# Epoch [60/300], Final Train Loss: 0.5067, Final Train Accuracy: 88.64%, Best Train Accuracy: 88.88, Loss to best acc:0.49%
#
# Epoch [60/300], Final Valid Loss: 2.6059, Final Valid Accuracy: 23.41%, Best Valid Accuracy: 23.44%, Loss to best Valid accuracy:2.31
#
# Epoch [61/300], Final Train Loss: 0.2842, Final Train Accuracy: 86.40%, Best Train Accuracy: 88.88, Loss to best acc:0.49%
#
# Epoch [61/300], Final Valid Loss: 2.4008, Final Valid Accuracy: 23.36%, Best Valid Accuracy: 23.44%, Loss to best Valid accuracy:2.31
#
# Epoch [62/300], Final Train Loss: 0.2641, Final Train Accuracy: 89.42%, Best Train Accuracy: 89.42, Loss to best acc:0.26%
#
# Epoch [62/300], Final Valid Loss: 2.2700, Final Valid Accuracy: 23.43%, Best Valid Accuracy: 23.44%, Loss to best Valid accuracy:2.31
#
# Epoch [63/300], Final Train Loss: 0.3518, Final Train Accuracy: 88.06%, Best Train Accuracy: 89.42, Loss to best acc:0.26%
#
# Epoch [63/300], Final Valid Loss: 2.3115, Final Valid Accuracy: 23.41%, Best Valid Accuracy: 23.44%, Loss to best Valid accuracy:2.31
#
# Epoch [64/300], Final Train Loss: 0.3338, Final Train Accuracy: 89.71%, Best Train Accuracy: 89.71, Loss to best acc:0.33%
#
# Epoch [64/300], Final Valid Loss: 2.3702, Final Valid Accuracy: 23.34%, Best Valid Accuracy: 23.44%, Loss to best Valid accuracy:2.31
#
# Epoch [65/300], Final Train Loss: 0.4153, Final Train Accuracy: 88.98%, Best Train Accuracy: 89.71, Loss to best acc:0.33%
#
# Epoch [65/300], Final Valid Loss: 2.4326, Final Valid Accuracy: 23.30%, Best Valid Accuracy: 23.44%, Loss to best Valid accuracy:2.31
#
# Epoch [66/300], Final Train Loss: 0.3432, Final Train Accuracy: 88.07%, Best Train Accuracy: 89.71, Loss to best acc:0.33%
#
# Epoch [66/300], Final Valid Loss: 2.1555, Final Valid Accuracy: 23.36%, Best Valid Accuracy: 23.44%, Loss to best Valid accuracy:2.31
#
# Epoch [67/300], Final Train Loss: 0.4426, Final Train Accuracy: 88.48%, Best Train Accuracy: 89.71, Loss to best acc:0.33%
#
# Epoch [67/300], Final Valid Loss: 2.3847, Final Valid Accuracy: 23.37%, Best Valid Accuracy: 23.44%, Loss to best Valid accuracy:2.31
#
# Epoch [68/300], Final Train Loss: 0.4857, Final Train Accuracy: 88.14%, Best Train Accuracy: 89.71, Loss to best acc:0.33%
#
# Epoch [68/300], Final Valid Loss: 2.2316, Final Valid Accuracy: 23.42%, Best Valid Accuracy: 23.44%, Loss to best Valid accuracy:2.31
#
# Epoch [69/300], Final Train Loss: 0.3788, Final Train Accuracy: 88.93%, Best Train Accuracy: 89.71, Loss to best acc:0.33%
#
# Epoch [69/300], Final Valid Loss: 2.3379, Final Valid Accuracy: 23.45%, Best Valid Accuracy: 23.45%, Loss to best Valid accuracy:2.34
#
# Epoch [70/300], Final Train Loss: 0.2729, Final Train Accuracy: 89.92%, Best Train Accuracy: 89.92, Loss to best acc:0.27%
#
# Epoch [70/300], Final Valid Loss: 2.2698, Final Valid Accuracy: 23.48%, Best Valid Accuracy: 23.48%, Loss to best Valid accuracy:2.27
#
# Epoch [71/300], Final Train Loss: 0.3169, Final Train Accuracy: 90.77%, Best Train Accuracy: 90.77, Loss to best acc:0.32%
#
# Epoch [71/300], Final Valid Loss: 2.1663, Final Valid Accuracy: 23.54%, Best Valid Accuracy: 23.54%, Loss to best Valid accuracy:2.17
#
# Epoch [72/300], Final Train Loss: 0.1641, Final Train Accuracy: 90.97%, Best Train Accuracy: 90.97, Loss to best acc:0.16%
#
# Epoch [72/300], Final Valid Loss: 2.1792, Final Valid Accuracy: 23.59%, Best Valid Accuracy: 23.59%, Loss to best Valid accuracy:2.18
#
# Epoch [73/300], Final Train Loss: 0.3670, Final Train Accuracy: 91.03%, Best Train Accuracy: 91.03, Loss to best acc:0.37%
#
# Epoch [73/300], Final Valid Loss: 2.3543, Final Valid Accuracy: 23.59%, Best Valid Accuracy: 23.59%, Loss to best Valid accuracy:2.35
#
# Epoch [74/300], Final Train Loss: 0.3536, Final Train Accuracy: 89.53%, Best Train Accuracy: 91.03, Loss to best acc:0.37%
#
# Epoch [74/300], Final Valid Loss: 2.2937, Final Valid Accuracy: 23.62%, Best Valid Accuracy: 23.62%, Loss to best Valid accuracy:2.29
#
# Epoch [75/300], Final Train Loss: 0.3756, Final Train Accuracy: 90.07%, Best Train Accuracy: 91.03, Loss to best acc:0.37%
#
# Epoch [75/300], Final Valid Loss: 2.2967, Final Valid Accuracy: 23.61%, Best Valid Accuracy: 23.62%, Loss to best Valid accuracy:2.29
#
# Epoch [76/300], Final Train Loss: 0.4217, Final Train Accuracy: 89.96%, Best Train Accuracy: 91.03, Loss to best acc:0.37%
#
# Epoch [76/300], Final Valid Loss: 2.4530, Final Valid Accuracy: 23.64%, Best Valid Accuracy: 23.64%, Loss to best Valid accuracy:2.45
#
# Epoch [77/300], Final Train Loss: 0.4360, Final Train Accuracy: 89.72%, Best Train Accuracy: 91.03, Loss to best acc:0.37%
#
# Epoch [77/300], Final Valid Loss: 2.2619, Final Valid Accuracy: 23.63%, Best Valid Accuracy: 23.64%, Loss to best Valid accuracy:2.45
#
# Epoch [78/300], Final Train Loss: 0.5086, Final Train Accuracy: 88.27%, Best Train Accuracy: 91.03, Loss to best acc:0.37%
#
# Epoch [78/300], Final Valid Loss: 2.2790, Final Valid Accuracy: 23.62%, Best Valid Accuracy: 23.64%, Loss to best Valid accuracy:2.45
#
# Epoch [79/300], Final Train Loss: 0.3989, Final Train Accuracy: 90.16%, Best Train Accuracy: 91.03, Loss to best acc:0.37%
#
# Epoch [79/300], Final Valid Loss: 2.4098, Final Valid Accuracy: 23.61%, Best Valid Accuracy: 23.64%, Loss to best Valid accuracy:2.45
#
# Epoch [80/300], Final Train Loss: 0.2514, Final Train Accuracy: 91.03%, Best Train Accuracy: 91.03, Loss to best acc:0.25%
#
# Epoch [80/300], Final Valid Loss: 2.2738, Final Valid Accuracy: 23.60%, Best Valid Accuracy: 23.64%, Loss to best Valid accuracy:2.45
#
# Epoch [81/300], Final Train Loss: 0.2683, Final Train Accuracy: 90.15%, Best Train Accuracy: 91.03, Loss to best acc:0.25%
#
# Epoch [81/300], Final Valid Loss: 2.3965, Final Valid Accuracy: 23.62%, Best Valid Accuracy: 23.64%, Loss to best Valid accuracy:2.45
#
# Epoch [82/300], Final Train Loss: 0.1450, Final Train Accuracy: 90.09%, Best Train Accuracy: 91.03, Loss to best acc:0.25%
#
# Epoch [82/300], Final Valid Loss: 2.4015, Final Valid Accuracy: 23.62%, Best Valid Accuracy: 23.64%, Loss to best Valid accuracy:2.45
#
# Epoch [83/300], Final Train Loss: 0.2515, Final Train Accuracy: 89.55%, Best Train Accuracy: 91.03, Loss to best acc:0.25%
#
# Epoch [83/300], Final Valid Loss: 2.2931, Final Valid Accuracy: 23.62%, Best Valid Accuracy: 23.64%, Loss to best Valid accuracy:2.45
#
# Epoch [84/300], Final Train Loss: 0.2327, Final Train Accuracy: 89.68%, Best Train Accuracy: 91.03, Loss to best acc:0.25%
#
# Epoch [84/300], Final Valid Loss: 2.3226, Final Valid Accuracy: 23.64%, Best Valid Accuracy: 23.64%, Loss to best Valid accuracy:2.32
#
# Epoch [85/300], Final Train Loss: 0.2602, Final Train Accuracy: 91.06%, Best Train Accuracy: 91.06, Loss to best acc:0.26%
#
# Epoch [85/300], Final Valid Loss: 2.2554, Final Valid Accuracy: 23.68%, Best Valid Accuracy: 23.68%, Loss to best Valid accuracy:2.26
#
# Epoch [86/300], Final Train Loss: 0.3231, Final Train Accuracy: 92.78%, Best Train Accuracy: 92.78, Loss to best acc:0.32%
#
# Epoch [86/300], Final Valid Loss: 2.3499, Final Valid Accuracy: 23.71%, Best Valid Accuracy: 23.71%, Loss to best Valid accuracy:2.35
#
# Epoch [87/300], Final Train Loss: 0.2339, Final Train Accuracy: 93.01%, Best Train Accuracy: 93.01, Loss to best acc:0.23%
#
# Epoch [87/300], Final Valid Loss: 2.4231, Final Valid Accuracy: 23.68%, Best Valid Accuracy: 23.71%, Loss to best Valid accuracy:2.35
#
# Epoch [88/300], Final Train Loss: 0.3470, Final Train Accuracy: 91.60%, Best Train Accuracy: 93.01, Loss to best acc:0.23%
#
# Epoch [88/300], Final Valid Loss: 2.4848, Final Valid Accuracy: 23.67%, Best Valid Accuracy: 23.71%, Loss to best Valid accuracy:2.35
#
# Epoch [89/300], Final Train Loss: 0.2907, Final Train Accuracy: 90.78%, Best Train Accuracy: 93.01, Loss to best acc:0.23%
#
# Epoch [89/300], Final Valid Loss: 2.4035, Final Valid Accuracy: 23.71%, Best Valid Accuracy: 23.71%, Loss to best Valid accuracy:2.35
#
# Epoch [90/300], Final Train Loss: 0.3894, Final Train Accuracy: 89.37%, Best Train Accuracy: 93.01, Loss to best acc:0.23%
#
# Epoch [90/300], Final Valid Loss: 2.5100, Final Valid Accuracy: 23.75%, Best Valid Accuracy: 23.75%, Loss to best Valid accuracy:2.51
#
# Epoch [91/300], Final Train Loss: 0.2593, Final Train Accuracy: 87.99%, Best Train Accuracy: 93.01, Loss to best acc:0.23%
#
# Epoch [91/300], Final Valid Loss: 2.1445, Final Valid Accuracy: 23.80%, Best Valid Accuracy: 23.80%, Loss to best Valid accuracy:2.14
#
# Epoch [92/300], Final Train Loss: 0.2024, Final Train Accuracy: 90.37%, Best Train Accuracy: 93.01, Loss to best acc:0.23%
#
# Epoch [92/300], Final Valid Loss: 2.2771, Final Valid Accuracy: 23.82%, Best Valid Accuracy: 23.82%, Loss to best Valid accuracy:2.28
#
# Epoch [93/300], Final Train Loss: 0.3357, Final Train Accuracy: 89.76%, Best Train Accuracy: 93.01, Loss to best acc:0.23%
#
# Epoch
, Best Valid Accuracy: 24.02%, Loss to best Valid accuracy:2.24
#
# Epoch [111/300], Final Train Loss: 0.2548, Final Train Accuracy: 91.06%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [111/300], Final Valid Loss: 2.3158, Final Valid Accuracy: 23.98%, Best Valid Accuracy: 24.02%, Loss to best Valid accuracy:2.24
#
# Epoch [112/300], Final Train Loss: 0.2656, Final Train Accuracy: 89.41%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [112/300], Final Valid Loss: 2.2270, Final Valid Accuracy: 24.00%, Best Valid Accuracy: 24.02%, Loss to best Valid accuracy:2.24
#
# Epoch [113/300], Final Train Loss: 0.1964, Final Train Accuracy: 90.93%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [113/300], Final Valid Loss: 2.1852, Final Valid Accuracy: 24.03%, Best Valid Accuracy: 24.03%, Loss to best Valid accuracy:2.19
#
# Epoch [114/300], Final Train Loss: 0.3144, Final Train Accuracy: 91.66%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [114/300], Final Valid Loss: 2.3923, Final Valid Accuracy: 23.99%, Best Valid Accuracy: 24.03%, Loss to best Valid accuracy:2.19
#
# Epoch [115/300], Final Train Loss: 0.2312, Final Train Accuracy: 91.18%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [115/300], Final Valid Loss: 2.2968, Final Valid Accuracy: 24.01%, Best Valid Accuracy: 24.03%, Loss to best Valid accuracy:2.19
#
# Epoch [116/300], Final Train Loss: 0.2238, Final Train Accuracy: 92.78%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [116/300], Final Valid Loss: 2.1662, Final Valid Accuracy: 24.06%, Best Valid Accuracy: 24.06%, Loss to best Valid accuracy:2.17
#
# Epoch [117/300], Final Train Loss: 0.2244, Final Train Accuracy: 93.29%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [117/300], Final Valid Loss: 2.4096, Final Valid Accuracy: 24.10%, Best Valid Accuracy: 24.10%, Loss to best Valid accuracy:2.41
#
# Epoch [118/300], Final Train Loss: 0.2846, Final Train Accuracy: 91.70%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [118/300], Final Valid Loss: 2.3878, Final Valid Accuracy: 24.11%, Best Valid Accuracy: 24.11%, Loss to best Valid accuracy:2.39
#
# Epoch [119/300], Final Train Loss: 0.2828, Final Train Accuracy: 90.99%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [119/300], Final Valid Loss: 2.0522, Final Valid Accuracy: 24.18%, Best Valid Accuracy: 24.18%, Loss to best Valid accuracy:2.05
#
# Epoch [120/300], Final Train Loss: 0.2070, Final Train Accuracy: 91.59%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [120/300], Final Valid Loss: 2.2056, Final Valid Accuracy: 24.19%, Best Valid Accuracy: 24.19%, Loss to best Valid accuracy:2.21
#
# Epoch [121/300], Final Train Loss: 0.1860, Final Train Accuracy: 91.76%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [121/300], Final Valid Loss: 2.2475, Final Valid Accuracy: 24.21%, Best Valid Accuracy: 24.21%, Loss to best Valid accuracy:2.25
#
# Epoch [122/300], Final Train Loss: 0.2853, Final Train Accuracy: 90.50%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [122/300], Final Valid Loss: 2.2441, Final Valid Accuracy: 24.23%, Best Valid Accuracy: 24.23%, Loss to best Valid accuracy:2.24
#
# Epoch [123/300], Final Train Loss: 0.2324, Final Train Accuracy: 91.26%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [123/300], Final Valid Loss: 2.2966, Final Valid Accuracy: 24.22%, Best Valid Accuracy: 24.23%, Loss to best Valid accuracy:2.24
#
# Epoch [124/300], Final Train Loss: 0.1924, Final Train Accuracy: 92.68%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [124/300], Final Valid Loss: 2.3524, Final Valid Accuracy: 24.22%, Best Valid Accuracy: 24.23%, Loss to best Valid accuracy:2.24
#
# Epoch [125/300], Final Train Loss: 0.2117, Final Train Accuracy: 93.24%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [125/300], Final Valid Loss: 2.2333, Final Valid Accuracy: 24.25%, Best Valid Accuracy: 24.25%, Loss to best Valid accuracy:2.23
#
# Epoch [126/300], Final Train Loss: 0.2555, Final Train Accuracy: 92.22%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [126/300], Final Valid Loss: 2.1952, Final Valid Accuracy: 24.27%, Best Valid Accuracy: 24.27%, Loss to best Valid accuracy:2.20
#
# Epoch [127/300], Final Train Loss: 0.2460, Final Train Accuracy: 91.02%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [127/300], Final Valid Loss: 2.2924, Final Valid Accuracy: 24.26%, Best Valid Accuracy: 24.27%, Loss to best Valid accuracy:2.20
#
# Epoch [128/300], Final Train Loss: 0.3567, Final Train Accuracy: 91.39%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [128/300], Final Valid Loss: 2.4053, Final Valid Accuracy: 24.28%, Best Valid Accuracy: 24.28%, Loss to best Valid accuracy:2.41
#
# Epoch [129/300], Final Train Loss: 0.3180, Final Train Accuracy: 90.82%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [129/300], Final Valid Loss: 2.4993, Final Valid Accuracy: 24.27%, Best Valid Accuracy: 24.28%, Loss to best Valid accuracy:2.41
#
# Epoch [130/300], Final Train Loss: 0.2367, Final Train Accuracy: 90.08%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [130/300], Final Valid Loss: 2.4100, Final Valid Accuracy: 24.27%, Best Valid Accuracy: 24.28%, Loss to best Valid accuracy:2.41
#
# Epoch [131/300], Final Train Loss: 0.1861, Final Train Accuracy: 90.76%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [131/300], Final Valid Loss: 2.1726, Final Valid Accuracy: 24.30%, Best Valid Accuracy: 24.30%, Loss to best Valid accuracy:2.17
#
# Epoch [132/300], Final Train Loss: 0.1433, Final Train Accuracy: 92.89%, Best Train Accuracy: 93.66, Loss to best acc:0.23%
#
# Epoch [132/300], Final Valid Loss: 2.3097, Final Valid Accuracy: 24.32%, Best Valid Accuracy: 24.32%, Loss to best Valid accuracy:2.31
#
# Epoch [133/300], Final Train Loss: 0.2054, Final Train Accuracy: 93.89%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [133/300], Final Valid Loss: 2.3114, Final Valid Accuracy: 24.33%, Best Valid Accuracy: 24.33%, Loss to best Valid accuracy:2.31
#
# Epoch [134/300], Final Train Loss: 0.2550, Final Train Accuracy: 92.14%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [134/300], Final Valid Loss: 2.2351, Final Valid Accuracy: 24.38%, Best Valid Accuracy: 24.38%, Loss to best Valid accuracy:2.24
#
# Epoch [135/300], Final Train Loss: 0.2005, Final Train Accuracy: 91.95%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [135/300], Final Valid Loss: 2.2449, Final Valid Accuracy: 24.41%, Best Valid Accuracy: 24.41%, Loss to best Valid accuracy:2.24
#
# Epoch [136/300], Final Train Loss: 0.2515, Final Train Accuracy: 92.71%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [136/300], Final Valid Loss: 2.3200, Final Valid Accuracy: 24.42%, Best Valid Accuracy: 24.42%, Loss to best Valid accuracy:2.32
#
# Epoch [137/300], Final Train Loss: 0.3219, Final Train Accuracy: 92.87%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [137/300], Final Valid Loss: 2.2906, Final Valid Accuracy: 24.43%, Best Valid Accuracy: 24.43%, Loss to best Valid accuracy:2.29
#
# Epoch [138/300], Final Train Loss: 0.2194, Final Train Accuracy: 93.79%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [138/300], Final Valid Loss: 2.5541, Final Valid Accuracy: 24.44%, Best Valid Accuracy: 24.44%, Loss to best Valid accuracy:2.55
#
# Epoch [139/300], Final Train Loss: 0.3274, Final Train Accuracy: 93.32%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [139/300], Final Valid Loss: 2.2157, Final Valid Accuracy: 24.46%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.22
#
# Epoch [140/300], Final Train Loss: 0.2458, Final Train Accuracy: 92.08%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [140/300], Final Valid Loss: 2.3041, Final Valid Accuracy: 24.44%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.22
#
# Epoch [141/300], Final Train Loss: 0.2356, Final Train Accuracy: 91.65%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [141/300], Final Valid Loss: 2.3199, Final Valid Accuracy: 24.43%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.22
#
# Epoch [142/300], Final Train Loss: 0.2130, Final Train Accuracy: 91.50%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [142/300], Final Valid Loss: 2.2707, Final Valid Accuracy: 24.44%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.22
#
# Epoch [143/300], Final Train Loss: 0.1746, Final Train Accuracy: 92.52%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [143/300], Final Valid Loss: 2.2520, Final Valid Accuracy: 24.45%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.22
#
# Epoch [144/300], Final Train Loss: 0.3920, Final Train Accuracy: 91.69%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [144/300], Final Valid Loss: 2.3839, Final Valid Accuracy: 24.43%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.22
#
# Epoch [145/300], Final Train Loss: 0.2348, Final Train Accuracy: 92.68%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [145/300], Final Valid Loss: 2.3719, Final Valid Accuracy: 24.44%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.22
#
# Epoch [146/300], Final Train Loss: 0.3107, Final Train Accuracy: 93.75%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [146/300], Final Valid Loss: 2.3276, Final Valid Accuracy: 24.46%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.33
#
# Epoch [147/300], Final Train Loss: 0.2525, Final Train Accuracy: 92.42%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [147/300], Final Valid Loss: 2.2929, Final Valid Accuracy: 24.46%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.29
#
# Epoch [148/300], Final Train Loss: 0.2616, Final Train Accuracy: 93.10%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [148/300], Final Valid Loss: 2.4006, Final Valid Accuracy: 24.45%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.29
#
# Epoch [149/300], Final Train Loss: 0.2082, Final Train Accuracy: 93.57%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [149/300], Final Valid Loss: 2.3421, Final Valid Accuracy: 24.45%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.29
#
# Epoch [150/300], Final Train Loss: 0.2073, Final Train Accuracy: 93.39%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [150/300], Final Valid Loss: 2.4915, Final Valid Accuracy: 24.45%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.29
#
# Epoch [151/300], Final Train Loss: 0.1867, Final Train Accuracy: 92.47%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [151/300], Final Valid Loss: 2.3760, Final Valid Accuracy: 24.46%, Best Valid Accuracy: 24.46%, Loss to best Valid accuracy:2.29
#
# Epoch [152/300], Final Train Loss: 0.2121, Final Train Accuracy: 90.95%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [152/300], Final Valid Loss: 2.3464, Final Valid Accuracy: 24.47%, Best Valid Accuracy: 24.47%, Loss to best Valid accuracy:2.35
#
# Epoch [153/300], Final Train Loss: 0.2682, Final Train Accuracy: 91.01%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [153/300], Final Valid Loss: 2.2906, Final Valid Accuracy: 24.45%, Best Valid Accuracy: 24.47%, Loss to best Valid accuracy:2.35
#
# Epoch [154/300], Final Train Loss: 0.2906, Final Train Accuracy: 91.61%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch [154/300], Final Valid Loss: 2.1475, Final Valid Accuracy: 24.48%, Best Valid Accuracy: 24.48%, Loss to best Valid accuracy:2.15
#
# Epoch [155/300], Final Train Loss: 0.1997, Final Train Accuracy: 92.65%, Best Train Accuracy: 93.89, Loss to best acc:0.21%
#
# Epoch
, Best Train Accuracy: 94.11, Loss to best acc:0.16%
#
# Epoch [172/300], Final Valid Loss: 2.3018, Final Valid Accuracy: 24.58%, Best Valid Accuracy: 24.61%, Loss to best Valid accuracy:2.26
#
# Epoch [173/300], Final Train Loss: 0.2870, Final Train Accuracy: 92.59%, Best Train Accuracy: 94.11, Loss to best acc:0.16%
#
# Epoch [173/300], Final Valid Loss: 2.2418, Final Valid Accuracy: 24.59%, Best Valid Accuracy: 24.61%, Loss to best Valid accuracy:2.26
#
# Epoch [174/300], Final Train Loss: 0.3243, Final Train Accuracy: 91.49%, Best Train Accuracy: 94.11, Loss to best acc:0.16%
#
# Epoch [174/300], Final Valid Loss: 2.1446, Final Valid Accuracy: 24.62%, Best Valid Accuracy: 24.62%, Loss to best Valid accuracy:2.14
#
# Epoch [175/300], Final Train Loss: 0.3054, Final Train Accuracy: 91.15%, Best Train Accuracy: 94.11, Loss to best acc:0.16%
#
# Epoch [175/300], Final Valid Loss: 2.2080, Final Valid Accuracy: 24.62%, Best Valid Accuracy: 24.62%, Loss to best Valid accuracy:2.14
#
# Epoch [176/300], Final Train Loss: 0.1905, Final Train Accuracy: 93.02%, Best Train Accuracy: 94.11, Loss to best acc:0.16%
#
# Epoch [176/300], Final Valid Loss: 2.3282, Final Valid Accuracy: 24.63%, Best Valid Accuracy: 24.63%, Loss to best Valid accuracy:2.33
#
# Epoch [177/300], Final Train Loss: 0.2319, Final Train Accuracy: 94.36%, Best Train Accuracy: 94.36, Loss to best acc:0.23%
#
# Epoch [177/300], Final Valid Loss: 2.1887, Final Valid Accuracy: 24.64%, Best Valid Accuracy: 24.64%, Loss to best Valid accuracy:2.19
#
# Epoch [178/300], Final Train Loss: 0.2506, Final Train Accuracy: 94.35%, Best Train Accuracy: 94.36, Loss to best acc:0.23%
#
# Epoch [178/300], Final Valid Loss: 2.3362, Final Valid Accuracy: 24.63%, Best Valid Accuracy: 24.64%, Loss to best Valid accuracy:2.19
#
# Epoch [179/300], Final Train Loss: 0.2604, Final Train Accuracy: 93.80%, Best Train Accuracy: 94.36, Loss to best acc:0.23%
#
# Epoch [179/300], Final Valid Loss: 2.2158, Final Valid Accuracy: 24.64%, Best Valid Accuracy: 24.64%, Loss to best Valid accuracy:2.22
#
# Epoch [180/300], Final Train Loss: 0.1500, Final Train Accuracy: 95.20%, Best Train Accuracy: 95.20, Loss to best acc:0.15%
#
# Epoch [180/300], Final Valid Loss: 2.3538, Final Valid Accuracy: 24.67%, Best Valid Accuracy: 24.67%, Loss to best Valid accuracy:2.35
#
# Epoch [181/300], Final Train Loss: 0.2044, Final Train Accuracy: 94.48%, Best Train Accuracy: 95.20, Loss to best acc:0.15%
#
# Epoch [181/300], Final Valid Loss: 2.2887, Final Valid Accuracy: 24.67%, Best Valid Accuracy: 24.67%, Loss to best Valid accuracy:2.29
#
# Epoch [182/300], Final Train Loss: 0.1344, Final Train Accuracy: 93.67%, Best Train Accuracy: 95.20, Loss to best acc:0.15%
#
# Epoch [182/300], Final Valid Loss: 2.2463, Final Valid Accuracy: 24.67%, Best Valid Accuracy: 24.67%, Loss to best Valid accuracy:2.25
#
# Epoch [183/300], Final Train Loss: 0.3033, Final Train Accuracy: 90.43%, Best Train Accuracy: 95.20, Loss to best acc:0.15%
#
# ...
#
# Epoch [241/300], Final Valid Loss: 2.3016, Final Valid Accuracy: 24.92%, Best Valid Accuracy: 24.94%, Loss to best Valid accuracy:2.25
#
# Epoch [242/300], Final Train Loss: 0.1968, Final Train Accuracy: 92.29%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [242/300], Final Valid Loss: 2.1776, Final Valid Accuracy: 24.94%, Best Valid Accuracy: 24.94%, Loss to best Valid accuracy:2.25
#
# Epoch [243/300], Final Train Loss: 0.2413, Final Train Accuracy: 92.52%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [243/300], Final Valid Loss: 2.2122, Final Valid Accuracy: 24.95%, Best Valid Accuracy: 24.95%, Loss to best Valid accuracy:2.21
#
# Epoch [244/300], Final Train Loss: 0.3101, Final Train Accuracy: 90.18%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [244/300], Final Valid Loss: 2.2583, Final Valid Accuracy: 24.95%, Best Valid Accuracy: 24.95%, Loss to best Valid accuracy:2.26
#
# Epoch [245/300], Final Train Loss: 0.3161, Final Train Accuracy: 91.44%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [245/300], Final Valid Loss: 2.1457, Final Valid Accuracy: 24.96%, Best Valid Accuracy: 24.96%, Loss to best Valid accuracy:2.15
#
# Epoch [246/300], Final Train Loss: 0.3250, Final Train Accuracy: 92.24%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [246/300], Final Valid Loss: 2.2839, Final Valid Accuracy: 24.97%, Best Valid Accuracy: 24.97%, Loss to best Valid accuracy:2.28
#
# Epoch [247/300], Final Train Loss: 0.2804, Final Train Accuracy: 93.31%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [247/300], Final Valid Loss: 2.3205, Final Valid Accuracy: 24.97%, Best Valid Accuracy: 24.97%, Loss to best Valid accuracy:2.32
#
# Epoch [248/300], Final Train Loss: 0.2092, Final Train Accuracy: 93.34%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [248/300], Final Valid Loss: 2.1757, Final Valid Accuracy: 24.97%, Best Valid Accuracy: 24.97%, Loss to best Valid accuracy:2.32
#
# Epoch [249/300], Final Train Loss: 0.1961, Final Train Accuracy: 93.58%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [249/300], Final Valid Loss: 2.0658, Final Valid Accuracy: 24.99%, Best Valid Accuracy: 24.99%, Loss to best Valid accuracy:2.07
#
# Epoch [250/300], Final Train Loss: 0.1870, Final Train Accuracy: 94.68%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [250/300], Final Valid Loss: 2.4144, Final Valid Accuracy: 24.98%, Best Valid Accuracy: 24.99%, Loss to best Valid accuracy:2.07
#
# Epoch [251/300], Final Train Loss: 0.1729, Final Train Accuracy: 93.40%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [251/300], Final Valid Loss: 2.1314, Final Valid Accuracy: 25.00%, Best Valid Accuracy: 25.00%, Loss to best Valid accuracy:2.13
#
# Epoch [252/300], Final Train Loss: 0.2353, Final Train Accuracy: 92.54%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [252/300], Final Valid Loss: 2.2645, Final Valid Accuracy: 25.00%, Best Valid Accuracy: 25.00%, Loss to best Valid accuracy:2.26
#
# Epoch [253/300], Final Train Loss: 0.2485, Final Train Accuracy: 91.21%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [253/300], Final Valid Loss: 2.2503, Final Valid Accuracy: 25.00%, Best Valid Accuracy: 25.00%, Loss to best Valid accuracy:2.26
#
# Epoch [254/300], Final Train Loss: 0.3443, Final Train Accuracy: 91.59%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [254/300], Final Valid Loss: 2.3775, Final Valid Accuracy: 25.00%, Best Valid Accuracy: 25.00%, Loss to best Valid accuracy:2.26
#
# Epoch [255/300], Final Train Loss: 0.2782, Final Train Accuracy: 91.25%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [255/300], Final Valid Loss: 2.2005, Final Valid Accuracy: 25.01%, Best Valid Accuracy: 25.01%, Loss to best Valid accuracy:2.20
#
# Epoch [256/300], Final Train Loss: 0.2184, Final Train Accuracy: 92.88%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [256/300], Final Valid Loss: 2.4982, Final Valid Accuracy: 25.01%, Best Valid Accuracy: 25.01%, Loss to best Valid accuracy:2.20
#
# Epoch [257/300], Final Train Loss: 0.1807, Final Train Accuracy: 94.61%, Best Train Accuracy: 95.90, Loss to best acc:0.19%
#
# Epoch [257/300], Final Valid Loss: 2.3769, Final Valid Accuracy: 25.01%, Best Valid Accuracy: 25.01%, Loss to best Valid accuracy:2.20
#
# Epoch [258/300], Final Train Loss: 0.1751, Final Train Accuracy: 96.18%, Best Train Accuracy: 96.18, Loss to best acc:0.18%
#
# Epoch [258/300], Final Valid Loss: 2.4364, Final Valid Accuracy: 25.02%, Best Valid Accuracy: 25.02%, Loss to best Valid accuracy:2.44
#
# Epoch [259/300], Final Train Loss: 0.1862, Final Train Accuracy: 96.68%, Best Train Accuracy: 96.68, Loss to best acc:0.19%
#
# Epoch [259/300], Final Valid Loss: 2.2400, Final Valid Accuracy: 25.04%, Best Valid Accuracy: 25.04%, Loss to best Valid accuracy:2.24
#
# Epoch [260/300], Final Train Loss: 0.0778, Final Train Accuracy: 97.01%, Best Train Accuracy: 97.01, Loss to best acc:0.08%
#
# Epoch [260/300], Final Valid Loss: 2.1672, Final Valid Accuracy: 25.06%, Best Valid Accuracy: 25.06%, Loss to best Valid accuracy:2.17
#
# Epoch [261/300], Final Train Loss: 0.0575, Final Train Accuracy: 96.14%, Best Train Accuracy: 97.01, Loss to best acc:0.08%
#
# Epoch [261/300], Final Valid Loss: 2.2697, Final Valid Accuracy: 25.06%, Best Valid Accuracy: 25.06%, Loss to best Valid accuracy:2.27
#
# Epoch [262/300], Final Train Loss: 0.1061, Final Train Accuracy: 97.32%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [262/300], Final Valid Loss: 2.1162, Final Valid Accuracy: 25.07%, Best Valid Accuracy: 25.07%, Loss to best Valid accuracy:2.12
#
# Epoch [263/300], Final Train Loss: 0.1549, Final Train Accuracy: 96.80%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [263/300], Final Valid Loss: 2.1298, Final Valid Accuracy: 25.08%, Best Valid Accuracy: 25.08%, Loss to best Valid accuracy:2.13
#
# Epoch [264/300], Final Train Loss: 0.2406, Final Train Accuracy: 93.38%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [264/300], Final Valid Loss: 2.3912, Final Valid Accuracy: 25.08%, Best Valid Accuracy: 25.08%, Loss to best Valid accuracy:2.13
#
# Epoch [265/300], Final Train Loss: 0.2926, Final Train Accuracy: 90.72%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [265/300], Final Valid Loss: 2.2957, Final Valid Accuracy: 25.07%, Best Valid Accuracy: 25.08%, Loss to best Valid accuracy:2.13
#
# Epoch [266/300], Final Train Loss: 0.4802, Final Train Accuracy: 88.99%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [266/300], Final Valid Loss: 2.3173, Final Valid Accuracy: 25.07%, Best Valid Accuracy: 25.08%, Loss to best Valid accuracy:2.13
#
# Epoch [267/300], Final Train Loss: 0.4519, Final Train Accuracy: 88.62%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [267/300], Final Valid Loss: 2.2750, Final Valid Accuracy: 25.06%, Best Valid Accuracy: 25.08%, Loss to best Valid accuracy:2.13
#
# Epoch [268/300], Final Train Loss: 0.4262, Final Train Accuracy: 86.79%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch
, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [285/300], Final Train Loss: 0.3031, Final Train Accuracy: 91.35%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [285/300], Final Valid Loss: 2.2604, Final Valid Accuracy: 25.09%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [286/300], Final Train Loss: 0.2521, Final Train Accuracy: 93.02%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [286/300], Final Valid Loss: 2.3052, Final Valid Accuracy: 25.10%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [287/300], Final Train Loss: 0.1909, Final Train Accuracy: 94.45%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [287/300], Final Valid Loss: 2.2378, Final Valid Accuracy: 25.11%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [288/300], Final Train Loss: 0.2803, Final Train Accuracy: 94.63%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [288/300], Final Valid Loss: 2.3458, Final Valid Accuracy: 25.11%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [289/300], Final Train Loss: 0.2550, Final Train Accuracy: 92.68%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [289/300], Final Valid Loss: 2.4087, Final Valid Accuracy: 25.11%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [290/300], Final Train Loss: 0.2081, Final Train Accuracy: 92.75%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [290/300], Final Valid Loss: 2.3643, Final Valid Accuracy: 25.12%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [291/300], Final Train Loss: 0.1674, Final Train Accuracy: 92.36%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [291/300], Final Valid Loss: 2.2587, Final Valid Accuracy: 25.13%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [292/300], Final Train Loss: 0.2401, Final Train Accuracy: 90.89%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [292/300], Final Valid Loss: 2.1417, Final Valid Accuracy: 25.13%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [293/300], Final Train Loss: 0.2206, Final Train Accuracy: 90.21%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [293/300], Final Valid Loss: 2.2424, Final Valid Accuracy: 25.14%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [294/300], Final Train Loss: 0.2384, Final Train Accuracy: 91.94%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [294/300], Final Valid Loss: 2.2252, Final Valid Accuracy: 25.13%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [295/300], Final Train Loss: 0.2315, Final Train Accuracy: 93.31%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [295/300], Final Valid Loss: 2.1691, Final Valid Accuracy: 25.14%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [296/300], Final Train Loss: 0.2633, Final Train Accuracy: 94.17%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [296/300], Final Valid Loss: 2.3240, Final Valid Accuracy: 25.15%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.18
#
# Epoch [297/300], Final Train Loss: 0.3008, Final Train Accuracy: 94.11%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [297/300], Final Valid Loss: 2.3347, Final Valid Accuracy: 25.15%, Best Valid Accuracy: 25.15%, Loss to best Valid accuracy:2.33
#
# Epoch [298/300], Final Train Loss: 0.2659, Final Train Accuracy: 94.92%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [298/300], Final Valid Loss: 2.1521, Final Valid Accuracy: 25.17%, Best Valid Accuracy: 25.17%, Loss to best Valid accuracy:2.15
#
# Epoch [299/300], Final Train Loss: 0.2382, Final Train Accuracy: 92.40%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [299/300], Final Valid Loss: 2.1459, Final Valid Accuracy: 25.16%, Best Valid Accuracy: 25.17%, Loss to best Valid accuracy:2.15
#
# Epoch [300/300], Final Train Loss: 0.1660, Final Train Accuracy: 93.83%, Best Train Accuracy: 97.32, Loss to best acc:0.11%
#
# Epoch [300/300], Final Valid Loss: 2.1431, Final Valid Accuracy: 25.18%, Best Valid Accuracy: 25.18%, Loss to best Valid accuracy:2.14
#
# 模型参数已保存为scale=1.0-512.pth
#
# {'训练的模型的保留路径': 'scale=1.0-512.pth', '在测试集中的最终损失': 2.1431357860565186, '在测试集中的最终准确率': 0.25183333333333335, '在测试集中的最佳准确率': 0.25183333333333335, '在训练集中的最终准确率': 0.93826, '在训练集中的最佳准确率': 0.97324, '在训练集中的最终损失': 0.1659507155418396, '在训练集中的最佳损失': 0.10608607530593872}
# 字典保存在文件中
