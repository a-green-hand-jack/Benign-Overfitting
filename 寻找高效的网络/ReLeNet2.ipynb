# %%
# 加载各种库
import torch
import os
import pickle
import torch.nn as nn
from torchvision.transforms import ToTensor
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
import torchvision
from torchvision.datasets import CIFAR10
import numpy as np
import random
from torch.optim.lr_scheduler import CosineAnnealingLR  # 实现cos函数式的变化
# 加载支持函数和类
from support_code.load_dataset import get_data_loader
from support_code.ReLeNet import ReLeNet
# 设置设备和种子
device_cuda = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# 设置随机种子
seed = 10  # 你可以选择任何整数作为种子值

# 设置PyTorch随机种子
torch.manual_seed(seed)

# 设置CUDA随机种子（如果使用GPU）
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# 设置Numpy随机种子
np.random.seed(seed)

# 设置Python随机种子
random.seed(seed)

# %%
def get_scale(scale, writer,  
            device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu"), train_loader=None, valid_loader=None, test_loader=None, 
            channel=3,
            num_classes=10,
            im_size=(32, 32),
            # 可能需要的超参数
            momentum = 0.9,
            weight_decay = 0.0005,
            initial_lr = 0.1,
            num_epochs = 100,
            save_dir = "logs-ReLeNet-0914"):

  # -------------------------------------------------创建模型实例并将其移至 GPU -----------------------------------------------------
  model = ReLeNet(channel=channel, num_classes=num_classes)
  model.to(device)
  # 确保文件夹存在，如果不存在则创建它
  os.makedirs(save_dir, exist_ok=True)
  # 定义损失函数/优化器/学习率
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(model.parameters(), lr=initial_lr, weight_decay=weight_decay, momentum=momentum)
  scheduler = CosineAnnealingLR(optimizer, T_max=10)

  # 记录训练过程中的准确率和损失
  tag_loss = "train_loss_{}".format(scale)
  tag_acc = "train_accuracy_{}".format(scale)

  # 训练循环...
  final_train_loss = 0
  final_train_acc = 0
  best_train_acc = 0.0  # 用于跟踪一个scale也就是一个完整的train的过程中的最佳准确率

  # 验证步骤...
  # 记录验证的次数
  valid_correct = 0
  valid_total = 0
  best_valid_acc = 0.0
  val_loss = "val_loss_{}".format(scale)
  val_acc = "val_accuracy_{}".format(scale)
  acc = 0.0
  loss = 1.0

  for epoch in range(num_epochs):

    # ----------------------------首先是训练过程----------------------------
    train_correct = 0
    train_total = 0
    for batch_idx, (imgs, targets) in enumerate(train_loader):
      imgs, targets = imgs.to(device), targets.to(device)
      outputs = model(imgs)
      loss = criterion(outputs, targets)
      _, predicted = torch.max(outputs, 1)
      train_total += targets.size(0)
      train_correct += (predicted == targets).sum().item()
      optimizer.zero_grad() # W_new = W_old + \gamma \times \deta W_old,这里相当于先要求\gamma 为零矩阵
      loss.backward()   # 使用backward得到了\deta W_old
      optimizer.step()  # 选择合适的\gamma 得到了W_new
      scheduler.step()  # \gamma 事实上是一个依赖于learning_rate的一个矩阵函数,这里更新了learning_rate,而且learning_rate的更新是依赖于epoch的

    acc = train_correct / train_total
    writer.add_scalar(tag_loss, loss.item(), epoch)
    writer.add_scalar(tag_acc, acc, epoch)
    # 更新模型权重并记录到Tensorboard
    for name, param in model.named_parameters():
      writer.add_histogram(name, param.clone().cpu().data.numpy(), epoch)
    final_train_acc = train_correct / train_total
    # 更新最佳准确率,以及对应的loss
    if final_train_acc >= best_train_acc:
      best_train_acc = final_train_acc
      best_train_loss = loss.item()
    final_train_loss = loss.item()
    print("Epoch [{}/{}], Final Train Loss: {:.4f}, Final Train Accuracy: {:.2f}%, Best Train Accuracy: {:.2f}, Loss to best acc:{:.2f}%".format(epoch+1, num_epochs, final_train_loss, final_train_acc * 100, best_train_acc * 100, best_train_loss),"\n")
    # 记录学习率(learning_rate)的更新情况
    writer.add_scalar("learning_rate",optimizer.param_groups[0]['lr'])

    # -------------------------然后进入了验证步骤---------------------------------
    for batch_idx, (imgs, targets) in enumerate(valid_loader):
      imgs, targets = imgs.to(device), targets.to(device)
      outputs = model(imgs)
      loss = criterion(outputs, targets)
      _, predicted = torch.max(outputs, 1)
      valid_total += targets.size(0)
      valid_correct += (predicted == targets).sum().item()
      acc = valid_correct / valid_total

    writer.add_scalar(val_loss, loss.item(), epoch)
    writer.add_scalar(val_acc, acc, epoch)
    # 记录valid中的最终情况
    final_valid_acc = acc
    final_valid_loss = loss
    # 更新最佳准确率,以及对应的loss
    if final_valid_acc >= best_valid_acc:
      best_valid_acc = final_valid_acc
      best_valid_loss = loss.item()
    final_valid_loss = loss.item()
    print("Epoch [{}/{}], Final Valid Loss: {:.4f}, Final Valid Accuracy: {:.2f}%, Best Valid Accuracy: {:.2f}%, Loss to best Valid accuracy:{:.2f}".format(epoch+1, num_epochs, final_valid_loss, final_valid_acc * 100, best_valid_acc * 100, best_valid_loss),"\n")


  # 记录train过程中的最终情况
  writer.add_scalar("final_train_loss", final_train_loss, scale)
  writer.add_scalar("final_train_acc", final_train_acc, scale)
  writer.add_scalar("best_train_acc", best_train_acc, scale)
  writer.add_scalar("best_train_loss", best_train_loss, scale)
  # 记录valid的最终情况
  writer.add_scalar("final_valid_loss", final_valid_loss, scale)
  writer.add_scalar("final_valid_acc", final_valid_acc, scale)
  writer.add_scalar("best_valid_acc", best_valid_acc, scale)
  writer.add_scalar("best_valid_loss", best_valid_loss, scale)

  # 保存模型参数
  # 构建完整的文件路径
  filename = os.path.join(save_dir, "scale={}.pth".format(scale))
  # 保存模型
  torch.save(model.state_dict(), filename)
  print("模型参数已保存为{}".format(filename), '\n')

  # 完成各种工作，记录结果...
  normal_dict = {
      "训练的模型的保留路径": filename,
      "在测试集中的最终损失": final_valid_loss,
      "在测试集中的最终损失":best_valid_loss,
      "在测试集中的最终准确率": final_valid_acc,
      "在测试集中的最佳准确率": best_valid_acc,
      "在训练集中的最终准确率": final_train_acc,
      "在训练集中的最佳准确率": best_train_acc,
      "在训练集中的最终损失": final_train_loss,
      "在训练集中的最佳损失":best_train_loss
  }
  return normal_dict

# %%
# 定义初始的scale范围
scale_min = 0.1
scale_max = 0.9
scale_list = [round(x * 0.1, 1) for x in range(int(scale_min * 10), int(scale_max * 10) + 1)]
# print(scale_list)
my_list = []
# 添加tensorboard
writer_new = SummaryWriter("logs-ReLeNet-0914")

for scale in scale_list:
  train_loader, valid_loader, test_loader = get_data_loader(scale, valid_scale=0.1)
  dic = {}
  print("--------------------开始scale={}的情况---------------------".format(scale), "\n")
  dic['scale={}'.format(scale)] = get_scale(scale=scale, writer=writer_new, train_loader=train_loader, valid_loader=valid_loader,save_dir = "logs-ReLeNet-0914", num_epochs=300)
  print(dic['scale={}'.format(scale)])
  my_list.append(dic)

writer_new.close()

# -------------------------------------保存列表,因为我发现notebook不是很可靠-----------------------------
# 指定保存文件的文件夹和文件名
folder_path = "logs-ReLeNet-0914"
file_name = "dic_ReLeNet.pkl"

# 确保文件夹存在，如果不存在则创建它
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# 组合文件夹路径和文件名
dic_file_path = os.path.join(folder_path, file_name)

with open(dic_file_path, "wb") as file:
  pickle.dump(dic, file=file)

print("字典保存在文件中")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# --------------------开始scale=0.1的情况---------------------
#
# Epoch [1/300], Final Train Loss: 2.2411, Final Train Accuracy: 13.10%, Best Train Accuracy: 13.10, Loss to best acc:2.24%
#
# Epoch [1/300], Final Valid Loss: 2.2662, Final Valid Accuracy: 18.90%, Best Valid Accuracy: 18.90%, Loss to best Valid accuracy:2.27
#
# Epoch [2/300], Final Train Loss: 2.1590, Final Train Accuracy: 18.07%, Best Train Accuracy: 18.07, Loss to best acc:2.16%
#
# Epoch [2/300], Final Valid Loss: 2.2064, Final Valid Accuracy: 19.35%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [3/300], Final Train Loss: 2.1976, Final Train Accuracy: 18.33%, Best Train Accuracy: 18.33, Loss to best acc:2.20%
#
# Epoch [3/300], Final Valid Loss: 2.2738, Final Valid Accuracy: 17.20%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [4/300], Final Train Loss: 2.1346, Final Train Accuracy: 19.58%, Best Train Accuracy: 19.58, Loss to best acc:2.13%
#
# Epoch [4/300], Final Valid Loss: 2.2514, Final Valid Accuracy: 15.93%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [5/300], Final Train Loss: 2.1573, Final Train Accuracy: 20.32%, Best Train Accuracy: 20.32, Loss to best acc:2.16%
#
# Epoch [5/300], Final Valid Loss: 2.3048, Final Valid Accuracy: 14.80%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [6/300], Final Train Loss: 2.1842, Final Train Accuracy: 20.23%, Best Train Accuracy: 20.32, Loss to best acc:2.16%
#
# Epoch [6/300], Final Valid Loss: 2.2207, Final Valid Accuracy: 15.02%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [7/300], Final Train Loss: 2.1443, Final Train Accuracy: 19.89%, Best Train Accuracy: 20.32, Loss to best acc:2.16%
#
# Epoch [7/300], Final Valid Loss: 2.2777, Final Valid Accuracy: 14.73%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [8/300], Final Train Loss: 2.1504, Final Train Accuracy: 21.29%, Best Train Accuracy: 21.29, Loss to best acc:2.15%
#
# Epoch [8/300], Final Valid Loss: 2.2627, Final Valid Accuracy: 14.55%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [9/300], Final Train Loss: 2.1119, Final Train Accuracy: 21.72%, Best Train Accuracy: 21.72, Loss to best acc:2.11%
#
# Epoch [9/300], Final Valid Loss: 2.2704, Final Valid Accuracy: 14.47%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [10/300], Final Train Loss: 2.1219, Final Train Accuracy: 21.77%, Best Train Accuracy: 21.77, Loss to best acc:2.12%
#
# Epoch [10/300], Final Valid Loss: 2.3373, Final Valid Accuracy: 14.24%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [11/300], Final Train Loss: 2.0982, Final Train Accuracy: 22.30%, Best Train Accuracy: 22.30, Loss to best acc:2.10%
#
# Epoch [11/300], Final Valid Loss: 2.3624, Final Valid Accuracy: 14.24%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [12/300], Final Train Loss: 2.1044, Final Train Accuracy: 22.53%, Best Train Accuracy: 22.53, Loss to best acc:2.10%
#
# Epoch [12/300], Final Valid Loss: 2.2781, Final Valid Accuracy: 14.37%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [13/300], Final Train Loss: 2.1207, Final Train Accuracy: 23.08%, Best Train Accuracy: 23.08, Loss to best acc:2.12%
#
# Epoch [13/300], Final Valid Loss: 2.2777, Final Valid Accuracy: 14.45%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [14/300], Final Train Loss: 2.0976, Final Train Accuracy: 23.09%, Best Train Accuracy: 23.09, Loss to best acc:2.10%
#
# Epoch [14/300], Final Valid Loss: 2.2721, Final Valid Accuracy: 14.42%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [15/300], Final Train Loss: 2.1256, Final Train Accuracy: 23.39%, Best Train Accuracy: 23.39, Loss to best acc:2.13%
#
# Epoch [15/300], Final Valid Loss: 2.2608, Final Valid Accuracy: 14.45%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [16/300], Final Train Loss: 2.1172, Final Train Accuracy: 23.10%, Best Train Accuracy: 23.39, Loss to best acc:2.13%
#
# Epoch [16/300], Final Valid Loss: 2.3050, Final Valid Accuracy: 14.52%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [17/300], Final Train Loss: 2.0912, Final Train Accuracy: 23.31%, Best Train Accuracy: 23.39, Loss to best acc:2.13%
#
# Epoch [17/300], Final Valid Loss: 2.2176, Final Valid Accuracy: 14.78%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [18/300], Final Train Loss: 2.1147, Final Train Accuracy: 23.66%, Best Train Accuracy: 23.66, Loss to best acc:2.11%
#
# Epoch [18/300], Final Valid Loss: 2.2829, Final Valid Accuracy: 14.73%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [19/300], Final Train Loss: 2.1003, Final Train Accuracy: 23.86%, Best Train Accuracy: 23.86, Loss to best acc:2.10%
#
# Epoch [19/300], Final Valid Loss: 2.1856, Final Valid Accuracy: 15.03%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [20/300], Final Train Loss: 2.0624, Final Train Accuracy: 23.55%, Best Train Accuracy: 23.86, Loss to best acc:2.10%
#
# Epoch [20/300], Final Valid Loss: 2.2637, Final Valid Accuracy: 15.02%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [21/300], Final Train Loss: 2.1039, Final Train Accuracy: 24.09%, Best Train Accuracy: 24.09, Loss to best acc:2.10%
#
# Epoch [21/300], Final Valid Loss: 2.2720, Final Valid Accuracy: 15.03%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [22/300], Final Train Loss: 2.0805, Final Train Accuracy: 23.38%, Best Train Accuracy: 24.09, Loss to best acc:2.10%
#
# Epoch [22/300], Final Valid Loss: 2.2509, Final Valid Accuracy: 15.10%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [23/300], Final Train Loss: 2.1049, Final Train Accuracy: 23.97%, Best Train Accuracy: 24.09, Loss to best acc:2.10%
#
# Epoch [23/300], Final Valid Loss: 2.2617, Final Valid Accuracy: 15.13%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [24/300], Final Train Loss: 2.0863, Final Train Accuracy: 24.19%, Best Train Accuracy: 24.19, Loss to best acc:2.09%
#
# Epoch [24/300], Final Valid Loss: 2.3011, Final Valid Accuracy: 15.13%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [25/300], Final Train Loss: 2.0998, Final Train Accuracy: 24.08%, Best Train Accuracy: 24.19, Loss to best acc:2.09%
#
# Epoch [25/300], Final Valid Loss: 2.1813, Final Valid Accuracy: 15.27%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [26/300], Final Train Loss: 2.1094, Final Train Accuracy: 24.11%, Best Train Accuracy: 24.19, Loss to best acc:2.09%
#
# Epoch [26/300], Final Valid Loss: 2.2461, Final Valid Accuracy: 15.27%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [27/300], Final Train Loss: 2.1288, Final Train Accuracy: 24.49%, Best Train Accuracy: 24.49, Loss to best acc:2.13%
#
# Epoch [27/300], Final Valid Loss: 2.1914, Final Valid Accuracy: 15.43%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [28/300], Final Train Loss: 2.0948, Final Train Accuracy: 23.91%, Best Train Accuracy: 24.49, Loss to best acc:2.13%
#
# Epoch [28/300], Final Valid Loss: 2.2229, Final Valid Accuracy: 15.52%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [29/300], Final Train Loss: 2.1040, Final Train Accuracy: 24.48%, Best Train Accuracy: 24.49, Loss to best acc:2.13%
#
# Epoch [29/300], Final Valid Loss: 2.2725, Final Valid Accuracy: 15.50%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [30/300], Final Train Loss: 2.1049, Final Train Accuracy: 24.25%, Best Train Accuracy: 24.49, Loss to best acc:2.13%
#
# Epoch [30/300], Final Valid Loss: 2.2400, Final Valid Accuracy: 15.54%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [31/300], Final Train Loss: 2.1217, Final Train Accuracy: 24.99%, Best Train Accuracy: 24.99, Loss to best acc:2.12%
#
# Epoch [31/300], Final Valid Loss: 2.2467, Final Valid Accuracy: 15.55%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [32/300], Final Train Loss: 2.0275, Final Train Accuracy: 25.03%, Best Train Accuracy: 25.03, Loss to best acc:2.03%
#
# Epoch [32/300], Final Valid Loss: 2.2329, Final Valid Accuracy: 15.62%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [33/300], Final Train Loss: 2.0183, Final Train Accuracy: 25.41%, Best Train Accuracy: 25.41, Loss to best acc:2.02%
#
# Epoch [33/300], Final Valid Loss: 2.2643, Final Valid Accuracy: 15.58%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [34/300], Final Train Loss: 2.0511, Final Train Accuracy: 24.81%, Best Train Accuracy: 25.41, Loss to best acc:2.02%
#
# Epoch [34/300], Final Valid Loss: 2.2837, Final Valid Accuracy: 15.63%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [35/300], Final Train Loss: 2.0684, Final Train Accuracy: 25.42%, Best Train Accuracy: 25.42, Loss to best acc:2.07%
#
# Epoch [35/300], Final Valid Loss: 2.1952, Final Valid Accuracy: 15.75%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [36/300], Final Train Loss: 2.0290, Final Train Accuracy: 25.67%, Best Train Accuracy: 25.67, Loss to best acc:2.03%
#
# Epoch [36/300], Final Valid Loss: 2.2256, Final Valid Accuracy: 15.84%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [37/300], Final Train Loss: 2.0480, Final Train Accuracy: 25.82%, Best Train Accuracy: 25.82, Loss to best acc:2.05%
#
# Epoch [37/300], Final Valid Loss: 2.2451, Final Valid Accuracy: 15.91%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [38/300], Final Train Loss: 2.0492, Final Train Accuracy: 25.48%, Best Train Accuracy: 25.82, Loss to best acc:2.05%
#
# Epoch [38/300], Final Valid Loss: 2.1956, Final Valid Accuracy: 16.07%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [39/300], Final Train Loss: 2.0838, Final Train Accuracy: 26.02%, Best Train Accuracy: 26.02, Loss to best acc:2.08%
#
# Epoch [39/300], Final Valid Loss: 2.2427, Final Valid Accuracy: 16.08%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [40/300], Final Train Loss: 2.0534, Final Train Accuracy: 25.67%, Best Train Accuracy: 26.02, Loss to best acc:2.08%
#
# Epoch [40/300], Final Valid Loss: 2.2114, Final Valid Accuracy: 16.16%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [41/300], Final Train Loss: 2.1048, Final Train Accuracy: 25.44%, Best Train Accuracy: 26.02, Loss to best acc:2.08%
#
# Epoch [41/300], Final Valid Loss: 2.2244, Final Valid Accuracy: 16.24%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [42/300], Final Train Loss: 2.0621, Final Train Accuracy: 26.33%, Best Train Accuracy: 26.33, Loss to best acc:2.06%
#
# Epoch [42/300], Final Valid Loss: 2.2157, Final Valid Accuracy: 16.32%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [43/300], Final Train Loss: 2.0447, Final Train Accuracy: 25.80%, Best Train Accuracy: 26.33, Loss to best acc:2.06%
#
# Epoch [43/300], Final Valid Loss: 2.1883, Final Valid Accuracy: 16.42%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [44/300], Final Train Loss: 2.0416, Final Train Accuracy: 26.03%, Best Train Accuracy: 26.33, Loss to best acc:2.06%
#
# Epoch [44/300], Final Valid Loss: 2.1840, Final Valid Accuracy: 16.48%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [45/300], Final Train Loss: 2.0828, Final Train Accuracy: 25.64%, Best Train Accuracy: 26.33, Loss to best acc:2.06%
#
# Epoch [45/300], Final Valid Loss: 2.2277, Final Valid Accuracy: 16.52%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [46/300], Final Train Loss: 2.0491, Final Train Accuracy: 26.23%, Best Train Accuracy: 26.33, Loss to best acc:2.06%
#
# Epoch [46/300], Final Valid Loss: 2.1858, Final Valid Accuracy: 16.60%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [47/300], Final Train Loss: 2.0755, Final Train Accuracy: 26.78%, Best Train Accuracy: 26.78, Loss to best acc:2.08%
#
# Epoch [47/300], Final Valid Loss: 2.1801, Final Valid Accuracy: 16.67%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [48/300], Final Train Loss: 2.0829, Final Train Accuracy: 26.84%, Best Train Accuracy: 26.84, Loss to best acc:2.08%
#
# Epoch [48/300], Final Valid Loss: 2.2284, Final Valid Accuracy: 16.64%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [49/300], Final Train Loss: 2.0666, Final Train Accuracy: 26.49%, Best Train Accuracy: 26.84, Loss to best acc:2.08%
#
# Epoch [49/300], Final Valid Loss: 2.2890, Final Valid Accuracy: 16.57%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [50/300], Final Train Loss: 2.0947, Final Train Accuracy: 26.07%, Best Train Accuracy: 26.84, Loss to best acc:2.08%
#
# Epoch [50/300], Final Valid Loss: 2.2062, Final Valid Accuracy: 16.61%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [51/300], Final Train Loss: 2.0360, Final Train Accuracy: 26.40%, Best Train Accuracy: 26.84, Loss to best acc:2.08%
#
# Epoch [51/300], Final Valid Loss: 2.1934, Final Valid Accuracy: 16.65%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [52/300], Final Train Loss: 2.0254, Final Train Accuracy: 26.13%, Best Train Accuracy: 26.84, Loss to best acc:2.08%
#
# Epoch [52/300], Final Valid Loss: 2.1910, Final Valid Accuracy: 16.71%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [53/300], Final Train Loss: 2.0580, Final Train Accuracy: 26.72%, Best Train Accuracy: 26.84, Loss to best acc:2.08%
#
# Epoch [53/300], Final Valid Loss: 2.2418, Final Valid Accuracy: 16.67%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [54/300], Final Train Loss: 2.0651, Final Train Accuracy: 26.59%, Best Train Accuracy: 26.84, Loss to best acc:2.08%
#
# Epoch [54/300], Final Valid Loss: 2.2355, Final Valid Accuracy: 16.64%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [55/300], Final Train Loss: 2.1076, Final Train Accuracy: 26.63%, Best Train Accuracy: 26.84, Loss to best acc:2.08%
#
# Epoch [55/300], Final Valid Loss: 2.2169, Final Valid Accuracy: 16.64%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [56/300], Final Train Loss: 2.0445, Final Train Accuracy: 26.80%, Best Train Accuracy: 26.84, Loss to best acc:2.08%
#
# Epoch [56/300], Final Valid Loss: 2.1909, Final Valid Accuracy: 16.72%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [57/300], Final Train Loss: 2.0778, Final Train Accuracy: 27.09%, Best Train Accuracy: 27.09, Loss to best acc:2.08%
#
# Epoch [57/300], Final Valid Loss: 2.2804, Final Valid Accuracy: 16.71%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [58/300], Final Train Loss: 2.0752, Final Train Accuracy: 27.18%, Best Train Accuracy: 27.18, Loss to best acc:2.08%
#
# Epoch [58/300], Final Valid Loss: 2.2371, Final Valid Accuracy: 16.73%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [59/300], Final Train Loss: 2.0312, Final Train Accuracy: 26.77%, Best Train Accuracy: 27.18, Loss to best acc:2.08%
#
# Epoch [59/300], Final Valid Loss: 2.1884, Final Valid Accuracy: 16.84%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [60/300], Final Train Loss: 2.0213, Final Train Accuracy: 26.99%, Best Train Accuracy: 27.18, Loss to best acc:2.08%
#
# Epoch [60/300], Final Valid Loss: 2.2072, Final Valid Accuracy: 16.87%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [61/300], Final Train Loss: 2.0351, Final Train Accuracy: 27.46%, Best Train Accuracy: 27.46, Loss to best acc:2.04%
#
# Epoch [61/300], Final Valid Loss: 2.2071, Final Valid Accuracy: 16.92%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [62/300], Final Train Loss: 2.0430, Final Train Accuracy: 27.34%, Best Train Accuracy: 27.46, Loss to best acc:2.04%
#
# Epoch [62/300], Final Valid Loss: 2.1886, Final Valid Accuracy: 16.98%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [63/300], Final Train Loss: 2.0557, Final Train Accuracy: 27.09%, Best Train Accuracy: 27.46, Loss to best acc:2.04%
#
# Epoch [63/300], Final Valid Loss: 2.2243, Final Valid Accuracy: 17.00%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [64/300], Final Train Loss: 2.0276, Final Train Accuracy: 27.72%, Best Train Accuracy: 27.72, Loss to best acc:2.03%
#
# Epoch [64/300], Final Valid Loss: 2.2037, Final Valid Accuracy: 17.06%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [65/300], Final Train Loss: 2.0816, Final Train Accuracy: 27.51%, Best Train Accuracy: 27.72, Loss to best acc:2.03%
#
# Epoch [65/300], Final Valid Loss: 2.2214, Final Valid Accuracy: 17.07%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [66/300], Final Train Loss: 2.0706, Final Train Accuracy: 27.87%, Best Train Accuracy: 27.87, Loss to best acc:2.07%
#
# Epoch [66/300], Final Valid Loss: 2.2109, Final Valid Accuracy: 17.08%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [67/300], Final Train Loss: 2.0390, Final Train Accuracy: 27.42%, Best Train Accuracy: 27.87, Loss to best acc:2.07%
#
# Epoch [67/300], Final Valid Loss: 2.2137, Final Valid Accuracy: 17.08%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [68/300], Final Train Loss: 2.0258, Final Train Accuracy: 27.77%, Best Train Accuracy: 27.87, Loss to best acc:2.07%
#
# Epoch [68/300], Final Valid Loss: 2.2196, Final Valid Accuracy: 17.10%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [69/300], Final Train Loss: 2.0305, Final Train Accuracy: 27.47%, Best Train Accuracy: 27.87, Loss to best acc:2.07%
#
# Epoch [69/300], Final Valid Loss: 2.1751, Final Valid Accuracy: 17.14%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [70/300], Final Train Loss: 2.0626, Final Train Accuracy: 28.02%, Best Train Accuracy: 28.02, Loss to best acc:2.06%
#
# Epoch [70/300], Final Valid Loss: 2.2093, Final Valid Accuracy: 17.17%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [71/300], Final Train Loss: 2.0356, Final Train Accuracy: 28.31%, Best Train Accuracy: 28.31, Loss to best acc:2.04%
#
# Epoch [71/300], Final Valid Loss: 2.2263, Final Valid Accuracy: 17.15%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [72/300], Final Train Loss: 2.0503, Final Train Accuracy: 27.78%, Best Train Accuracy: 28.31, Loss to best acc:2.04%
#
# Epoch [72/300], Final Valid Loss: 2.2452, Final Valid Accuracy: 17.12%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [73/300], Final Train Loss: 2.0518, Final Train Accuracy: 27.70%, Best Train Accuracy: 28.31, Loss to best acc:2.04%
#
# Epoch [73/300], Final Valid Loss: 2.2537, Final Valid Accuracy: 17.08%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [74/300], Final Train Loss: 2.0455, Final Train Accuracy: 28.10%, Best Train Accuracy: 28.31, Loss to best acc:2.04%
#
# Epoch [74/300], Final Valid Loss: 2.2238, Final Valid Accuracy: 17.09%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [75/300], Final Train Loss: 2.0373, Final Train Accuracy: 27.77%, Best Train Accuracy: 28.31, Loss to best acc:2.04%
#
# Epoch [75/300], Final Valid Loss: 2.1982, Final Valid Accuracy: 17.12%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [76/300], Final Train Loss: 2.0817, Final Train Accuracy: 27.84%, Best Train Accuracy: 28.31, Loss to best acc:2.04%
#
# Epoch [76/300], Final Valid Loss: 2.2290, Final Valid Accuracy: 17.10%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [77/300], Final Train Loss: 2.0739, Final Train Accuracy: 28.04%, Best Train Accuracy: 28.31, Loss to best acc:2.04%
#
# Epoch [77/300], Final Valid Loss: 2.2527, Final Valid Accuracy: 17.09%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [78/300], Final Train Loss: 2.0532, Final Train Accuracy: 27.51%, Best Train Accuracy: 28.31, Loss to best acc:2.04%
#
# Epoch [78/300], Final Valid Loss: 2.2536, Final Valid Accuracy: 17.05%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [79/300], Final Train Loss: 2.0595, Final Train Accuracy: 28.47%, Best Train Accuracy: 28.47, Loss to best acc:2.06%
#
# Epoch [79/300], Final Valid Loss: 2.2872, Final Valid Accuracy: 17.02%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [80/300], Final Train Loss: 2.0266, Final Train Accuracy: 28.78%, Best Train Accuracy: 28.78, Loss to best acc:2.03%
#
# Epoch [80/300], Final Valid Loss: 2.2095, Final Valid Accuracy: 17.05%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [81/300], Final Train Loss: 2.0864, Final Train Accuracy: 28.94%, Best Train Accuracy: 28.94, Loss to best acc:2.09%
#
# Epoch [81/300], Final Valid Loss: 2.2370, Final Valid Accuracy: 17.04%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [82/300], Final Train Loss: 2.0211, Final Train Accuracy: 27.92%, Best Train Accuracy: 28.94, Loss to best acc:2.09%
#
# Epoch [82/300], Final Valid Loss: 2.2349, Final Valid Accuracy: 17.04%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [83/300], Final Train Loss: 2.0555, Final Train Accuracy: 28.34%, Best Train Accuracy: 28.94, Loss to best acc:2.09%
#
# Epoch [83/300], Final Valid Loss: 2.2012, Final Valid Accuracy: 17.08%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [84/300], Final Train Loss: 2.0721, Final Train Accuracy: 28.30%, Best Train Accuracy: 28.94, Loss to best acc:2.09%
#
# Epoch [84/300], Final Valid Loss: 2.2237, Final Valid Accuracy: 17.10%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [85/300], Final Train Loss: 2.0775, Final Train Accuracy: 27.95%, Best Train Accuracy: 28.94, Loss to best acc:2.09%
#
# Epoch [85/300], Final Valid Loss: 2.2119, Final Valid Accuracy: 17.11%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [86/300], Final Train Loss: 2.0694, Final Train Accuracy: 28.52%, Best Train Accuracy: 28.94, Loss to best acc:2.09%
#
# Epoch [86/300], Final Valid Loss: 2.2431, Final Valid Accuracy: 17.10%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [87/300], Final Train Loss: 2.0459, Final Train Accuracy: 28.61%, Best Train Accuracy: 28.94, Loss to best acc:2.09%
#
# Epoch [87/300], Final Valid Loss: 2.1984, Final Valid Accuracy: 17.14%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [88/300], Final Train Loss: 2.0962, Final Train Accuracy: 28.67%, Best Train Accuracy: 28.94, Loss to best acc:2.09%
#
# Epoch [88/300], Final Valid Loss: 2.2161, Final Valid Accuracy: 17.16%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [89/300], Final Train Loss: 2.0466, Final Train Accuracy: 28.47%, Best Train Accuracy: 28.94, Loss to best acc:2.09%
#
# Epoch [89/300], Final Valid Loss: 2.2348, Final Valid Accuracy: 17.19%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [90/300], Final Train Loss: 2.0707, Final Train Accuracy: 28.50%, Best Train Accuracy: 28.94, Loss to best acc:2.09%
#
# Epoch [90/300], Final Valid Loss: 2.2687, Final Valid Accuracy: 17.16%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [91/300], Final Train Loss: 2.0843, Final Train Accuracy: 29.17%, Best Train Accuracy: 29.17, Loss to best acc:2.08%
#
# Epoch [91/300], Final Valid Loss: 2.2475, Final Valid Accuracy: 17.19%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [92/300], Final Train Loss: 2.0506, Final Train Accuracy: 28.60%, Best Train Accuracy: 29.17, Loss to best acc:2.08%
#
# Epoch [92/300], Final Valid Loss: 2.2584, Final Valid Accuracy: 17.17%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [93/300], Final Train Loss: 2.0324, Final Train Accuracy: 28.36%, Best Train Accuracy: 29.17, Loss to best acc:2.08%
#
# Epoch [93/300], Final Valid Loss: 2.2355, Final Valid Accuracy: 17.18%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [94/300], Final Train Loss: 2.0462, Final Train Accuracy: 28.67%, Best Train Accuracy: 29.17, Loss to best acc:2.08%
#
# Epoch [94/300], Final Valid Loss: 2.2440, Final Valid Accuracy: 17.17%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [95/300], Final Train Loss: 2.0523, Final Train Accuracy: 28.50%, Best Train Accuracy: 29.17, Loss to best acc:2.08%
#
# Epoch [95/300], Final Valid Loss: 2.1977, Final Valid Accuracy: 17.19%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [96/300], Final Train Loss: 2.0182, Final Train Accuracy: 28.07%, Best Train Accuracy: 29.17, Loss to best acc:2.08%
#
# Epoch [96/300], Final Valid Loss: 2.1965, Final Valid Accuracy: 17.21%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [97/300], Final Train Loss: 2.0104, Final Train Accuracy: 28.73%, Best Train Accuracy: 29.17, Loss to best acc:2.08%
#
# Epoch [97/300], Final Valid Loss: 2.2591, Final Valid Accuracy: 17.18%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [98/300], Final Train Loss: 2.0243, Final Train Accuracy: 28.67%, Best Train Accuracy: 29.17, Loss to best acc:2.08%
#
# Epoch [98/300], Final Valid Loss: 2.2647, Final Valid Accuracy: 17.18%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [99/300], Final Train Loss: 2.0777, Final Train Accuracy: 28.92%, Best Train Accuracy: 29.17, Loss to best acc:2.08%
#
# Epoch [99/300], Final Valid Loss: 2.2254, Final Valid Accuracy: 17.19%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [100/300], Final Train Loss: 2.0413, Final Train Accuracy: 29.21%, Best Train Accuracy: 29.21, Loss to best acc:2.04%
#
# Epoch [100/300], Final Valid Loss: 2.2544, Final Valid Accuracy: 17.21%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [101/300], Final Train Loss: 2.0314, Final Train Accuracy: 29.22%, Best Train Accuracy: 29.22, Loss to best acc:2.03%
#
# Epoch [101/300], Final Valid Loss: 2.2363, Final Valid Accuracy: 17.20%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [102/300], Final Train Loss: 2.0257, Final Train Accuracy: 29.37%, Best Train Accuracy: 29.37, Loss to best acc:2.03%
#
# Epoch [102/300], Final Valid Loss: 2.1964, Final Valid Accuracy: 17.23%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [103/300], Final Train Loss: 2.0637, Final Train Accuracy: 29.01%, Best Train Accuracy: 29.37, Loss to best acc:2.03%
#
# Epoch [103/300], Final Valid Loss: 2.2430, Final Valid Accuracy: 17.22%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [104/300], Final Train Loss: 2.0604, Final Train Accuracy: 28.57%, Best Train Accuracy: 29.37, Loss to best acc:2.03%
#
# Epoch [104/300], Final Valid Loss: 2.2353, Final Valid Accuracy: 17.20%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [105/300], Final Train Loss: 2.0434, Final Train Accuracy: 28.61%, Best Train Accuracy: 29.37, Loss to best acc:2.03%
#
# Epoch [105/300], Final Valid Loss: 2.2371, Final Valid Accuracy: 17.20%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [106/300], Final Train Loss: 2.0314, Final Train Accuracy: 29.40%, Best Train Accuracy: 29.40, Loss to best acc:2.03%
#
# Epoch [106/300], Final Valid Loss: 2.2428, Final Valid Accuracy: 17.20%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [107/300], Final Train Loss: 2.0199, Final Train Accuracy: 29.15%, Best Train Accuracy: 29.40, Loss to best acc:2.03%
#
# Epoch [107/300], Final Valid Loss: 2.2269, Final Valid Accuracy: 17.24%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [108/300], Final Train Loss: 2.0438, Final Train Accuracy: 28.73%, Best Train Accuracy: 29.40, Loss to best acc:2.03%
#
# Epoch [108/300], Final Valid Loss: 2.2160, Final Valid Accuracy: 17.24%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [109/300], Final Train Loss: 2.0219, Final Train Accuracy: 29.93%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [109/300], Final Valid Loss: 2.2280, Final Valid Accuracy: 17.23%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [110/300], Final Train Loss: 2.0471, Final Train Accuracy: 29.46%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [110/300], Final Valid Loss: 2.2585, Final Valid Accuracy: 17.23%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [111/300], Final Train Loss: 1.9992, Final Train Accuracy: 29.18%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [111/300], Final Valid Loss: 2.2147, Final Valid Accuracy: 17.25%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [112/300], Final Train Loss: 2.0268, Final Train Accuracy: 28.97%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [112/300], Final Valid Loss: 2.2466, Final Valid Accuracy: 17.25%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [113/300], Final Train Loss: 2.0157, Final Train Accuracy: 29.84%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [113/300], Final Valid Loss: 2.2242, Final Valid Accuracy: 17.25%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [114/300], Final Train Loss: 2.0293, Final Train Accuracy: 29.79%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [114/300], Final Valid Loss: 2.2457, Final Valid Accuracy: 17.28%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [115/300], Final Train Loss: 1.9971, Final Train Accuracy: 29.08%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [115/300], Final Valid Loss: 2.2082, Final Valid Accuracy: 17.33%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [116/300], Final Train Loss: 2.0425, Final Train Accuracy: 28.99%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [116/300], Final Valid Loss: 2.2526, Final Valid Accuracy: 17.33%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [117/300], Final Train Loss: 2.0069, Final Train Accuracy: 29.66%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [117/300], Final Valid Loss: 2.2306, Final Valid Accuracy: 17.36%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [118/300], Final Train Loss: 2.0346, Final Train Accuracy: 29.39%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [118/300], Final Valid Loss: 2.2350, Final Valid Accuracy: 17.36%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [119/300], Final Train Loss: 2.0200, Final Train Accuracy: 29.70%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [119/300], Final Valid Loss: 2.1978, Final Valid Accuracy: 17.38%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [120/300], Final Train Loss: 2.0549, Final Train Accuracy: 29.35%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [120/300], Final Valid Loss: 2.2672, Final Valid Accuracy: 17.39%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [121/300], Final Train Loss: 2.0318, Final Train Accuracy: 29.06%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [121/300], Final Valid Loss: 2.2294, Final Valid Accuracy: 17.39%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [122/300], Final Train Loss: 2.0487, Final Train Accuracy: 29.58%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [122/300], Final Valid Loss: 2.2644, Final Valid Accuracy: 17.40%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [123/300], Final Train Loss: 2.0225, Final Train Accuracy: 29.01%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [123/300], Final Valid Loss: 2.2074, Final Valid Accuracy: 17.42%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [124/300], Final Train Loss: 2.0487, Final Train Accuracy: 29.52%, Best Train Accuracy: 29.93, Loss to best acc:2.02%
#
# Epoch [124/300], Final Valid Loss: 2.2351, Final Valid Accuracy: 17.43%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [125/300], Final Train Loss: 2.0448, Final Train Accuracy: 30.06%, Best Train Accuracy: 30.06, Loss to best acc:2.04%
#
# Epoch [125/300], Final Valid Loss: 2.2540, Final Valid Accuracy: 17.44%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [126/300], Final Train Loss: 2.0364, Final Train Accuracy: 29.98%, Best Train Accuracy: 30.06, Loss to best acc:2.04%
#
# Epoch [126/300], Final Valid Loss: 2.2691, Final Valid Accuracy: 17.41%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [127/300], Final Train Loss: 2.0228, Final Train Accuracy: 29.76%, Best Train Accuracy: 30.06, Loss to best acc:2.04%
#
# Epoch [127/300], Final Valid Loss: 2.2673, Final Valid Accuracy: 17.38%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [128/300], Final Train Loss: 2.0686, Final Train Accuracy: 28.65%, Best Train Accuracy: 30.06, Loss to best acc:2.04%
#
# Epoch [128/300], Final Valid Loss: 2.2648, Final Valid Accuracy: 17.36%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [129/300], Final Train Loss: 2.0502, Final Train Accuracy: 29.73%, Best Train Accuracy: 30.06, Loss to best acc:2.04%
#
# Epoch [129/300], Final Valid Loss: 2.2522, Final Valid Accuracy: 17.36%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [130/300], Final Train Loss: 2.0187, Final Train Accuracy: 30.09%, Best Train Accuracy: 30.09, Loss to best acc:2.02%
#
# Epoch [130/300], Final Valid Loss: 2.2624, Final Valid Accuracy: 17.34%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [131/300], Final Train Loss: 2.0375, Final Train Accuracy: 29.84%, Best Train Accuracy: 30.09, Loss to best acc:2.02%
#
# Epoch [131/300], Final Valid Loss: 2.2531, Final Valid Accuracy: 17.36%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [132/300], Final Train Loss: 2.0273, Final Train Accuracy: 29.68%, Best Train Accuracy: 30.09, Loss to best acc:2.02%
#
# Epoch [132/300], Final Valid Loss: 2.2387, Final Valid Accuracy: 17.38%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [133/300], Final Train Loss: 2.0553, Final Train Accuracy: 29.64%, Best Train Accuracy: 30.09, Loss to best acc:2.02%
#
# Epoch [133/300], Final Valid Loss: 2.2362, Final Valid Accuracy: 17.40%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [134/300], Final Train Loss: 1.9928, Final Train Accuracy: 30.15%, Best Train Accuracy: 30.15, Loss to best acc:1.99%
#
# Epoch [134/300], Final Valid Loss: 2.2487, Final Valid Accuracy: 17.41%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [135/300], Final Train Loss: 2.0146, Final Train Accuracy: 30.42%, Best Train Accuracy: 30.42, Loss to best acc:2.01%
#
# Epoch [135/300], Final Valid Loss: 2.2431, Final Valid Accuracy: 17.42%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [136/300], Final Train Loss: 2.0137, Final Train Accuracy: 29.87%, Best Train Accuracy: 30.42, Loss to best acc:2.01%
#
# Epoch [136/300], Final Valid Loss: 2.2259, Final Valid Accuracy: 17.41%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [137/300], Final Train Loss: 2.0048, Final Train Accuracy: 29.70%, Best Train Accuracy: 30.42, Loss to best acc:2.01%
#
# Epoch [137/300], Final Valid Loss: 2.2659, Final Valid Accuracy: 17.37%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [138/300], Final Train Loss: 2.0312, Final Train Accuracy: 29.72%, Best Train Accuracy: 30.42, Loss to best acc:2.01%
#
# Epoch [138/300], Final Valid Loss: 2.2577, Final Valid Accuracy: 17.38%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [139/300], Final Train Loss: 2.0328, Final Train Accuracy: 29.85%, Best Train Accuracy: 30.42, Loss to best acc:2.01%
#
# Epoch [139/300], Final Valid Loss: 2.2315, Final Valid Accuracy: 17.38%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [140/300], Final Train Loss: 2.0353, Final Train Accuracy: 30.64%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [140/300], Final Valid Loss: 2.2043, Final Valid Accuracy: 17.42%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [141/300], Final Train Loss: 2.0134, Final Train Accuracy: 30.00%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [141/300], Final Valid Loss: 2.2168, Final Valid Accuracy: 17.45%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [142/300], Final Train Loss: 2.0260, Final Train Accuracy: 30.58%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [142/300], Final Valid Loss: 2.2204, Final Valid Accuracy: 17.45%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [143/300], Final Train Loss: 2.0443, Final Train Accuracy: 30.21%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [143/300], Final Valid Loss: 2.2424, Final Valid Accuracy: 17.44%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [144/300], Final Train Loss: 2.0635, Final Train Accuracy: 30.62%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [144/300], Final Valid Loss: 2.2494, Final Valid Accuracy: 17.44%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [145/300], Final Train Loss: 2.0298, Final Train Accuracy: 30.08%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [145/300], Final Valid Loss: 2.2437, Final Valid Accuracy: 17.45%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [146/300], Final Train Loss: 2.0276, Final Train Accuracy: 30.45%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [146/300], Final Valid Loss: 2.2210, Final Valid Accuracy: 17.47%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [147/300], Final Train Loss: 2.0073, Final Train Accuracy: 30.42%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [147/300], Final Valid Loss: 2.2404, Final Valid Accuracy: 17.48%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [148/300], Final Train Loss: 2.0377, Final Train Accuracy: 29.72%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [148/300], Final Valid Loss: 2.2906, Final Valid Accuracy: 17.47%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [149/300], Final Train Loss: 2.0340, Final Train Accuracy: 29.98%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [149/300], Final Valid Loss: 2.2677, Final Valid Accuracy: 17.45%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [150/300], Final Train Loss: 2.0297, Final Train Accuracy: 30.63%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [150/300], Final Valid Loss: 2.2408, Final Valid Accuracy: 17.46%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [151/300], Final Train Loss: 2.0195, Final Train Accuracy: 30.39%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [151/300], Final Valid Loss: 2.2403, Final Valid Accuracy: 17.46%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [152/300], Final Train Loss: 1.9974, Final Train Accuracy: 30.47%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [152/300], Final Valid Loss: 2.2090, Final Valid Accuracy: 17.48%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [153/300], Final Train Loss: 2.0093, Final Train Accuracy: 30.50%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [153/300], Final Valid Loss: 2.2554, Final Valid Accuracy: 17.47%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [154/300], Final Train Loss: 2.0238, Final Train Accuracy: 30.24%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [154/300], Final Valid Loss: 2.2087, Final Valid Accuracy: 17.48%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [155/300], Final Train Loss: 1.9903, Final Train Accuracy: 30.60%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [155/300], Final Valid Loss: 2.2646, Final Valid Accuracy: 17.47%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [156/300], Final Train Loss: 2.0487, Final Train Accuracy: 29.85%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [156/300], Final Valid Loss: 2.2286, Final Valid Accuracy: 17.49%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [157/300], Final Train Loss: 2.0302, Final Train Accuracy: 30.16%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [157/300], Final Valid Loss: 2.2299, Final Valid Accuracy: 17.48%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [158/300], Final Train Loss: 2.0444, Final Train Accuracy: 30.37%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [158/300], Final Valid Loss: 2.2454, Final Valid Accuracy: 17.48%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [159/300], Final Train Loss: 2.0069, Final Train Accuracy: 30.46%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [159/300], Final Valid Loss: 2.2232, Final Valid Accuracy: 17.49%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [160/300], Final Train Loss: 2.0206, Final Train Accuracy: 30.07%, Best Train Accuracy: 30.64, Loss to best acc:2.04%
#
# Epoch [160/300], Final Valid Loss: 2.2055, Final Valid Accuracy: 17.51%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [161/300], Final Train Loss: 1.9965, Final Train Accuracy: 30.74%, Best Train Accuracy: 30.74, Loss to best acc:2.00%
#
# Epoch [161/300], Final Valid Loss: 2.2138, Final Valid Accuracy: 17.52%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [162/300], Final Train Loss: 2.0377, Final Train Accuracy: 30.86%, Best Train Accuracy: 30.86, Loss to best acc:2.04%
#
# Epoch [162/300], Final Valid Loss: 2.2449, Final Valid Accuracy: 17.51%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [163/300], Final Train Loss: 2.0191, Final Train Accuracy: 30.71%, Best Train Accuracy: 30.86, Loss to best acc:2.04%
#
# Epoch [163/300], Final Valid Loss: 2.1771, Final Valid Accuracy: 17.53%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [164/300], Final Train Loss: 2.0168, Final Train Accuracy: 30.89%, Best Train Accuracy: 30.89, Loss to best acc:2.02%
#
# Epoch [164/300], Final Valid Loss: 2.2481, Final Valid Accuracy: 17.54%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [165/300], Final Train Loss: 1.9844, Final Train Accuracy: 30.71%, Best Train Accuracy: 30.89, Loss to best acc:2.02%
#
# Epoch [165/300], Final Valid Loss: 2.1933, Final Valid Accuracy: 17.56%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [166/300], Final Train Loss: 2.0182, Final Train Accuracy: 30.91%, Best Train Accuracy: 30.91, Loss to best acc:2.02%
#
# Epoch [166/300], Final Valid Loss: 2.2186, Final Valid Accuracy: 17.56%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [167/300], Final Train Loss: 2.0726, Final Train Accuracy: 31.01%, Best Train Accuracy: 31.01, Loss to best acc:2.07%
#
# Epoch [167/300], Final Valid Loss: 2.2095, Final Valid Accuracy: 17.57%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [168/300], Final Train Loss: 2.0414, Final Train Accuracy: 30.67%, Best Train Accuracy: 31.01, Loss to best acc:2.07%
#
# Epoch [168/300], Final Valid Loss: 2.2337, Final Valid Accuracy: 17.57%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [169/300], Final Train Loss: 2.0350, Final Train Accuracy: 30.40%, Best Train Accuracy: 31.01, Loss to best acc:2.07%
#
# Epoch [169/300], Final Valid Loss: 2.2175, Final Valid Accuracy: 17.57%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [170/300], Final Train Loss: 2.0300, Final Train Accuracy: 31.42%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [170/300], Final Valid Loss: 2.2573, Final Valid Accuracy: 17.56%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [171/300], Final Train Loss: 2.0586, Final Train Accuracy: 31.17%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [171/300], Final Valid Loss: 2.1980, Final Valid Accuracy: 17.58%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [172/300], Final Train Loss: 2.0486, Final Train Accuracy: 31.08%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [172/300], Final Valid Loss: 2.2276, Final Valid Accuracy: 17.57%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [173/300], Final Train Loss: 2.0083, Final Train Accuracy: 30.74%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [173/300], Final Valid Loss: 2.2500, Final Valid Accuracy: 17.54%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [174/300], Final Train Loss: 2.0137, Final Train Accuracy: 31.33%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [174/300], Final Valid Loss: 2.2267, Final Valid Accuracy: 17.53%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [175/300], Final Train Loss: 2.0494, Final Train Accuracy: 30.21%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [175/300], Final Valid Loss: 2.2076, Final Valid Accuracy: 17.54%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [176/300], Final Train Loss: 2.0306, Final Train Accuracy: 30.93%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [176/300], Final Valid Loss: 2.2208, Final Valid Accuracy: 17.56%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [177/300], Final Train Loss: 2.0209, Final Train Accuracy: 31.24%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [177/300], Final Valid Loss: 2.2350, Final Valid Accuracy: 17.54%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [178/300], Final Train Loss: 2.0336, Final Train Accuracy: 31.20%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [178/300], Final Valid Loss: 2.1978, Final Valid Accuracy: 17.55%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [179/300], Final Train Loss: 2.0464, Final Train Accuracy: 31.25%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [179/300], Final Valid Loss: 2.2411, Final Valid Accuracy: 17.55%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [180/300], Final Train Loss: 2.0427, Final Train Accuracy: 31.22%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [180/300], Final Valid Loss: 2.2477, Final Valid Accuracy: 17.53%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [181/300], Final Train Loss: 2.0666, Final Train Accuracy: 30.71%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [181/300], Final Valid Loss: 2.2021, Final Valid Accuracy: 17.53%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [182/300], Final Train Loss: 2.0555, Final Train Accuracy: 30.94%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# Epoch [182/300], Final Valid Loss: 2.2220, Final Valid Accuracy: 17.54%, Best Valid Accuracy: 19.35%, Loss to best Valid accuracy:2.21
#
# Epoch [183/300], Final Train Loss: 2.0203, Final Train Accuracy: 31.06%, Best Train Accuracy: 31.42, Loss to best acc:2.03%
#
# ...
#
# Epoch [241/300], Final Valid Loss: 2.2197, Final Valid Accuracy: 19.89%, Best Valid Accuracy: 19.89%, Loss to best Valid accuracy:2.22
#
# Epoch [242/300], Final Train Loss: 1.6808, Final Train Accuracy: 70.04%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [242/300], Final Valid Loss: 2.2157, Final Valid Accuracy: 19.89%, Best Valid Accuracy: 19.89%, Loss to best Valid accuracy:2.22
#
# Epoch [243/300], Final Train Loss: 1.6693, Final Train Accuracy: 70.15%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [243/300], Final Valid Loss: 2.2078, Final Valid Accuracy: 19.90%, Best Valid Accuracy: 19.90%, Loss to best Valid accuracy:2.21
#
# Epoch [244/300], Final Train Loss: 1.6528, Final Train Accuracy: 71.32%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [244/300], Final Valid Loss: 2.2458, Final Valid Accuracy: 19.91%, Best Valid Accuracy: 19.91%, Loss to best Valid accuracy:2.25
#
# Epoch [245/300], Final Train Loss: 1.6783, Final Train Accuracy: 71.24%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [245/300], Final Valid Loss: 2.2086, Final Valid Accuracy: 19.92%, Best Valid Accuracy: 19.92%, Loss to best Valid accuracy:2.21
#
# Epoch [246/300], Final Train Loss: 1.6799, Final Train Accuracy: 69.82%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [246/300], Final Valid Loss: 2.2148, Final Valid Accuracy: 19.91%, Best Valid Accuracy: 19.92%, Loss to best Valid accuracy:2.21
#
# Epoch [247/300], Final Train Loss: 1.7094, Final Train Accuracy: 70.78%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [247/300], Final Valid Loss: 2.2707, Final Valid Accuracy: 19.89%, Best Valid Accuracy: 19.92%, Loss to best Valid accuracy:2.21
#
# Epoch [248/300], Final Train Loss: 1.6594, Final Train Accuracy: 71.40%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [248/300], Final Valid Loss: 2.2587, Final Valid Accuracy: 19.88%, Best Valid Accuracy: 19.92%, Loss to best Valid accuracy:2.21
#
# Epoch [249/300], Final Train Loss: 1.6779, Final Train Accuracy: 70.86%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [249/300], Final Valid Loss: 2.2375, Final Valid Accuracy: 19.89%, Best Valid Accuracy: 19.92%, Loss to best Valid accuracy:2.21
#
# Epoch [250/300], Final Train Loss: 1.6720, Final Train Accuracy: 70.87%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [250/300], Final Valid Loss: 2.2511, Final Valid Accuracy: 19.88%, Best Valid Accuracy: 19.92%, Loss to best Valid accuracy:2.21
#
# Epoch [251/300], Final Train Loss: 1.6946, Final Train Accuracy: 71.36%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [251/300], Final Valid Loss: 2.2093, Final Valid Accuracy: 19.88%, Best Valid Accuracy: 19.92%, Loss to best Valid accuracy:2.21
#
# Epoch [252/300], Final Train Loss: 1.6511, Final Train Accuracy: 71.33%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [252/300], Final Valid Loss: 2.2121, Final Valid Accuracy: 19.88%, Best Valid Accuracy: 19.92%, Loss to best Valid accuracy:2.21
#
# Epoch [253/300], Final Train Loss: 1.6381, Final Train Accuracy: 71.27%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [253/300], Final Valid Loss: 2.2093, Final Valid Accuracy: 19.90%, Best Valid Accuracy: 19.92%, Loss to best Valid accuracy:2.21
#
# Epoch [254/300], Final Train Loss: 1.6875, Final Train Accuracy: 71.60%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [254/300], Final Valid Loss: 2.1995, Final Valid Accuracy: 19.92%, Best Valid Accuracy: 19.92%, Loss to best Valid accuracy:2.20
#
# Epoch [255/300], Final Train Loss: 1.6513, Final Train Accuracy: 71.21%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [255/300], Final Valid Loss: 2.2013, Final Valid Accuracy: 19.93%, Best Valid Accuracy: 19.93%, Loss to best Valid accuracy:2.20
#
# Epoch [256/300], Final Train Loss: 1.6968, Final Train Accuracy: 71.07%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [256/300], Final Valid Loss: 2.2114, Final Valid Accuracy: 19.94%, Best Valid Accuracy: 19.94%, Loss to best Valid accuracy:2.21
#
# Epoch [257/300], Final Train Loss: 1.6667, Final Train Accuracy: 70.93%, Best Train Accuracy: 71.71, Loss to best acc:1.66%
#
# Epoch [257/300], Final Valid Loss: 2.2090, Final Valid Accuracy: 19.96%, Best Valid Accuracy: 19.96%, Loss to best Valid accuracy:2.21
#
# Epoch [258/300], Final Train Loss: 1.6647, Final Train Accuracy: 71.87%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [258/300], Final Valid Loss: 2.2083, Final Valid Accuracy: 19.97%, Best Valid Accuracy: 19.97%, Loss to best Valid accuracy:2.21
#
# Epoch [259/300], Final Train Loss: 1.6631, Final Train Accuracy: 71.81%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [259/300], Final Valid Loss: 2.1981, Final Valid Accuracy: 19.98%, Best Valid Accuracy: 19.98%, Loss to best Valid accuracy:2.20
#
# Epoch [260/300], Final Train Loss: 1.6643, Final Train Accuracy: 71.20%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [260/300], Final Valid Loss: 2.2092, Final Valid Accuracy: 19.99%, Best Valid Accuracy: 19.99%, Loss to best Valid accuracy:2.21
#
# Epoch [261/300], Final Train Loss: 1.6371, Final Train Accuracy: 71.52%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [261/300], Final Valid Loss: 2.2493, Final Valid Accuracy: 19.98%, Best Valid Accuracy: 19.99%, Loss to best Valid accuracy:2.21
#
# Epoch [262/300], Final Train Loss: 1.6549, Final Train Accuracy: 71.07%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [262/300], Final Valid Loss: 2.1985, Final Valid Accuracy: 20.00%, Best Valid Accuracy: 20.00%, Loss to best Valid accuracy:2.20
#
# Epoch [263/300], Final Train Loss: 1.6669, Final Train Accuracy: 71.63%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [263/300], Final Valid Loss: 2.2476, Final Valid Accuracy: 20.00%, Best Valid Accuracy: 20.00%, Loss to best Valid accuracy:2.25
#
# Epoch [264/300], Final Train Loss: 1.6748, Final Train Accuracy: 71.46%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [264/300], Final Valid Loss: 2.2153, Final Valid Accuracy: 20.00%, Best Valid Accuracy: 20.00%, Loss to best Valid accuracy:2.22
#
# Epoch [265/300], Final Train Loss: 1.7046, Final Train Accuracy: 71.29%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [265/300], Final Valid Loss: 2.1952, Final Valid Accuracy: 20.01%, Best Valid Accuracy: 20.01%, Loss to best Valid accuracy:2.20
#
# Epoch [266/300], Final Train Loss: 1.6786, Final Train Accuracy: 71.12%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [266/300], Final Valid Loss: 2.2424, Final Valid Accuracy: 20.01%, Best Valid Accuracy: 20.01%, Loss to best Valid accuracy:2.24
#
# Epoch [267/300], Final Train Loss: 1.6689, Final Train Accuracy: 71.65%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [267/300], Final Valid Loss: 2.2019, Final Valid Accuracy: 20.03%, Best Valid Accuracy: 20.03%, Loss to best Valid accuracy:2.20
#
# Epoch [268/300], Final Train Loss: 1.7037, Final Train Accuracy: 70.86%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [268/300], Final Valid Loss: 2.2130, Final Valid Accuracy: 20.03%, Best Valid Accuracy: 20.03%, Loss to best Valid accuracy:2.21
#
# Epoch [269/300], Final Train Loss: 1.6905, Final Train Accuracy: 71.22%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [269/300], Final Valid Loss: 2.1987, Final Valid Accuracy: 20.04%, Best Valid Accuracy: 20.04%, Loss to best Valid accuracy:2.20
#
# Epoch [270/300], Final Train Loss: 1.7071, Final Train Accuracy: 71.55%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [270/300], Final Valid Loss: 2.2153, Final Valid Accuracy: 20.05%, Best Valid Accuracy: 20.05%, Loss to best Valid accuracy:2.22
#
# Epoch [271/300], Final Train Loss: 1.6301, Final Train Accuracy: 71.50%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [271/300], Final Valid Loss: 2.2345, Final Valid Accuracy: 20.06%, Best Valid Accuracy: 20.06%, Loss to best Valid accuracy:2.23
#
# Epoch [272/300], Final Train Loss: 1.6415, Final Train Accuracy: 71.52%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [272/300], Final Valid Loss: 2.2069, Final Valid Accuracy: 20.07%, Best Valid Accuracy: 20.07%, Loss to best Valid accuracy:2.21
#
# Epoch [273/300], Final Train Loss: 1.6483, Final Train Accuracy: 71.68%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [273/300], Final Valid Loss: 2.2206, Final Valid Accuracy: 20.09%, Best Valid Accuracy: 20.09%, Loss to best Valid accuracy:2.22
#
# Epoch [274/300], Final Train Loss: 1.6719, Final Train Accuracy: 71.15%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [274/300], Final Valid Loss: 2.2383, Final Valid Accuracy: 20.08%, Best Valid Accuracy: 20.09%, Loss to best Valid accuracy:2.22
#
# Epoch [275/300], Final Train Loss: 1.6922, Final Train Accuracy: 71.86%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [275/300], Final Valid Loss: 2.2829, Final Valid Accuracy: 20.06%, Best Valid Accuracy: 20.09%, Loss to best Valid accuracy:2.22
#
# Epoch [276/300], Final Train Loss: 1.6587, Final Train Accuracy: 71.53%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [276/300], Final Valid Loss: 2.2437, Final Valid Accuracy: 20.06%, Best Valid Accuracy: 20.09%, Loss to best Valid accuracy:2.22
#
# Epoch [277/300], Final Train Loss: 1.6736, Final Train Accuracy: 71.17%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [277/300], Final Valid Loss: 2.2317, Final Valid Accuracy: 20.06%, Best Valid Accuracy: 20.09%, Loss to best Valid accuracy:2.22
#
# Epoch [278/300], Final Train Loss: 1.6432, Final Train Accuracy: 71.60%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [278/300], Final Valid Loss: 2.1897, Final Valid Accuracy: 20.07%, Best Valid Accuracy: 20.09%, Loss to best Valid accuracy:2.22
#
# Epoch [279/300], Final Train Loss: 1.6550, Final Train Accuracy: 71.13%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [279/300], Final Valid Loss: 2.1962, Final Valid Accuracy: 20.07%, Best Valid Accuracy: 20.09%, Loss to best Valid accuracy:2.22
#
# Epoch [280/300], Final Train Loss: 1.6608, Final Train Accuracy: 71.21%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [280/300], Final Valid Loss: 2.1929, Final Valid Accuracy: 20.09%, Best Valid Accuracy: 20.09%, Loss to best Valid accuracy:2.19
#
# Epoch [281/300], Final Train Loss: 1.6933, Final Train Accuracy: 71.48%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [281/300], Final Valid Loss: 2.2265, Final Valid Accuracy: 20.08%, Best Valid Accuracy: 20.09%, Loss to best Valid accuracy:2.19
#
# Epoch [282/300], Final Train Loss: 1.6696, Final Train Accuracy: 70.92%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [282/300], Final Valid Loss: 2.2064, Final Valid Accuracy: 20.10%, Best Valid Accuracy: 20.10%, Loss to best Valid accuracy:2.21
#
# Epoch [283/300], Final Train Loss: 1.6395, Final Train Accuracy: 71.66%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [283/300], Final Valid Loss: 2.2172, Final Valid Accuracy: 20.09%, Best Valid Accuracy: 20.10%, Loss to best Valid accuracy:2.21
#
# Epoch [284/300], Final Train Loss: 1.6558, Final Train Accuracy: 70.67%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [284/300], Final Valid Loss: 2.2651, Final Valid Accuracy: 20.08%, Best Valid Accuracy: 20.10%, Loss to best Valid accuracy:2.21
#
# Epoch [285/300], Final Train Loss: 1.6615, Final Train Accuracy: 71.62%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [285/300], Final Valid Loss: 2.2296, Final Valid Accuracy: 20.09%, Best Valid Accuracy: 20.10%, Loss to best Valid accuracy:2.21
#
# Epoch [286/300], Final Train Loss: 1.6597, Final Train Accuracy: 71.80%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [286/300], Final Valid Loss: 2.2156, Final Valid Accuracy: 20.09%, Best Valid Accuracy: 20.10%, Loss to best Valid accuracy:2.21
#
# Epoch [287/300], Final Train Loss: 1.6834, Final Train Accuracy: 71.83%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [287/300], Final Valid Loss: 2.2310, Final Valid Accuracy: 20.10%, Best Valid Accuracy: 20.10%, Loss to best Valid accuracy:2.23
#
# Epoch [288/300], Final Train Loss: 1.6925, Final Train Accuracy: 71.22%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [288/300], Final Valid Loss: 2.2686, Final Valid Accuracy: 20.09%, Best Valid Accuracy: 20.10%, Loss to best Valid accuracy:2.23
#
# Epoch [289/300], Final Train Loss: 1.6780, Final Train Accuracy: 71.64%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [289/300], Final Valid Loss: 2.2286, Final Valid Accuracy: 20.09%, Best Valid Accuracy: 20.10%, Loss to best Valid accuracy:2.23
#
# Epoch [290/300], Final Train Loss: 1.6756, Final Train Accuracy: 71.71%, Best Train Accuracy: 71.87, Loss to best acc:1.66%
#
# Epoch [290/300], Final Valid Loss: 2.1976, Final Valid Accuracy: 20.09%, Best Valid Accuracy: 20.10%, Loss to best Valid accuracy:2.23
#
# Epoch [291/300], Final Train Loss: 1.6770, Final Train Accuracy: 72.53%, Best Train Accuracy: 72.53, Loss to best acc:1.68%
#
# Epoch [291/300], Final Valid Loss: 2.2016, Final Valid Accuracy: 20.11%, Best Valid Accuracy: 20.11%, Loss to best Valid accuracy:2.20
#
# Epoch [292/300], Final Train Loss: 1.6663, Final Train Accuracy: 71.63%, Best Train Accuracy: 72.53, Loss to best acc:1.68%
#
# Epoch [292/300], Final Valid Loss: 2.1941, Final Valid Accuracy: 20.11%, Best Valid Accuracy: 20.11%, Loss to best Valid accuracy:2.19
#
# Epoch [293/300], Final Train Loss: 1.6420, Final Train Accuracy: 71.97%, Best Train Accuracy: 72.53, Loss to best acc:1.68%
#
# Epoch [293/300], Final Valid Loss: 2.2049, Final Valid Accuracy: 20.12%, Best Valid Accuracy: 20.12%, Loss to best Valid accuracy:2.20
#
# Epoch [294/300], Final Train Loss: 1.6749, Final Train Accuracy: 72.01%, Best Train Accuracy: 72.53, Loss to best acc:1.68%
#
# Epoch [294/300], Final Valid Loss: 2.1951, Final Valid Accuracy: 20.13%, Best Valid Accuracy: 20.13%, Loss to best Valid accuracy:2.20
#
# Epoch [295/300], Final Train Loss: 1.6863, Final Train Accuracy: 71.03%, Best Train Accuracy: 72.53, Loss to best acc:1.68%
#
# Epoch [295/300], Final Valid Loss: 2.1982, Final Valid Accuracy: 20.13%, Best Valid Accuracy: 20.13%, Loss to best Valid accuracy:2.20
#
# Epoch [296/300], Final Train Loss: 1.6824, Final Train Accuracy: 71.10%, Best Train Accuracy: 72.53, Loss to best acc:1.68%
#
# Epoch [296/300], Final Valid Loss: 2.2348, Final Valid Accuracy: 20.13%, Best Valid Accuracy: 20.13%, Loss to best Valid accuracy:2.20
#
# Epoch [297/300], Final Train Loss: 1.6892, Final Train Accuracy: 71.78%, Best Train Accuracy: 72.53, Loss to best acc:1.68%
#
# Epoch [297/300], Final Valid Loss: 2.1941, Final Valid Accuracy: 20.14%, Best Valid Accuracy: 20.14%, Loss to best Valid accuracy:2.19
#
# Epoch [298/300], Final Train Loss: 1.6812, Final Train Accuracy: 72.20%, Best Train Accuracy: 72.53, Loss to best acc:1.68%
#
# Epoch [298/300], Final Valid Loss: 2.1817, Final Valid Accuracy: 20.15%, Best Valid Accuracy: 20.15%, Loss to best Valid accuracy:2.18
#
# Epoch [299/300], Final Train Loss: 1.7035, Final Train Accuracy: 72.00%, Best Train Accuracy: 72.53, Loss to best acc:1.68%
#
# Epoch [299/300], Final Valid Loss: 2.2106, Final Valid Accuracy: 20.17%, Best Valid Accuracy: 20.17%, Loss to best Valid accuracy:2.21
#
# Epoch [300/300], Final Train Loss: 1.6536, Final Train Accuracy: 72.37%, Best Train Accuracy: 72.53, Loss to best acc:1.68%
#
# Epoch [300/300], Final Valid Loss: 2.1813, Final Valid Accuracy: 20.18%, Best Valid Accuracy: 20.18%, Loss to best Valid accuracy:2.18
#
# 模型参数已保存为logs-ReLeNet-0914\scale=0.9.pth
#
# {'训练的模型的保留路径': 'logs-ReLeNet-0914\\scale=0.9.pth', '在测试集中的最终损失': 2.181304693222046, '在测试集中的最终准确率': 0.20182333333333333, '在测试集中的最佳准确率': 0.20182333333333333, '在训练集中的最终准确率': 0.7237, '在训练集中的最佳准确率': 0.72528, '在训练集中的最终损失': 1.6536004543304443, '在训练集中的最佳损失': 1.6770280599594116}
# 字典保存在文件中
