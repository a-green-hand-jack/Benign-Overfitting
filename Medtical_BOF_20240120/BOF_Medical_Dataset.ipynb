# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 考察医学影像数据的BOF

# %% [markdown]
# ## ISIC2018

# %%
from ISIC2018.isic_BOF import CompareBOF

folder = ".\\Result\\old_crop\\isic2"
test_BOF = CompareBOF(file_path=folder, target_pkl="bof.pkl", aug_name='crop')

print(len(test_BOF.comb_BOF))
test_BOF.draw_BOF(net_name="data", aug_name="crop")
# Out:
# 64

# %%
from ISIC2018.isic_BOF import CompareBOF

folder = ".\\Result\\new_aug_20240120\\ISIC2018"
test_BOF = CompareBOF(file_path=folder, target_pkl="bof.pkl", aug_name='crop')

print(len(test_BOF.comb_BOF))
test_BOF.draw_BOF(net_name="data", aug_name="crop")
# Out:
# 64

# %%
from ISIC2018.isic_BOF import CompareBOF

folder = ".\\Result\\new_aug_20240120_angle\\ISIC2018"
test_BOF = CompareBOF(file_path=folder, target_pkl="bof.pkl", aug_name='angle')

print(len(test_BOF.comb_BOF))
test_BOF.draw_BOF(net_name="data", aug_name="angle")
# Out:
# 180

# %% [markdown]
# ## BUSI

# %%
from ISIC2018.isic_BOF import CompareBOF

folder = ".\\Result\\MedticlDataset\\BUSI"
test_BOF = CompareBOF(file_path=folder, target_pkl="bof.pkl", aug_name='crop')

print(len(test_BOF.comb_BOF))
test_BOF.draw_BOF(net_name="data", aug_name="crop")
# Out:
# 32

# %%
from ISIC2018.isic_BOF import CompareBOF

folder = ".\\Result\\new_aug_20240120\\BUSI"
test_BOF = CompareBOF(file_path=folder, target_pkl="bof.pkl", aug_name='crop')

print(len(test_BOF.comb_BOF))
test_BOF.draw_BOF(net_name="data", aug_name="crop")
# Out:
# 23

# %%
from ISIC2018.isic_BOF import CompareBOF

folder = ".\\Result\\new_aug_20240120_angle\\BUSI"
test_BOF = CompareBOF(file_path=folder, target_pkl="bof.pkl", aug_name='angle')

print(len(test_BOF.comb_BOF))
test_BOF.draw_BOF(net_name="data", aug_name="angle")
# Out:
# 180
