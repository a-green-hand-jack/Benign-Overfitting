# %% [markdown]
# # 提高准确率
#
# 之前的模型的准确率似乎有一些太低了,大约只有28%-30%左右,这样可能会在分析中产生一些新的问题.而我们期待的正确率可以在50%附近,通过提高模型的复杂度自然可以轻易的做到这一点,但是那样在计算上会花费太多时间,为了节约算力,我考虑使用更好的optimizer和scheduler,也就是利用超参数实现准确率的提高.

# %% [markdown]
# ## MLP网络---不变
# 这里依旧采用之前的MLP模型

# %%
import torch.nn as nn
import torch.nn.functional as F

''' MLP '''
class MLP(nn.Module):
    def __init__(self, channel=3, num_classes=10, im_size=(32, 32)):
        super(MLP, self).__init__()
        self.fc_1 = nn.Linear(im_size[0] * im_size[1]*channel, 512)
        self.fc_2 = nn.Linear(512, 512)
        self.fc_3 = nn.Linear(512, num_classes)

    def forward(self, x):
        out = x.view(x.size(0), -1)
        out = F.relu(self.fc_1(out))
        out = F.relu(self.fc_2(out))
        out = self.fc_3(out)
        return out

# %% [markdown]
# ## 新的模型
#
# 采用**Adam**作为optimizer,采用**torch.optim.lr_scheduler.LambdaLR**实现线性动态的对学习率的调整

# %%
import torch
import torch.nn as nn
from torchvision.transforms import ToTensor
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
import torchvision
from torchvision.datasets import CIFAR10
import numpy as np
import random
from get_rank_cpu_0904 import Effective_Ranks, get_Effective_Ranks
from torch.optim.lr_scheduler import LambdaLR   # 这个用来实现学习率的线性变化
from torch.optim.lr_scheduler import CosineAnnealingLR  # 实现cos函数式的变化
from load_dataset import get_data_loader

def get_scale(scale, writer,  
            device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu"), train_loader=None, valid_loader=None, test_loader=None, channel=3,
            num_classes=10,
            im_size=(32, 32),
            # 可能需要的超参数
            momentum = 0.9,
            weight_decay = 0.0005,
            initial_lr = 0.1,
            num_epochs = 100):

  # -------------------------------------------------创建模型实例并将其移至 GPU -----------------------------------------------------
  # model = MLP(channel=channel, num_classes=num_classes, im_size=im_size)
  model = MLP()
  model.to(device)

  # 定义损失函数/优化器/学习率
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(
    model.parameters(),
    lr=initial_lr,  # 这里我只想关心学习率的影响,所以其他的参数先采用默认值
    betas=(0.9, 0.999),
    eps=1e-8,
    weight_decay=0.0005)
  # scheduler = LambdaLR(optimizer, lr_lambda=lambda epoch: 1/(epoch+1))
  scheduler = CosineAnnealingLR(optimizer, T_max=20)

  # 记录训练过程中的准确率和损失
  tag_loss = "train_loss_{}".format(scale)
  tag_acc = "train_accuracy_{}".format(scale)

  # 训练循环...
  final_train_loss = 0
  final_train_acc = 0
  best_train_acc = 0.0  # 用于跟踪一个scale也就是一个完整的train的过程中的最佳准确率

  # 验证步骤...
  # 记录验证的次数
  valid_correct = 0
  valid_total = 0
  best_valid_acc = 0.0
  val_loss = "val_loss_{}".format(scale)
  val_acc = "val_accuracy_{}".format(scale)
  acc = 0.0
  loss = 1.0

  for epoch in range(num_epochs):

    # ----------------------------首先是训练过程----------------------------
    train_correct = 0
    train_total = 0
    for batch_idx, (imgs, targets) in enumerate(train_loader):
      imgs, targets = imgs.to(device), targets.to(device)
      outputs = model(imgs)
      loss = criterion(outputs, targets)
      _, predicted = torch.max(outputs, 1)
      train_total += targets.size(0)
      train_correct += (predicted == targets).sum().item()
      optimizer.zero_grad() # W_new = W_old + \gamma \times \deta W_old,这里相当于先要求\gamma 为零矩阵
      loss.backward()   # 使用backward得到了\deta W_old
      optimizer.step()  # 选择合适的\gamma 得到了W_new
      scheduler.step()  # \gamma 事实上是一个依赖于learning_rate的一个矩阵函数,这里更新了learning_rate,而且learning_rate的更新是依赖于epoch的

    acc = train_correct / train_total
    writer.add_scalar(tag_loss, loss.item(), epoch)
    writer.add_scalar(tag_acc, acc, epoch)
    # 更新模型权重并记录到Tensorboard
    for name, param in model.named_parameters():
      writer.add_histogram(name, param.clone().cpu().data.numpy(), epoch)
    final_train_acc = train_correct / train_total
    # 更新最佳准确率,以及对应的loss
    if final_train_acc >= best_train_acc:
      best_train_acc = final_train_acc
      best_train_loss = loss.item()
    final_train_loss = loss.item()
    print("Epoch [{}/{}], Final Train Loss: {:.4f}, Final Train Accuracy: {:.2f}%, Best Train Accuracy: {:.2f}, Loss to best acc:{:.2f}%".format(epoch+1, num_epochs, final_train_loss, final_train_acc * 100, best_train_acc * 100, best_train_loss),"\n")
    # 记录学习率(learning_rate)的更新情况
    writer.add_scalar("learning_rate",optimizer.param_groups[0]['lr'])

    # -------------------------然后进入了验证步骤---------------------------------
    for batch_idx, (imgs, targets) in enumerate(valid_loader):
      imgs, targets = imgs.to(device), targets.to(device)
      outputs = model(imgs)
      loss = criterion(outputs, targets)
      _, predicted = torch.max(outputs, 1)
      valid_total += targets.size(0)
      valid_correct += (predicted == targets).sum().item()
      acc = valid_correct / valid_total

    writer.add_scalar(val_loss, loss.item(), epoch)
    writer.add_scalar(val_acc, acc, epoch)
    # 记录valid中的最终情况
    final_valid_acc = acc
    final_valid_loss = loss
    # 更新最佳准确率,以及对应的loss
    if final_valid_acc >= best_valid_acc:
      best_valid_acc = final_valid_acc
      best_valid_loss = loss.item()
    final_valid_loss = loss.item()
    print("Epoch [{}/{}], Final Valid Loss: {:.4f}, Final Valid Accuracy: {:.2f}%, Best Valid Accuracy: {:.2f}%, Loss to best Valid accuracy:{:.2f}".format(epoch+1, num_epochs, final_valid_loss, final_valid_acc * 100, best_valid_acc * 100, best_valid_loss),"\n")


  # 记录train过程中的最终情况
  writer.add_scalar("final_train_loss", final_train_loss, scale)
  writer.add_scalar("final_train_acc", final_train_acc, scale)
  writer.add_scalar("best_train_acc", best_train_acc, scale)
  writer.add_scalar("best_train_loss", best_train_loss, scale)
  # 记录valid的最终情况
  writer.add_scalar("final_valid_loss", final_valid_loss, scale)
  writer.add_scalar("final_valid_acc", final_valid_acc, scale)
  writer.add_scalar("best_valid_acc", best_valid_acc, scale)
  writer.add_scalar("best_valid_loss", best_valid_loss, scale)

  # 保存模型参数
  filename = "LP-RL-model_scale={}.pth".format(scale)
  torch.save(model.state_dict(), filename)
  print("模型参数已保存为{}".format(filename), '\n')

  # 完成各种工作，记录结果...
  normal_dict = {
      "训练的模型的保留路径": filename,
      "在测试集中的最终损失": final_valid_loss,
      "在测试集中的最终损失":best_valid_loss,
      "在测试集中的最终准确率": final_valid_acc,
      "在测试集中的最佳准确率": best_valid_acc,
      "在训练集中的最终准确率": final_train_acc,
      "在训练集中的最佳准确率": best_train_acc,
      "在训练集中的最终损失": final_train_loss,
      "在训练集中的最佳损失":best_train_loss
  }
  return normal_dict

# %%
def get_rank(scale, writer, device, train_loader):
  get_cifar10_gpu = get_Effective_Ranks(train_dataloader=train_loader)
  rk, Rk = get_cifar10_gpu.train_rk, get_cifar10_gpu.train_Rk
  rk_max_value = max(rk)  # 找到列表中的最大值
  rk_max_index = rk.index(rk_max_value)  # 找到最大值对应的索引
  Rk_value_max_rk_index = Rk[rk_max_index]
  # Rk_max_value = max(Rk)  # 找到列表中的最大值
  # Rk_max_index = Rk.index(Rk_max_value)  # 找到最大值对应的索引
  # print(rk_max_index, rk_max_value, '\n', Rk_max_index, Rk_max_value)

  # 记录的标记
  # 构建动态字符串
  index_rk = "rk_max_index_scale"
  # index_Rk = "Rk_max_index_sacle={}".format(scale)
  value_rk = "rk_max_value_scale"
  value_Rk = "Rk_max_value_sacel"
  value_Rk_index_max_rk = "value_Rk_index_max_rk_sacle" # 这里记录的是rk最大的时候的k对应的Rk的value
  r_0 = "r0_sacle"
  writer.add_scalar(index_rk, rk_max_index, scale)
  # writer.add_scalar(index_Rk, Rk_max_index, scale)
  writer.add_scalar(value_rk, rk_max_value, scale)
  # writer.add_scalar(value_Rk, Rk_max_value, scale)
  writer.add_scalar(r_0, scale)
  writer.add_scalar(value_Rk_index_max_rk, Rk_value_max_rk_index, scale)

  # 建立字典，保存结果
  rank_dict = {index_rk:rk_max_index,
          value_rk:rk_max_value,
          value_Rk:Rk_value_max_rk_index,
          r_0:rk[0]}
  return rank_dict

# %%
# ------------------------------------训练开始前的基本设置---------------------------------------------------
# 设置设备和种子
device_cuda = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# 设置随机种子
seed = 10  # 你可以选择任何整数作为种子值

# 设置PyTorch随机种子
torch.manual_seed(seed)

# 设置CUDA随机种子（如果使用GPU）
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# 设置Numpy随机种子
np.random.seed(seed)

# 设置Python随机种子
random.seed(seed)


# ---------------------------------- 设置结束----------------------------------------------------------------------------------

# 定义初始的scale范围
scale_min = 0.1
scale_max = 0.9
scale_list = [round(x * 0.1, 1) for x in range(int(scale_min * 10), int(scale_max * 10) + 1)]
# print(scale_list)
my_list = []
# 添加tensorboard
writer_new = SummaryWriter("logs-MLP-RL")

for scale in scale_list:
  train_loader, valid_loader, test_loader = get_data_loader(scale, valid_scale=0.1)
  print("--------------------开始scale={}的情况---------------------".format(scale), "\n")
  print("首先得到了有效秩的情况 \n")
  dic = {}
  dic['rank_sacle={}'.format(scale)] = get_rank(scale=scale,device=device_cuda, train_loader=train_loader, writer=writer_new)
  print(dic['rank_sacle={}'.format(scale)])
  dic['sacle={}'.format(scale)] = get_scale(scale=scale, writer=writer_new, train_loader=train_loader, valid_loader=valid_loader)
  print(dic['sacle={}'.format(scale)])
  my_list.append(dic)

writer_new.close()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# --------------------开始scale=0.1的情况---------------------
#
# 首先得到了有效秩的情况
#
# {'rk_max_index_scale': 1585, 'rk_max_value_scale': 3559136.0927861114, 'Rk_max_value_sacel': 958.9959793243203, 'r0_sacle': 2.0244539429268635}
# Epoch [1/100], Final Train Loss: 2.3062, Final Train Accuracy: 10.60%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [1/100], Final Valid Loss: 2.3001, Final Valid Accuracy: 10.60%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [2/100], Final Train Loss: 2.3002, Final Train Accuracy: 9.86%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [2/100], Final Valid Loss: 2.3025, Final Valid Accuracy: 10.35%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [3/100], Final Train Loss: 2.3039, Final Train Accuracy: 9.81%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [3/100], Final Valid Loss: 2.3051, Final Valid Accuracy: 10.27%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [4/100], Final Train Loss: 72.5160, Final Train Accuracy: 9.71%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [4/100], Final Valid Loss: 2.3033, Final Valid Accuracy: 10.10%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [5/100], Final Train Loss: 2.3068, Final Train Accuracy: 9.77%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [5/100], Final Valid Loss: 2.3027, Final Valid Accuracy: 10.10%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [6/100], Final Train Loss: 2.3023, Final Train Accuracy: 9.93%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [6/100], Final Valid Loss: 2.3029, Final Valid Accuracy: 10.18%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [7/100], Final Train Loss: 2.3001, Final Train Accuracy: 9.88%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [7/100], Final Valid Loss: 2.3027, Final Valid Accuracy: 10.17%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [8/100], Final Train Loss: 2.3079, Final Train Accuracy: 10.02%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [8/100], Final Valid Loss: 2.3064, Final Valid Accuracy: 9.95%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [9/100], Final Train Loss: 2.3047, Final Train Accuracy: 10.10%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [9/100], Final Valid Loss: 2.3031, Final Valid Accuracy: 9.96%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [10/100], Final Train Loss: 2.3068, Final Train Accuracy: 9.90%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [10/100], Final Valid Loss: 2.3036, Final Valid Accuracy: 9.80%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [11/100], Final Train Loss: 2.3024, Final Train Accuracy: 9.98%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [11/100], Final Valid Loss: 2.3034, Final Valid Accuracy: 9.77%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [12/100], Final Train Loss: 2.3038, Final Train Accuracy: 9.79%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [12/100], Final Valid Loss: 2.3024, Final Valid Accuracy: 9.84%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [13/100], Final Train Loss: 2.3258, Final Train Accuracy: 10.01%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [13/100], Final Valid Loss: 2.3174, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [14/100], Final Train Loss: 2.3004, Final Train Accuracy: 9.95%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [14/100], Final Valid Loss: 2.3031, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [15/100], Final Train Loss: 2.3025, Final Train Accuracy: 9.80%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [15/100], Final Valid Loss: 2.3024, Final Valid Accuracy: 9.96%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [16/100], Final Train Loss: 2.3108, Final Train Accuracy: 10.05%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [16/100], Final Valid Loss: 2.3018, Final Valid Accuracy: 9.96%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [17/100], Final Train Loss: 2.3045, Final Train Accuracy: 9.98%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [17/100], Final Valid Loss: 2.3105, Final Valid Accuracy: 9.97%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [18/100], Final Train Loss: 2.3432, Final Train Accuracy: 10.00%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [18/100], Final Valid Loss: 979.5681, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [19/100], Final Train Loss: 2.3065, Final Train Accuracy: 9.95%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [19/100], Final Valid Loss: 2.3028, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [20/100], Final Train Loss: 2.3072, Final Train Accuracy: 9.93%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [20/100], Final Valid Loss: 2.3090, Final Valid Accuracy: 9.96%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [21/100], Final Train Loss: 2.3020, Final Train Accuracy: 9.94%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [21/100], Final Valid Loss: 2.3059, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [22/100], Final Train Loss: 2.3044, Final Train Accuracy: 9.82%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [22/100], Final Valid Loss: 2.3009, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [23/100], Final Train Loss: 2.3078, Final Train Accuracy: 10.05%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [23/100], Final Valid Loss: 2.3065, Final Valid Accuracy: 9.87%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [24/100], Final Train Loss: 2.3033, Final Train Accuracy: 9.93%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [24/100], Final Valid Loss: 2.3019, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [25/100], Final Train Loss: 2.3429, Final Train Accuracy: 9.78%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [25/100], Final Valid Loss: 2.3228, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [26/100], Final Train Loss: 2.3034, Final Train Accuracy: 9.85%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [26/100], Final Valid Loss: 2.3031, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [27/100], Final Train Loss: 2.2987, Final Train Accuracy: 9.91%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [27/100], Final Valid Loss: 2.3043, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [28/100], Final Train Loss: 2.3101, Final Train Accuracy: 10.15%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [28/100], Final Valid Loss: 2.3082, Final Valid Accuracy: 9.94%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [29/100], Final Train Loss: 2.3042, Final Train Accuracy: 10.08%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [29/100], Final Valid Loss: 2.3110, Final Valid Accuracy: 9.94%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [30/100], Final Train Loss: 2.3119, Final Train Accuracy: 9.94%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [30/100], Final Valid Loss: 2.3063, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [31/100], Final Train Loss: 2.3009, Final Train Accuracy: 10.16%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [31/100], Final Valid Loss: 2.3059, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [32/100], Final Train Loss: 2.3417, Final Train Accuracy: 9.88%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [32/100], Final Valid Loss: 2.3212, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [33/100], Final Train Loss: 2.3054, Final Train Accuracy: 10.13%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [33/100], Final Valid Loss: 2.3059, Final Valid Accuracy: 9.85%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [34/100], Final Train Loss: 2.3229, Final Train Accuracy: 10.03%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [34/100], Final Valid Loss: 2.3166, Final Valid Accuracy: 9.86%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [35/100], Final Train Loss: 2.3223, Final Train Accuracy: 10.05%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [35/100], Final Valid Loss: 2.3135, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [36/100], Final Train Loss: 2.3723, Final Train Accuracy: 9.88%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [36/100], Final Valid Loss: 2.3470, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [37/100], Final Train Loss: 2.3035, Final Train Accuracy: 9.95%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [37/100], Final Valid Loss: 2.3100, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [38/100], Final Train Loss: 2.3113, Final Train Accuracy: 9.78%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [38/100], Final Valid Loss: 2.3023, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [39/100], Final Train Loss: 2.3161, Final Train Accuracy: 9.79%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [39/100], Final Valid Loss: 2.3142, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [40/100], Final Train Loss: 2.3021, Final Train Accuracy: 9.96%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [40/100], Final Valid Loss: 2.3041, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [41/100], Final Train Loss: 2.3058, Final Train Accuracy: 9.73%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [41/100], Final Valid Loss: 2.3062, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [42/100], Final Train Loss: 2.3057, Final Train Accuracy: 9.82%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [42/100], Final Valid Loss: 2.3029, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [43/100], Final Train Loss: 2.3133, Final Train Accuracy: 9.91%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [43/100], Final Valid Loss: 2.3047, Final Valid Accuracy: 9.95%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [44/100], Final Train Loss: 2.3055, Final Train Accuracy: 9.99%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [44/100], Final Valid Loss: 2.3018, Final Valid Accuracy: 9.95%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [45/100], Final Train Loss: 2.3042, Final Train Accuracy: 10.15%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [45/100], Final Valid Loss: 2.3062, Final Valid Accuracy: 9.95%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [46/100], Final Train Loss: 2.3041, Final Train Accuracy: 9.78%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [46/100], Final Valid Loss: 2.3018, Final Valid Accuracy: 9.95%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [47/100], Final Train Loss: 2.3050, Final Train Accuracy: 9.91%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [47/100], Final Valid Loss: 2.3065, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [48/100], Final Train Loss: 2.2977, Final Train Accuracy: 9.82%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [48/100], Final Valid Loss: 2.3033, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [49/100], Final Train Loss: 2.2926, Final Train Accuracy: 10.02%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [49/100], Final Valid Loss: 2.3130, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [50/100], Final Train Loss: 2.3046, Final Train Accuracy: 9.90%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [50/100], Final Valid Loss: 2.3037, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [51/100], Final Train Loss: 2.3082, Final Train Accuracy: 9.88%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [51/100], Final Valid Loss: 2.3040, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [52/100], Final Train Loss: 2.3039, Final Train Accuracy: 9.95%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [52/100], Final Valid Loss: 2.3038, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [53/100], Final Train Loss: 2.3034, Final Train Accuracy: 10.13%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [53/100], Final Valid Loss: 2.3032, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [54/100], Final Train Loss: 2.3107, Final Train Accuracy: 9.90%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [54/100], Final Valid Loss: 2.3157, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [55/100], Final Train Loss: 2.3031, Final Train Accuracy: 9.95%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [55/100], Final Valid Loss: 2.3020, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [56/100], Final Train Loss: 2.3004, Final Train Accuracy: 9.85%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [56/100], Final Valid Loss: 2.3165, Final Valid Accuracy: 9.86%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [57/100], Final Train Loss: 2.3003, Final Train Accuracy: 9.97%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [57/100], Final Valid Loss: 2.3048, Final Valid Accuracy: 9.83%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [58/100], Final Train Loss: 2.3031, Final Train Accuracy: 9.88%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [58/100], Final Valid Loss: 2.3074, Final Valid Accuracy: 9.83%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [59/100], Final Train Loss: 2.3049, Final Train Accuracy: 9.97%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [59/100], Final Valid Loss: 2.3139, Final Valid Accuracy: 9.83%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [60/100], Final Train Loss: 2.3088, Final Train Accuracy: 9.82%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [60/100], Final Valid Loss: 2.3030, Final Valid Accuracy: 9.84%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [61/100], Final Train Loss: 2.2970, Final Train Accuracy: 9.98%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [61/100], Final Valid Loss: 2.3055, Final Valid Accuracy: 9.82%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [62/100], Final Train Loss: 2.3011, Final Train Accuracy: 10.21%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [62/100], Final Valid Loss: 2.3014, Final Valid Accuracy: 9.82%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [63/100], Final Train Loss: 2.3058, Final Train Accuracy: 9.73%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [63/100], Final Valid Loss: 2.3075, Final Valid Accuracy: 9.80%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [64/100], Final Train Loss: 2.3041, Final Train Accuracy: 9.91%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [64/100], Final Valid Loss: 2.3062, Final Valid Accuracy: 9.78%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [65/100], Final Train Loss: 2.3119, Final Train Accuracy: 10.20%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [65/100], Final Valid Loss: 2.3072, Final Valid Accuracy: 9.78%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [66/100], Final Train Loss: 2.3328, Final Train Accuracy: 10.03%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [66/100], Final Valid Loss: 2.3152, Final Valid Accuracy: 9.78%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [67/100], Final Train Loss: 1816.6122, Final Train Accuracy: 9.98%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [67/100], Final Valid Loss: 2.3698, Final Valid Accuracy: 9.79%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [68/100], Final Train Loss: 2.3079, Final Train Accuracy: 9.96%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [68/100], Final Valid Loss: 2.3126, Final Valid Accuracy: 9.80%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [69/100], Final Train Loss: 2.2974, Final Train Accuracy: 9.95%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [69/100], Final Valid Loss: 2.3070, Final Valid Accuracy: 9.81%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [70/100], Final Train Loss: 2.3058, Final Train Accuracy: 9.86%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [70/100], Final Valid Loss: 2.3045, Final Valid Accuracy: 9.82%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [71/100], Final Train Loss: 2.3030, Final Train Accuracy: 9.93%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [71/100], Final Valid Loss: 2.3022, Final Valid Accuracy: 9.83%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [72/100], Final Train Loss: 2.3018, Final Train Accuracy: 9.95%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [72/100], Final Valid Loss: 2.3064, Final Valid Accuracy: 9.81%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [73/100], Final Train Loss: 2.3043, Final Train Accuracy: 9.92%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [73/100], Final Valid Loss: 2.3033, Final Valid Accuracy: 9.81%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [74/100], Final Train Loss: 2.3056, Final Train Accuracy: 9.96%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [74/100], Final Valid Loss: 2.3093, Final Valid Accuracy: 9.82%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [75/100], Final Train Loss: 2.3167, Final Train Accuracy: 9.93%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [75/100], Final Valid Loss: 2.3157, Final Valid Accuracy: 9.82%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [76/100], Final Train Loss: 2.3133, Final Train Accuracy: 9.84%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [76/100], Final Valid Loss: 2.3074, Final Valid Accuracy: 9.83%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [77/100], Final Train Loss: 2.3041, Final Train Accuracy: 10.01%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [77/100], Final Valid Loss: 2.3021, Final Valid Accuracy: 9.84%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [78/100], Final Train Loss: 2.3217, Final Train Accuracy: 9.96%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [78/100], Final Valid Loss: 2.3166, Final Valid Accuracy: 9.85%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [79/100], Final Train Loss: 2.3068, Final Train Accuracy: 9.77%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [79/100], Final Valid Loss: 2.3037, Final Valid Accuracy: 9.86%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [80/100], Final Train Loss: 2.3057, Final Train Accuracy: 9.75%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [80/100], Final Valid Loss: 2.3012, Final Valid Accuracy: 9.86%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [81/100], Final Train Loss: 8.7430, Final Train Accuracy: 9.85%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [81/100], Final Valid Loss: 2.3318, Final Valid Accuracy: 9.86%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [82/100], Final Train Loss: 2.3026, Final Train Accuracy: 9.92%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [82/100], Final Valid Loss: 2.3027, Final Valid Accuracy: 9.86%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [83/100], Final Train Loss: 2.3106, Final Train Accuracy: 9.91%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [83/100], Final Valid Loss: 2.3173, Final Valid Accuracy: 9.87%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [84/100], Final Train Loss: 2.3046, Final Train Accuracy: 10.06%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [84/100], Final Valid Loss: 2.3018, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [85/100], Final Train Loss: 2.3032, Final Train Accuracy: 10.00%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [85/100], Final Valid Loss: 2.3037, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [86/100], Final Train Loss: 2.3018, Final Train Accuracy: 9.90%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [86/100], Final Valid Loss: 2.3031, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [87/100], Final Train Loss: 2.3078, Final Train Accuracy: 9.94%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [87/100], Final Valid Loss: 2.3022, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [88/100], Final Train Loss: 2.3101, Final Train Accuracy: 9.90%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [88/100], Final Valid Loss: 2.3026, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [89/100], Final Train Loss: 2.3403, Final Train Accuracy: 9.79%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [89/100], Final Valid Loss: 2.3424, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [90/100], Final Train Loss: 2.3024, Final Train Accuracy: 9.91%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [90/100], Final Valid Loss: 2.3047, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [91/100], Final Train Loss: 2.3036, Final Train Accuracy: 9.85%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [91/100], Final Valid Loss: 2.3018, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [92/100], Final Train Loss: 2.3020, Final Train Accuracy: 10.16%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [92/100], Final Valid Loss: 2.3045, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [93/100], Final Train Loss: 2.3005, Final Train Accuracy: 9.90%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [93/100], Final Valid Loss: 2.3045, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [94/100], Final Train Loss: 2.3028, Final Train Accuracy: 10.10%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [94/100], Final Valid Loss: 2.3045, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [95/100], Final Train Loss: 2.3012, Final Train Accuracy: 10.06%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [95/100], Final Valid Loss: 2.3038, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [96/100], Final Train Loss: 2.3194, Final Train Accuracy: 10.00%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [96/100], Final Valid Loss: 2.3101, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [97/100], Final Train Loss: 2.2992, Final Train Accuracy: 9.73%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [97/100], Final Valid Loss: 2.3020, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [98/100], Final Train Loss: 2.3029, Final Train Accuracy: 9.79%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [98/100], Final Valid Loss: 2.3050, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [99/100], Final Train Loss: 2.3032, Final Train Accuracy: 10.12%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [99/100], Final Valid Loss: 2.3039, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# Epoch [100/100], Final Train Loss: 2.3044, Final Train Accuracy: 10.02%, Best Train Accuracy: 10.60, Loss to best acc:2.31%
#
# Epoch [100/100], Final Valid Loss: 2.3218, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.60%, Loss to best Valid accuracy:2.30
#
# 模型参数已保存为LP-RL-model_scale=0.1.pth
#
# {'训练的模型的保留路径': 'LP-RL-model_scale=0.1.pth', '在测试集中的最终损失': 2.300081491470337, '在测试集中的最终准确率': 0.09913, '在测试集中的最佳准确率': 0.106, '在训练集中的最终准确率': 0.10016, '在训练集中的最佳准确率': 0.10596, '在训练集中的最终损失': 2.3044300079345703, '在训练集中的最佳损失': 2.3062007427215576}
# Files already downloaded and verified
# Files already downloaded and verified
# --------------------开始scale=0.2的情况---------------------
#
# 首先得到了有效秩的情况
#
# {'rk_max_index_scale': 1585, 'rk_max_value_scale': 960029.7457623144, 'Rk_max_value_sacel': 552.8914427345629, 'r0_sacle': 2.66570637588447}
# Epoch [1/100], Final Train Loss: 2.3013, Final Train Accuracy: 11.27%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [1/100], Final Valid Loss: 2.3024, Final Valid Accuracy: 8.80%, Best Valid Accuracy: 8.80%, Loss to best Valid accuracy:2.30
#
# Epoch [2/100], Final Train Loss: 2.3058, Final Train Accuracy: 9.89%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [2/100], Final Valid Loss: 2.3012, Final Valid Accuracy: 9.70%, Best Valid Accuracy: 9.70%, Loss to best Valid accuracy:2.30
#
# Epoch [3/100], Final Train Loss: 2.3143, Final Train Accuracy: 9.90%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [3/100], Final Valid Loss: 2.3076, Final Valid Accuracy: 10.30%, Best Valid Accuracy: 10.30%, Loss to best Valid accuracy:2.31
#
# Epoch [4/100], Final Train Loss: 2.3039, Final Train Accuracy: 10.02%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [4/100], Final Valid Loss: 2.3033, Final Valid Accuracy: 10.32%, Best Valid Accuracy: 10.32%, Loss to best Valid accuracy:2.30
#
# Epoch [5/100], Final Train Loss: 2.3030, Final Train Accuracy: 9.85%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [5/100], Final Valid Loss: 2.3032, Final Valid Accuracy: 10.40%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [6/100], Final Train Loss: 2.3043, Final Train Accuracy: 9.85%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [6/100], Final Valid Loss: 2.3023, Final Valid Accuracy: 10.13%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [7/100], Final Train Loss: 2.3097, Final Train Accuracy: 9.92%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [7/100], Final Valid Loss: 2.3058, Final Valid Accuracy: 9.94%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [8/100], Final Train Loss: 2.3017, Final Train Accuracy: 10.10%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [8/100], Final Valid Loss: 2.3025, Final Valid Accuracy: 9.94%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [9/100], Final Train Loss: 2.2980, Final Train Accuracy: 10.08%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [9/100], Final Valid Loss: 2.3031, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [10/100], Final Train Loss: 2.3059, Final Train Accuracy: 9.76%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [10/100], Final Valid Loss: 2.3061, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [11/100], Final Train Loss: 2.3033, Final Train Accuracy: 9.85%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [11/100], Final Valid Loss: 2.3021, Final Valid Accuracy: 9.95%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [12/100], Final Train Loss: 2.3045, Final Train Accuracy: 9.81%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [12/100], Final Valid Loss: 2.3049, Final Valid Accuracy: 9.85%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [13/100], Final Train Loss: 2.3044, Final Train Accuracy: 9.99%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [13/100], Final Valid Loss: 2.3029, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [14/100], Final Train Loss: 2.3058, Final Train Accuracy: 9.74%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [14/100], Final Valid Loss: 2.3063, Final Valid Accuracy: 9.84%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [15/100], Final Train Loss: 2.3036, Final Train Accuracy: 9.93%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [15/100], Final Valid Loss: 2.3022, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [16/100], Final Train Loss: 2.3059, Final Train Accuracy: 10.16%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [16/100], Final Valid Loss: 78.9810, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [17/100], Final Train Loss: 2.3112, Final Train Accuracy: 9.93%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [17/100], Final Valid Loss: 2.3132, Final Valid Accuracy: 9.82%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [18/100], Final Train Loss: 2.3099, Final Train Accuracy: 9.94%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [18/100], Final Valid Loss: 2.3134, Final Valid Accuracy: 9.82%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [19/100], Final Train Loss: 2.2988, Final Train Accuracy: 9.94%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [19/100], Final Valid Loss: 2.3024, Final Valid Accuracy: 9.76%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [20/100], Final Train Loss: 2.3032, Final Train Accuracy: 9.73%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [20/100], Final Valid Loss: 2.3043, Final Valid Accuracy: 9.81%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [21/100], Final Train Loss: 2.3024, Final Train Accuracy: 9.74%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [21/100], Final Valid Loss: 2.3103, Final Valid Accuracy: 9.79%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [22/100], Final Train Loss: 2.3033, Final Train Accuracy: 9.99%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [22/100], Final Valid Loss: 2.3034, Final Valid Accuracy: 9.80%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [23/100], Final Train Loss: 2.3112, Final Train Accuracy: 10.08%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [23/100], Final Valid Loss: 2.3209, Final Valid Accuracy: 9.80%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [24/100], Final Train Loss: 2.2987, Final Train Accuracy: 10.05%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [24/100], Final Valid Loss: 2.3015, Final Valid Accuracy: 9.83%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [25/100], Final Train Loss: 2.3138, Final Train Accuracy: 10.02%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [25/100], Final Valid Loss: 2.3069, Final Valid Accuracy: 9.83%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [26/100], Final Train Loss: 2.3002, Final Train Accuracy: 10.00%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [26/100], Final Valid Loss: 2.3025, Final Valid Accuracy: 9.83%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [27/100], Final Train Loss: 2.3049, Final Train Accuracy: 9.91%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [27/100], Final Valid Loss: 2.3024, Final Valid Accuracy: 9.86%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [28/100], Final Train Loss: 2.3482, Final Train Accuracy: 9.85%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [28/100], Final Valid Loss: 2.3308, Final Valid Accuracy: 9.86%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [29/100], Final Train Loss: 2.3055, Final Train Accuracy: 9.97%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [29/100], Final Valid Loss: 2.3059, Final Valid Accuracy: 9.87%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [30/100], Final Train Loss: 2.3066, Final Train Accuracy: 9.83%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [30/100], Final Valid Loss: 2.3056, Final Valid Accuracy: 9.85%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [31/100], Final Train Loss: 2.3050, Final Train Accuracy: 10.23%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [31/100], Final Valid Loss: 2.3058, Final Valid Accuracy: 9.82%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [32/100], Final Train Loss: 2.2997, Final Train Accuracy: 10.06%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [32/100], Final Valid Loss: 2.3029, Final Valid Accuracy: 9.81%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [33/100], Final Train Loss: 2.3025, Final Train Accuracy: 9.75%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [33/100], Final Valid Loss: 2.3033, Final Valid Accuracy: 9.81%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [34/100], Final Train Loss: 2.3041, Final Train Accuracy: 9.99%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [34/100], Final Valid Loss: 2.3064, Final Valid Accuracy: 9.83%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [35/100], Final Train Loss: 2.3031, Final Train Accuracy: 9.90%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [35/100], Final Valid Loss: 2.3053, Final Valid Accuracy: 9.81%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [36/100], Final Train Loss: 2.3264, Final Train Accuracy: 9.97%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [36/100], Final Valid Loss: 2.3173, Final Valid Accuracy: 9.81%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [37/100], Final Train Loss: 2.3133, Final Train Accuracy: 9.90%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [37/100], Final Valid Loss: 2.3305, Final Valid Accuracy: 9.83%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [38/100], Final Train Loss: 2.3020, Final Train Accuracy: 9.96%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [38/100], Final Valid Loss: 2.3033, Final Valid Accuracy: 9.83%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [39/100], Final Train Loss: 2.3021, Final Train Accuracy: 10.07%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [39/100], Final Valid Loss: 2.3048, Final Valid Accuracy: 9.82%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [40/100], Final Train Loss: 2.3124, Final Train Accuracy: 9.91%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [40/100], Final Valid Loss: 2.3076, Final Valid Accuracy: 9.82%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [41/100], Final Train Loss: 2.3002, Final Train Accuracy: 10.10%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [41/100], Final Valid Loss: 2.3033, Final Valid Accuracy: 9.82%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [42/100], Final Train Loss: 2.3019, Final Train Accuracy: 10.19%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [42/100], Final Valid Loss: 2.3006, Final Valid Accuracy: 9.84%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [43/100], Final Train Loss: 2.3038, Final Train Accuracy: 9.88%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [43/100], Final Valid Loss: 2.3040, Final Valid Accuracy: 9.82%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [44/100], Final Train Loss: 2.3042, Final Train Accuracy: 9.99%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [44/100], Final Valid Loss: 2.3026, Final Valid Accuracy: 9.84%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [45/100], Final Train Loss: 2.3068, Final Train Accuracy: 9.86%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [45/100], Final Valid Loss: 2.3030, Final Valid Accuracy: 9.84%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [46/100], Final Train Loss: 2.3118, Final Train Accuracy: 10.35%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [46/100], Final Valid Loss: 2.3013, Final Valid Accuracy: 9.87%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [47/100], Final Train Loss: 2.3079, Final Train Accuracy: 9.95%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [47/100], Final Valid Loss: 2.4242, Final Valid Accuracy: 9.87%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [48/100], Final Train Loss: 2.3059, Final Train Accuracy: 9.90%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [48/100], Final Valid Loss: 2.3035, Final Valid Accuracy: 9.85%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [49/100], Final Train Loss: 2.3182, Final Train Accuracy: 9.89%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [49/100], Final Valid Loss: 2.3097, Final Valid Accuracy: 9.85%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [50/100], Final Train Loss: 2.3025, Final Train Accuracy: 9.88%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [50/100], Final Valid Loss: 2.3060, Final Valid Accuracy: 9.86%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [51/100], Final Train Loss: 2.3008, Final Train Accuracy: 9.76%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [51/100], Final Valid Loss: 2.3010, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [52/100], Final Train Loss: 2.3036, Final Train Accuracy: 9.91%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [52/100], Final Valid Loss: 2.3017, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [53/100], Final Train Loss: 2.3020, Final Train Accuracy: 9.80%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [53/100], Final Valid Loss: 2.3024, Final Valid Accuracy: 9.87%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [54/100], Final Train Loss: 2.3034, Final Train Accuracy: 10.05%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [54/100], Final Valid Loss: 2.3061, Final Valid Accuracy: 9.87%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [55/100], Final Train Loss: 2.3037, Final Train Accuracy: 10.04%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [55/100], Final Valid Loss: 2.3014, Final Valid Accuracy: 9.87%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [56/100], Final Train Loss: 2.2993, Final Train Accuracy: 9.82%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [56/100], Final Valid Loss: 2.3063, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [57/100], Final Train Loss: 2.3134, Final Train Accuracy: 9.92%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [57/100], Final Valid Loss: 2.3117, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [58/100], Final Train Loss: 2.3132, Final Train Accuracy: 9.77%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [58/100], Final Valid Loss: 2.3059, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [59/100], Final Train Loss: 2.3096, Final Train Accuracy: 10.15%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [59/100], Final Valid Loss: 2.3007, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [60/100], Final Train Loss: 2.3129, Final Train Accuracy: 10.01%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [60/100], Final Valid Loss: 2.3082, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [61/100], Final Train Loss: 2.3022, Final Train Accuracy: 10.03%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [61/100], Final Valid Loss: 2.3106, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [62/100], Final Train Loss: 2.3063, Final Train Accuracy: 9.99%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [62/100], Final Valid Loss: 2.3024, Final Valid Accuracy: 9.86%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [63/100], Final Train Loss: 2.3037, Final Train Accuracy: 9.64%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [63/100], Final Valid Loss: 2.3029, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [64/100], Final Train Loss: 2.3181, Final Train Accuracy: 9.62%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [64/100], Final Valid Loss: 2.3062, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [65/100], Final Train Loss: 2.2999, Final Train Accuracy: 9.97%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [65/100], Final Valid Loss: 2.3033, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [66/100], Final Train Loss: 2.3194, Final Train Accuracy: 10.00%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [66/100], Final Valid Loss: 2.3085, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [67/100], Final Train Loss: 2.3080, Final Train Accuracy: 9.92%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [67/100], Final Valid Loss: 2.3031, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [68/100], Final Train Loss: 2.3091, Final Train Accuracy: 9.81%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [68/100], Final Valid Loss: 2.3030, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [69/100], Final Train Loss: 2.3075, Final Train Accuracy: 10.08%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [69/100], Final Valid Loss: 23.2365, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [70/100], Final Train Loss: 2.3082, Final Train Accuracy: 10.04%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [70/100], Final Valid Loss: 2.3060, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [71/100], Final Train Loss: 2.4496, Final Train Accuracy: 9.97%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [71/100], Final Valid Loss: 2.3083, Final Valid Accuracy: 9.95%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [72/100], Final Train Loss: 2.3022, Final Train Accuracy: 9.88%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [72/100], Final Valid Loss: 2.3011, Final Valid Accuracy: 9.96%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [73/100], Final Train Loss: 2.3013, Final Train Accuracy: 9.76%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [73/100], Final Valid Loss: 2.3016, Final Valid Accuracy: 9.94%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [74/100], Final Train Loss: 2.2995, Final Train Accuracy: 9.81%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [74/100], Final Valid Loss: 2.3029, Final Valid Accuracy: 9.96%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [75/100], Final Train Loss: 2.3501, Final Train Accuracy: 9.90%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [75/100], Final Valid Loss: 2.3101, Final Valid Accuracy: 9.96%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [76/100], Final Train Loss: 2.3154, Final Train Accuracy: 9.93%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [76/100], Final Valid Loss: 2.3076, Final Valid Accuracy: 9.96%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [77/100], Final Train Loss: 2.3204, Final Train Accuracy: 9.86%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [77/100], Final Valid Loss: 2.3043, Final Valid Accuracy: 9.96%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [78/100], Final Train Loss: 2.3042, Final Train Accuracy: 10.11%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [78/100], Final Valid Loss: 2.3057, Final Valid Accuracy: 9.94%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [79/100], Final Train Loss: 2.3010, Final Train Accuracy: 9.99%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [79/100], Final Valid Loss: 2.3113, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [80/100], Final Train Loss: 2.5969, Final Train Accuracy: 9.99%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [80/100], Final Valid Loss: 2.3118, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [81/100], Final Train Loss: 2.3064, Final Train Accuracy: 9.80%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# Epoch [81/100], Final Valid Loss: 2.3128, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.40%, Loss to best Valid accuracy:2.30
#
# Epoch [82/100], Final Train Loss: 2.3056, Final Train Accuracy: 10.03%, Best Train Accuracy: 11.27, Loss to best acc:2.30%
#
# ...
#
# Epoch [40/100], Final Valid Loss: 2.3053, Final Valid Accuracy: 9.72%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [41/100], Final Train Loss: 2.3048, Final Train Accuracy: 9.77%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [41/100], Final Valid Loss: 2.3044, Final Valid Accuracy: 9.71%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [42/100], Final Train Loss: 2.3031, Final Train Accuracy: 9.85%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [42/100], Final Valid Loss: 2.3010, Final Valid Accuracy: 9.72%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [43/100], Final Train Loss: 2.4598, Final Train Accuracy: 9.92%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [43/100], Final Valid Loss: 2.3151, Final Valid Accuracy: 9.71%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [44/100], Final Train Loss: 2.3039, Final Train Accuracy: 9.93%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [44/100], Final Valid Loss: 2.3036, Final Valid Accuracy: 9.73%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [45/100], Final Train Loss: 2.2999, Final Train Accuracy: 10.10%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [45/100], Final Valid Loss: 2.3111, Final Valid Accuracy: 9.74%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [46/100], Final Train Loss: 2.3008, Final Train Accuracy: 9.92%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [46/100], Final Valid Loss: 2.3012, Final Valid Accuracy: 9.76%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [47/100], Final Train Loss: 2.3062, Final Train Accuracy: 9.91%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [47/100], Final Valid Loss: 2.3029, Final Valid Accuracy: 9.80%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [48/100], Final Train Loss: 2.3067, Final Train Accuracy: 9.89%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [48/100], Final Valid Loss: 2.3028, Final Valid Accuracy: 9.80%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [49/100], Final Train Loss: 2.3071, Final Train Accuracy: 9.67%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [49/100], Final Valid Loss: 2.3055, Final Valid Accuracy: 9.79%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [50/100], Final Train Loss: 2.4197, Final Train Accuracy: 10.30%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [50/100], Final Valid Loss: 2.4555, Final Valid Accuracy: 9.80%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [51/100], Final Train Loss: 2.3043, Final Train Accuracy: 9.87%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [51/100], Final Valid Loss: 2.2995, Final Valid Accuracy: 9.81%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [52/100], Final Train Loss: 2.3036, Final Train Accuracy: 9.97%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [52/100], Final Valid Loss: 2.3013, Final Valid Accuracy: 9.83%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [53/100], Final Train Loss: 2.3029, Final Train Accuracy: 9.79%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [53/100], Final Valid Loss: 2.3035, Final Valid Accuracy: 9.84%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [54/100], Final Train Loss: 2.3033, Final Train Accuracy: 9.91%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [54/100], Final Valid Loss: 2.3076, Final Valid Accuracy: 9.86%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [55/100], Final Train Loss: 2.3021, Final Train Accuracy: 9.86%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [55/100], Final Valid Loss: 2.3075, Final Valid Accuracy: 9.87%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [56/100], Final Train Loss: 2.2992, Final Train Accuracy: 10.08%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [56/100], Final Valid Loss: 2.3022, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [57/100], Final Train Loss: 2.3039, Final Train Accuracy: 9.96%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [57/100], Final Valid Loss: 2.3048, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [58/100], Final Train Loss: 2.3036, Final Train Accuracy: 9.93%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [58/100], Final Valid Loss: 2.3051, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [59/100], Final Train Loss: 2.3064, Final Train Accuracy: 9.91%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [59/100], Final Valid Loss: 2.3022, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [60/100], Final Train Loss: 2.3058, Final Train Accuracy: 9.86%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [60/100], Final Valid Loss: 2.2994, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [61/100], Final Train Loss: 2.3028, Final Train Accuracy: 10.06%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [61/100], Final Valid Loss: 2.3028, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [62/100], Final Train Loss: 2.3007, Final Train Accuracy: 10.02%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [62/100], Final Valid Loss: 2.3052, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [63/100], Final Train Loss: 2.3005, Final Train Accuracy: 9.78%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [63/100], Final Valid Loss: 2.3031, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [64/100], Final Train Loss: 2.3041, Final Train Accuracy: 9.98%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [64/100], Final Valid Loss: 2.3048, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [65/100], Final Train Loss: 2.3016, Final Train Accuracy: 10.19%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [65/100], Final Valid Loss: 2.3080, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [66/100], Final Train Loss: 2.3020, Final Train Accuracy: 10.25%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [66/100], Final Valid Loss: 2.3049, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [67/100], Final Train Loss: 2.3116, Final Train Accuracy: 9.92%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [67/100], Final Valid Loss: 87.3636, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [68/100], Final Train Loss: 2.3030, Final Train Accuracy: 9.99%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [68/100], Final Valid Loss: 2.3019, Final Valid Accuracy: 9.95%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [69/100], Final Train Loss: 2.3022, Final Train Accuracy: 10.16%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [69/100], Final Valid Loss: 2.3156, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [70/100], Final Train Loss: 2.3277, Final Train Accuracy: 9.84%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [70/100], Final Valid Loss: 2.3277, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [71/100], Final Train Loss: 2.3031, Final Train Accuracy: 9.82%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [71/100], Final Valid Loss: 2.3034, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [72/100], Final Train Loss: 2.2994, Final Train Accuracy: 9.92%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [72/100], Final Valid Loss: 2.3037, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [73/100], Final Train Loss: 2.3048, Final Train Accuracy: 10.03%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [73/100], Final Valid Loss: 2.3034, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [74/100], Final Train Loss: 2.3046, Final Train Accuracy: 10.10%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [74/100], Final Valid Loss: 2.3045, Final Valid Accuracy: 9.88%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [75/100], Final Train Loss: 2.3004, Final Train Accuracy: 10.16%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [75/100], Final Valid Loss: 2.3044, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [76/100], Final Train Loss: 2.3021, Final Train Accuracy: 10.02%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [76/100], Final Valid Loss: 2.3036, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [77/100], Final Train Loss: 2.3007, Final Train Accuracy: 9.93%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [77/100], Final Valid Loss: 2.3033, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [78/100], Final Train Loss: 2.3047, Final Train Accuracy: 9.73%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [78/100], Final Valid Loss: 2.3046, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [79/100], Final Train Loss: 2.3253, Final Train Accuracy: 9.94%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [79/100], Final Valid Loss: 2.3074, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [80/100], Final Train Loss: 2.3015, Final Train Accuracy: 10.03%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [80/100], Final Valid Loss: 2.3015, Final Valid Accuracy: 9.89%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [81/100], Final Train Loss: 2.3014, Final Train Accuracy: 10.04%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [81/100], Final Valid Loss: 2.3076, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [82/100], Final Train Loss: 2.3110, Final Train Accuracy: 9.90%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [82/100], Final Valid Loss: 2.3071, Final Valid Accuracy: 9.90%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [83/100], Final Train Loss: 2.3034, Final Train Accuracy: 10.12%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [83/100], Final Valid Loss: 2.3038, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [84/100], Final Train Loss: 2.3047, Final Train Accuracy: 9.85%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [84/100], Final Valid Loss: 2.3038, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [85/100], Final Train Loss: 2.3194, Final Train Accuracy: 9.85%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [85/100], Final Valid Loss: 2.3066, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [86/100], Final Train Loss: 2.3075, Final Train Accuracy: 10.06%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [86/100], Final Valid Loss: 2.3021, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [87/100], Final Train Loss: 2.3016, Final Train Accuracy: 9.93%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [87/100], Final Valid Loss: 2.3049, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [88/100], Final Train Loss: 2.2998, Final Train Accuracy: 9.80%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [88/100], Final Valid Loss: 2.3041, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [89/100], Final Train Loss: 2.3008, Final Train Accuracy: 9.64%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [89/100], Final Valid Loss: 2.2990, Final Valid Accuracy: 9.93%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [90/100], Final Train Loss: 2.3028, Final Train Accuracy: 10.10%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [90/100], Final Valid Loss: 2.3038, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [91/100], Final Train Loss: 2.3043, Final Train Accuracy: 9.70%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [91/100], Final Valid Loss: 2.3066, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [92/100], Final Train Loss: 2.3059, Final Train Accuracy: 9.84%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [92/100], Final Valid Loss: 2.3002, Final Valid Accuracy: 9.91%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [93/100], Final Train Loss: 2.3032, Final Train Accuracy: 9.83%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [93/100], Final Valid Loss: 2.3020, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [94/100], Final Train Loss: 2.3022, Final Train Accuracy: 9.87%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [94/100], Final Valid Loss: 2.3016, Final Valid Accuracy: 9.92%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [95/100], Final Train Loss: 2.3030, Final Train Accuracy: 10.02%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [95/100], Final Valid Loss: 2.3040, Final Valid Accuracy: 9.94%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [96/100], Final Train Loss: 2.3060, Final Train Accuracy: 10.05%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [96/100], Final Valid Loss: 2.3003, Final Valid Accuracy: 9.94%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [97/100], Final Train Loss: 2.3029, Final Train Accuracy: 9.92%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [97/100], Final Valid Loss: 2.3033, Final Valid Accuracy: 9.96%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [98/100], Final Train Loss: 2.2992, Final Train Accuracy: 10.04%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [98/100], Final Valid Loss: 2.3024, Final Valid Accuracy: 9.97%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [99/100], Final Train Loss: 2.3029, Final Train Accuracy: 9.91%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [99/100], Final Valid Loss: 2.3052, Final Valid Accuracy: 9.98%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# Epoch [100/100], Final Train Loss: 2.3029, Final Train Accuracy: 10.10%, Best Train Accuracy: 12.64, Loss to best acc:2.31%
#
# Epoch [100/100], Final Valid Loss: 2.3029, Final Valid Accuracy: 9.98%, Best Valid Accuracy: 10.20%, Loss to best Valid accuracy:2.30
#
# 模型参数已保存为LP-RL-model_scale=0.9.pth
#
# {'训练的模型的保留路径': 'LP-RL-model_scale=0.9.pth', '在测试集中的最终损失': 2.3028738498687744, '在测试集中的最终准确率': 0.09983, '在测试集中的最佳准确率': 0.102, '在训练集中的最终准确率': 0.101, '在训练集中的最佳准确率': 0.1264, '在训练集中的最终损失': 2.3028903007507324, '在训练集中的最佳损失': 2.3131585121154785}
