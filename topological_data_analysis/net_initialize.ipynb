# %%
# %load_ext autoreload
# %autoreload 2

from net.custome_net import MLP,LeNet,ModelInitializer
import torch
import torch.nn as nn
import torchvision.models as models
import torch.nn.init as init
from dataset.get_dataloader import get_dataloader,loader2vec, vec_dis
from dataset.data2betti import distance_betti, distance_betti_ripser, plt_betti_number,plot_betti_number_bars
from ripser import Rips, ripser
import numpy as np
from dataset.get_betti_number import betti_4_net
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
k = betti_4_net(model=LeNet(), save_root="./distance/LeNet-NT/",debug_size=10,seed=15,name=LeNet.__name__,transform=None)
print(k)
# Out:
# {'LeNet-birth-death-l1_distance': [array([[0.        , 1.06292272],
#        [0.        , 1.30114305],
#        [0.        , 1.37920427],
#        [0.        , 1.39132977],
#        [0.        , 1.42303061],
#        [0.        , 1.45249796],
#        [0.        , 1.57130551],
#        [0.        , 1.67600536],
#        [0.        , 1.75592625],
#        [0.        , 1.78823137],
#        [0.        , 1.85642791],
#        [0.        , 1.93487763],
#        [0.        , 1.94805741],
#        [0.        , 2.05737567],
#        [0.        , 2.08060002],
#        [0.        , 2.14623785],
#        [0.        , 2.19516134],
#        [0.        , 2.24755669],
#        [0.        , 2.61747313],
#        [0.        ,        inf]]), array([[2.27677441, 2.29246354],
#        [2.27585888, 2.28646421],
#        [2.11470079, 2.22068048],
#        [1.99725962, 2.01795006],
#        [1.98721111, 2.27474284]])], 'LeNet-birth-death-l2_distance': [array([[0.        , 0.40644619],
#        [0.        , 0.49155563],
#        [0.        , 0.5001632 ],
#        [0.        , 0.50825357],
#        [0.        , 0.55744499],
#        [0.        , 0.57112908],
#        [0.        , 0.66635793],
#        [0.        , 0.68423796],
#        [0.        , 0.70209503],
#        [0.        , 0.72032505],
#        [0.        , 0.72064865],
#        [0.        , 0.7272324 ],
#        [0.        , 0.77046806],
#        [0.        , 0.79340583],
#        [0.        , 0.8134591 ],
#        [0.        , 0.83565593],
#        [0.        , 0.88738006],
#        [0.        , 0.89534158],
#        [0.        , 1.02271891],
#        [0.        ,        inf]]), array([[0.91515589, 0.97447872],
#        [0.91381472, 0.9698745 ],
#        [0.90238148, 0.9450534 ],
#        [0.7929287 , 0.81595653],
#        [0.78674656, 0.85906422],
#        [0.76958418, 0.77066988],
#        [0.75061679, 0.79368263]])]}
