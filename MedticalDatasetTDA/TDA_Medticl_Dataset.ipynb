# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # TDA in BUSI

# %% [markdown]
# ## 考察input的feature

# %%
# 加载自己的包
from TDA.data_tda import Image2TDA, CompareTDA

folder = ".//Result//UNeXt_output_TDA//output_BUSI"
test_BOF = CompareTDA(file_path=folder, target_pkl="L2_betti_features_0th.pkl")

# print(test_BOF.comb_BOF)
test_BOF.draw_BOF(net_name="Data", aug_name="crop")

# %% [markdown]
# ## 考察input的bars

# %% [markdown]
# ### 首先加载数据

# %%
import pickle
# 定义一个加载pkl文件的函数
def print_pkl_file(file_path):
    try:
        with open(file_path, 'rb') as file:
            data = pickle.load(file)
            # print(data)
    except Exception as e:
        print(f"Error: {e}")
    
    return data

# %% [markdown]
# ### 然后绘制图像

# %%
import os
import matplotlib.pyplot as plt

def plot_stacked_horizontal_bars2(ax, bar_data, index_title, color, pre_index):
    """
    绘制表示持续区间的堆叠水平条形图。

    参数:
    - ax (matplotlib.axes._axes.Axes): 子图对象。
    - bar_data (列表): 表示持续区间的数据列表，每个元素是包含起始和结束位置的列表。
    - index_title (整数): 用于标题的索引。
    - color (str): 条形图的颜色。
    - plt_title (str): 图的标题。

    返回: 无返回值，但会在子图上显示绘制的水平条形图。
    """

    for index, bar in enumerate(bar_data):
        # print(bar)
        start = bar[0]  # 起始位置
        end = bar[1]    # 结束位置
        # 绘制水平条形图
        if index == 0:
            ax.barh(index + pre_index,  end - start, left=start, height=0.5, color=color, label=index_title)
        else:
            ax.barh(index + pre_index,  end - start, left=start, height=0.5, color=color)

def plot_betti_number_bars2(betti_number, plt_title=None, root=None):
    """
    绘制表示 Betti 数的堆叠水平条形图。

    参数:
    - betti_number (列表的列表): 包含多个 Betti 数的列表，每个 Betti 数以堆叠水平条形图表示。
    - bar_spacing (浮点数): 条形图之间的间距。
    - plt_title (str): 图的标题。
    - root (str): 图的保存路径。

    返回: 无返回值，但会在同一张图上显示绘制的堆叠水平条形图。
    """
    if not os.path.exists(root):
        os.makedirs(root)

    fig, ax = plt.subplots()

    colors = ['red', 'black']  # 定义不同 Betti 数的颜色
    pre_index = 0
    for index, (value, color) in enumerate(zip(betti_number, colors)):
        if index == 0:
            pre_index += len(betti_number[1])
        else:
            pre_index = 0
        plot_stacked_horizontal_bars2(ax, value, index, color, pre_index)
        

    # 设置坐标轴标签
    ax.set_ylabel('Number')
    ax.set_xlabel('Birth-Death')
    ax.set_title(f"Persistence barcode {plt_title}")

    # 添加图例
    ax.legend()

    # 保存图片
    save_path = os.path.join(root, f"Betti_Bars_{plt_title}.png")
    plt.savefig(save_path)

    # 显示图表
    plt.show()

# %%
# 例子
pkl_file_path = './Result/UNext_output_TDA/input_BUSI/8/bars_betti_features_12th.pkl'
test_data = print_pkl_file(pkl_file_path)
L12save = test_data['L1_betti_number_list'][0]
L22save = test_data['L2_betti_number_list'][0]

# %%
data = L22save
plot_betti_number_bars2(betti_number=data, plt_title='L2', root="./test/")

# %% [markdown]
# ### 批量处理

# %%
# 单个处理的例子
pkl_file_path = './Result/UNext_output_TDA/input_BUSI/8/bars_betti_features_12th.pkl'
test_data = print_pkl_file(pkl_file_path)
L12save = test_data['L1_betti_number_list'][0]
L22save = test_data['L2_betti_number_list'][0]

plot_betti_number_bars2(betti_number=L12save, plt_title='L1{}'.format(5), root="./test/")
plot_betti_number_bars2(betti_number=L22save, plt_title='L2{}'.format(5), root="./test/")

# %%
import os

def print_subdirectories(folder_path):
    """
    打印指定文件夹下的子文件夹路径。

    参数:
    - folder_path (str): 目标文件夹的路径。

    返回: 无返回值，但会打印子文件夹的路径。
    """
    # 获取文件夹下的所有子文件夹
    subdirectories = [os.path.join(folder_path, d) for d in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, d))]

    # 打印子文件夹的路径
    for subdirectory in subdirectories:
        print(os.path.join(subdirectory, 'bars_betti_features_12th.pkl'))
        pkl_file_path = os.path.join(subdirectory, 'bars_betti_features_12th.pkl')
        test_data = print_pkl_file(pkl_file_path)
        L12save = test_data['L1_betti_number_list'][0]
        L22save = test_data['L2_betti_number_list'][0]

        plot_betti_number_bars2(betti_number=L12save, plt_title='L1{}'.format(subdirectory.split('/')[-1]), root="./test/")
        plot_betti_number_bars2(betti_number=L22save, plt_title='L2{}'.format(subdirectory.split('/')[-1]), root="./test/")

# 示例用法
folder_path = "./Result/UNext_output_TDA/input_BUSI/"
print_subdirectories(folder_path)
# Out:
# ./Result/UNext_output_TDA/input_BUSI/104\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/112\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/120\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/128\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/136\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/144\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/152\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/16\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/160\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/168\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/176\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/184\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/192\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/200\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/208\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/216\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/224\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/232\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/24\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/240\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/248\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/256\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/32\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/40\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/48\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/56\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/64\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/72\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/8\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/80\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/88\bars_betti_features_12th.pkl
# ./Result/UNext_output_TDA/input_BUSI/96\bars_betti_features_12th.pkl
